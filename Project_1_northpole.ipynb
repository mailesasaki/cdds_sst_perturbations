# %%
from netCDF4 import Dataset as NetCDFFile
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
import netCDF4 as nc
from netCDF4 import Dataset
from matplotlib import gridspec
import glob

data_control_path = glob.glob("/data/keeling/a/pappup2/a/CESM/cam5_new/CESM_output_data/atm/hist/*") #End of year control
data_control_last18=data_control_path[24:240] # Get years 3-20
data_control_data = xr.open_mfdataset(data_control_last18,combine="by_coords",use_cftime=True)
data_control = data_control_data.mean('time') # Average over the last 18 years

data_pole_path = glob.glob("/data/keeling/a/mailes2/a/CESM_DATA/aqua_northpoleperturb/outputdata/atm/hist/*") #End of year expriment-2 extraopical patch
data_pole_last18=data_pole_path[24:240] # Get years 3-20
data_pole_data = xr.open_mfdataset(data_pole_last18,combine="by_coords",use_cftime=True)
data_pole_n = data_pole_data.mean('time') # Average over the last 18 years


data_00_path = glob.glob("/data/keeling/a/pappup2/a/CESM/cam_00/CESM_output_data/atm/hist/*")
data_00_last18=data_00_path[24:240] # Get years 3-20
data_00_data = xr.open_mfdataset(data_00_last18,combine="by_coords",use_cftime=True)
data_00 = data_00_data.mean('time') # Average over the last 18 years


data_15_path=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_15_n/CESM_output_data/atm/hist/*")
data_15_last18=data_15_path[24:240] # Get years 3-20
data_15_data = xr.open_mfdataset(data_15_last18,combine="by_coords",use_cftime=True)
data_15_n = data_15_data.mean('time') # Average over the last 18 years

data_30_path=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_30_n/CESM_output_data/atm/hist/*")
data_30_last18=data_30_path[24:240] # Get years 3-20
data_30_data = xr.open_mfdataset(data_30_last18,combine="by_coords",use_cftime=True)
data_30_n = data_30_data.mean('time') # Average over the last 18 years


data_extratropic_path=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_45_n/CESM_output_data/atm/hist/*")
data_extratropic_last18=data_extratropic_path[24:240] # Get years 3-20
data_extratropic_data = xr.open_mfdataset(data_extratropic_last18,combine="by_coords",use_cftime=True)
data_45_n = data_extratropic_data.mean('time') # Average over the last 18 years


data_60_path=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_60_n/CESM_output_data/atm/hist/*")
data_60_last18=data_60_path[24:240] # Get years 3-20
data_60_data = xr.open_mfdataset(data_60_last18,combine="by_coords",use_cftime=True)
data_60_n = data_60_data.mean('time') # Average over the last 18 years


data_75_path=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_75_n/CESM_output_data/atm/hist/*")
data_75_last18=data_75_path[24:240] # Get years 3-20
data_75_data = xr.open_mfdataset(data_75_last18,combine="by_coords",use_cftime=True)
data_75_n = data_75_data.mean('time') # Average over the last 18 years

#surface_t2 = surface_t_2.mean('lon')
TOA_flux_exp_minus_control_pole_n = (data_pole_n.FSNT.mean('lon')-data_pole_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_15_n = (data_15_n.FSNT.mean('lon')-data_15_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_30_n = (data_30_n.FSNT.mean('lon')-data_30_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_45_n = (data_45_n.FSNT.mean('lon')-data_45_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_00 = (data_00.FSNT.mean('lon')-data_00.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_60_n = (data_60_n.FSNT.mean('lon')-data_60_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_75_n = (data_75_n.FSNT.mean('lon')-data_75_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
# Out:
# /data/keeling/a/pappup2/miniconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
pp_pole_n=np.array(TOA_flux_exp_minus_control_pole_n)
#zp= pp.transpose()
exp_pole_n=np.linspace(0,1,96)
plat_pole_n=np.array(TOA_flux_exp_minus_control_pole_n.lat)
expp_pole_n, ppp_pole_n=np.meshgrid(exp_pole_n, pp_pole_n)
#plt.figure(figsize=(10,3))

pp_00=np.array(TOA_flux_exp_minus_control_00)
#zp= pp.transpose()
exp_00=np.linspace(0,1,96)
plat_00=np.array(TOA_flux_exp_minus_control_00.lat)
expp_00, ppp_00=np.meshgrid(exp_00, pp_00)

pp_15_n=np.array(TOA_flux_exp_minus_control_15_n)
#zp= pp.transpose()
exp_15_n=np.linspace(0,1,96)
plat_15_n=np.array(TOA_flux_exp_minus_control_15_n.lat)
expp_15_n, ppp_15_n=np.meshgrid(exp_15_n, pp_15_n)

pp_30_n=np.array(TOA_flux_exp_minus_control_30_n)
#zp= pp.transpose()
exp_30_n=np.linspace(0,1,96)
plat_30_n=np.array(TOA_flux_exp_minus_control_30_n.lat)
expp_30_n, ppp_30_n=np.meshgrid(exp_30_n, pp_30_n)

pp_45_n=np.array(TOA_flux_exp_minus_control_45_n)
#zp= pp.transpose()
exp_45_n=np.linspace(0,1,96)
plat_45_n=np.array(TOA_flux_exp_minus_control_45_n.lat)
expp_45_n, ppp_45_n=np.meshgrid(exp_45_n, pp_45_n)

pp_60_n=np.array(TOA_flux_exp_minus_control_60_n)
#zp= pp.transpose()
exp_60_n=np.linspace(0,1,96)
plat_60_n=np.array(TOA_flux_exp_minus_control_60_n.lat)
expp_60_n, ppp_60_n=np.meshgrid(exp_60_n, pp_60_n)

pp_75_n=np.array(TOA_flux_exp_minus_control_75_n)
#zp= pp.transpose()
exp_75_n=np.linspace(0,2,96)
plat_75_n=np.array(TOA_flux_exp_minus_control_75_n.lat)
expp_75_n, ppp_75_n=np.meshgrid(exp_75_n, pp_75_n)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
from mpl_toolkits.axes_grid1 import ImageGrid
import pylab

nrow = 1
ncol = 3
fig = plt.figure(figsize=(25, 20))
grid = ImageGrid(fig, 
                 111, # as in plt.subplot(111)
                 nrows_ncols=(nrow,ncol),
                 axes_pad=0,
                 share_all=True,)

#for i in range(1):
#    for j in range(2):
im = np.random.rand(28,28)
gs = gridspec.GridSpec(7, 7)
gs.update(wspace=0)

plt.subplot(gs[0,0])
plt.pcolormesh(expp_00,plat_00,ppp_00,cmap='RdBu_r',vmin=-30, vmax=30)
plt.yticks(np.arange(-90, 91, 30))
plt.ylabel("Latitude")
plt.xticks([])
plt.xlabel("00 patch")

plt.subplot(gs[0,1])
plt.pcolormesh(expp_15_n,plat_15_n,ppp_15_n,cmap='RdBu_r',vmin=-30, vmax=30)
plt.xticks([])
plt.xlabel("15 patch")
ax = pylab.gca()
ax.yaxis.set_visible(False)

plt.subplot(gs[0,2])
plt.pcolormesh(expp_30_n,plat_30_n,ppp_30_n,cmap='RdBu_r',vmin=-30, vmax=30)
plt.xticks([])
plt.xlabel("30 patch")
ax = pylab.gca()
ax.yaxis.set_visible(False)

plt.subplot(gs[0,3])
plt.pcolormesh(expp_45_n,plat_45_n,ppp_45_n,cmap='RdBu_r',vmin=-30, vmax=30)
plt.xticks([])
plt.xlabel("45 patch")
ax = pylab.gca()
ax.yaxis.set_visible(False)

plt.subplot(gs[0,4])
plt.pcolormesh(expp_60_n,plat_60_n,ppp_60_n,cmap='RdBu_r',vmin=-30, vmax=30)
plt.xticks([])
plt.xlabel("60 patch")
ax = pylab.gca()
ax.yaxis.set_visible(False)

plt.subplot(gs[0,5])
plt.pcolormesh(expp_75_n,plat_75_n,ppp_75_n,cmap='RdBu_r',vmin=-30, vmax=30)
plt.xticks([])
plt.xlabel("75 patch")
ax = pylab.gca()
ax.yaxis.set_visible(False)

plt.subplot(gs[0,6])
plt.pcolormesh(expp_pole_n,plat_pole_n,ppp_pole_n,cmap='RdBu_r',vmin=-30, vmax=30)
plt.xticks([])
plt.xlabel("90 patch")
ax = pylab.gca()
ax.yaxis.set_visible(False)

# Get the current axis
ax = pylab.gca()
# Set Y-axis visibility to False
ax.yaxis.set_visible(False)

#        plt.set_yticklabels([])

#plt.tight_layout() # do not use this!!
plt.subplot(gs[0,6])
plt.colorbar()
plt.show()

# %%
#Surface flux
Qs_pole_n=(-data_pole_n.FLNS.mean('lon')+data_pole_n.FSNS.mean('lon')-data_pole_n.SHFLX.mean('lon')-data_pole_n.LHFLX.mean('lon'))-(-data_control.FLNS.mean('lon')+data_control.FSNS.mean('lon')-data_control.SHFLX.mean('lon')-data_control.LHFLX.mean('lon'))
Qs_00=(-data_00.FLNS.mean('lon')+data_00.FSNS.mean('lon')-data_00.SHFLX.mean('lon')-data_00.LHFLX.mean('lon'))-(-data_control.FLNS.mean('lon')+data_control.FSNS.mean('lon')-data_control.SHFLX.mean('lon')-data_control.LHFLX.mean('lon'))
Qs_15_n=(-data_15_n.FLNS.mean('lon')+data_15_n.FSNS.mean('lon')-data_15_n.SHFLX.mean('lon')-data_15_n.LHFLX.mean('lon'))-(-data_control.FLNS.mean('lon')+data_control.FSNS.mean('lon')-data_control.SHFLX.mean('lon')-data_control.LHFLX.mean('lon'))
Qs_30_n=(-data_30_n.FLNS.mean('lon')+data_30_n.FSNS.mean('lon')-data_30_n.SHFLX.mean('lon')-data_30_n.LHFLX.mean('lon'))-(-data_control.FLNS.mean('lon')+data_control.FSNS.mean('lon')-data_control.SHFLX.mean('lon')-data_control.LHFLX.mean('lon'))
Qs_45_n=(-data_45_n.FLNS.mean('lon')+data_45_n.FSNS.mean('lon')-data_45_n.SHFLX.mean('lon')-data_45_n.LHFLX.mean('lon'))-(-data_control.FLNS.mean('lon')+data_control.FSNS.mean('lon')-data_control.SHFLX.mean('lon')-data_control.LHFLX.mean('lon'))
Qs_60_n=(-data_60_n.FLNS.mean('lon')+data_60_n.FSNS.mean('lon')-data_60_n.SHFLX.mean('lon')-data_60_n.LHFLX.mean('lon'))-(-data_control.FLNS.mean('lon')+data_control.FSNS.mean('lon')-data_control.SHFLX.mean('lon')-data_control.LHFLX.mean('lon'))
Qs_75_n=(-data_75_n.FLNS.mean('lon')+data_75_n.FSNS.mean('lon')-data_75_n.SHFLX.mean('lon')-data_75_n.LHFLX.mean('lon'))-(-data_control.FLNS.mean('lon')+data_control.FSNS.mean('lon')-data_control.SHFLX.mean('lon')-data_control.LHFLX.mean('lon'))

#TOA
TOA_pole_n = (data_pole_n.FSNT.mean('lon')-data_pole_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_00 = (data_00.FSNT.mean('lon')-data_00.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_15_n = (data_15_n.FSNT.mean('lon')-data_15_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_30_n = (data_30_n.FSNT.mean('lon')-data_30_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_45_n = (data_45_n.FSNT.mean('lon')-data_45_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_60_n = (data_60_n.FSNT.mean('lon')-data_60_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_75_n = (data_75_n.FSNT.mean('lon')-data_75_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

# %%
Qs_pole_n.plot(color='black', label='90 patch')
Qs_00.plot(color='teal',label='00 patch')
Qs_15_n.plot(color='pink',label='15 patch')
Qs_30_n.plot(color='brown',label='30 patch')
Qs_45_n.plot(color='yellow',label='45 patch')
Qs_60_n.plot(color='red',label='60 patch')
Qs_75_n.plot(color='green',label='75 patch')
plt.legend(loc='upper right')
plt.title('Surface heat flux')
# Out:
# Text(0.5, 1.0, 'Surface heat flux')

# %%
TOA_pole_n.plot(color='black',label='90 patch')
TOA_00.plot(color='teal',label='00 patch')
TOA_15_n.plot(color='pink',label='15 patch')
TOA_30_n.plot(color='brown',label='30 patch')
TOA_45_n.plot(color='yellow',label='45 patch')
TOA_60_n.plot(color='red',label='60 patch')
TOA_75_n.plot(color='green',label='75 patch')
plt.legend(loc='upper left')
plt.title('TOA flux')
# Out:
# Text(0.5, 1.0, 'TOA flux')

# %%
Qs_control= data_control.FLNS.mean('lon')+data_control.FSNS.mean('lon')-data_control.SHFLX.mean('lon')-data_control.LHFLX.mean('lon')

# %%
Qs_control.plot(color='green',label='control')

# %%
Qa_pole_n=Qs_pole_n-TOA_pole_n
Qa_pole_n.plot(color='black',label='Qa')
TOA_pole_n.plot(color='red',label='TOA')
Qs_pole_n.plot(color='green', label='Qs')
plt.legend(loc='upper right')
plt.title("Pole patch")
plt.ylim([-100,70])
# Out:
# (-100.0, 70.0)

# %%
Qa_00=Qs_00-TOA_00
Qa_00.plot(color='black',label='Qa')
TOA_00.plot(color='red',label='TOA')
Qs_00.plot(color='green', label='Qs')
plt.legend(loc='upper right')
plt.title("Equator Patch")
plt.ylim([-100,70])
# Out:
# (-100.0, 70.0)

# %%
Qa_15_n=Qs_15_n-TOA_15_n
Qa_15_n.plot(color='black',label='Qa')
TOA_15_n.plot(color='red',label='TOA')
Qs_15_n.plot(color='green', label='Qs')
plt.legend(loc='upper right')
plt.title("15 deg Patch")
plt.ylim([-100,70])
# Out:
# (-100.0, 70.0)

# %%
Qa_30_n=Qs_30_n-TOA_30_n
Qa_30_n.plot(color='black',label='Qa')
TOA_30_n.plot(color='red',label='TOA')
Qs_30_n.plot(color='green', label='Qs')
plt.legend(loc='upper right')
plt.title("30 deg Patch")
plt.ylim([-100,70])
# Out:
# (-100.0, 70.0)

# %%
Qa_45_n=Qs_45_n-TOA_45_n
Qa_45_n.plot(color='black',label='Qa')
TOA_45_n.plot(color='red',label='TOA')
Qs_45_n.plot(color='green', label='Qs')
plt.legend(loc='upper right')
plt.title("45 deg Patch")
plt.ylim([-100,70])
# Out:
# (-100.0, 70.0)

# %%
Qa_60_n=Qs_60_n-TOA_60_n
Qa_60_n.plot(color='black',label='Qa')
TOA_60_n.plot(color='red',label='TOA')
Qs_60_n.plot(color='green', label='Qs')
plt.legend(loc='upper center')
plt.title("60 deg Patch")
plt.ylim([-100,70])
# Out:
# (-100.0, 70.0)

# %%
Qa_75_n=Qs_75_n-TOA_75_n
Qa_75_n.plot(color='black',label='Qa')
TOA_75_n.plot(color='red',label='TOA')
Qs_75_n.plot(color='green', label='Qs')
plt.legend(loc='upper center')
plt.title("75 deg Patch")
plt.ylim([-100,70])
plt.axvspan(65, 85, color='yellow', alpha=0.5)
plt.xticks([-90, -80, -60,-40,-20,0,20,40,60,80,90])
plt.xticks(rotation=40)
# Out:
# (array([-90, -80, -60, -40, -20,   0,  20,  40,  60,  80,  90]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
from mpl_toolkits.axes_grid1 import ImageGrid
import pylab

nrow = 1
ncol = 7
fig = plt.figure(figsize=(25, 20))
grid = ImageGrid(fig, 
                 111, # as in plt.subplot(111)
                 nrows_ncols=(nrow,ncol),
                 axes_pad=0,
                 share_all=True,)

#for i in range(1):
#    for j in range(2):
im = np.random.rand(28,28)
gs = gridspec.GridSpec(7, 7)
gs.update(wspace=0.1)

plt.subplot(gs[0,0])
Qa_00=Qs_00-TOA_00
Qa_00.plot(color='black',label='Qa')
TOA_00.plot(color='red',label='TOA')
Qs_00.plot(color='green', label='Qs')
plt.legend(loc='upper left')
plt.title("Equator Patch")
plt.ylim([-100,70])
plt.axvspan(-10, 10, color='yellow', alpha=0.5)
plt.xticks([-90, -80, -60,-40,-20,0,20,40,60,80,90])
plt.xticks(rotation=90)

plt.subplot(gs[0,1])
Qa_15_n=Qs_15_n-TOA_15_n
Qa_15_n.plot(color='black',label='Qa')
TOA_15_n.plot(color='red',label='TOA')
Qs_15_n.plot(color='green', label='Qs')
plt.legend(loc='upper left')
plt.title("15 deg Patch")
plt.ylim([-100,70])
ax = pylab.gca()
ax.yaxis.set_visible(False)
plt.axvspan(5, 25, color='yellow', alpha=0.5)
plt.xticks([-90, -80, -60,-40,-20,0,20,40,60,80,90])
plt.xticks(rotation=90)

plt.subplot(gs[0,2])
Qa_30_n=Qs_30_n-TOA_30_n
Qa_30_n.plot(color='black',label='Qa')
TOA_30_n.plot(color='red',label='TOA')
Qs_30_n.plot(color='green', label='Qs')
plt.legend(loc='upper left')
plt.title("30 deg Patch")
plt.ylim([-100,70])
ax = pylab.gca()
ax.yaxis.set_visible(False)
plt.axvspan(20, 40, color='yellow', alpha=0.5)
plt.xticks([-90, -80, -60,-40,-20,0,20,40,60,80,90])
plt.xticks(rotation=90)

plt.subplot(gs[0,3])
Qa_45_n=Qs_45_n-TOA_45_n
Qa_45_n.plot(color='black',label='Qa')
TOA_45_n.plot(color='red',label='TOA')
Qs_45_n.plot(color='green', label='Qs')
plt.legend(loc='upper left')
plt.title("45 deg Patch")
plt.ylim([-100,70])
ax = pylab.gca()
ax.yaxis.set_visible(False)
plt.axvspan(35, 55, color='yellow', alpha=0.5)
plt.xticks([-90, -80, -60,-40,-20,0,20,40,60,80,90])
plt.xticks(rotation=90)


plt.subplot(gs[0,4])
Qa_60_n=Qs_60_n-TOA_60_n
Qa_60_n.plot(color='black',label='Qa')
TOA_60_n.plot(color='red',label='TOA')
Qs_60_n.plot(color='green', label='Qs')
plt.legend(loc='upper left')
plt.title("60 deg Patch")
plt.ylim([-100,70])
ax = pylab.gca()
ax.yaxis.set_visible(False)
plt.axvspan(50, 70, color='yellow', alpha=0.5)
plt.xticks([-90, -80, -60,-40,-20,0,20,40,60,80,90])
plt.xticks(rotation=90)

plt.subplot(gs[0,5])
Qa_75_n=Qs_75_n-TOA_75_n
Qa_75_n.plot(color='black',label='Qa')
TOA_75_n.plot(color='red',label='TOA')
Qs_75_n.plot(color='green', label='Qs')
plt.legend(loc='upper left')
plt.title("75 deg Patch")
plt.ylim([-100,70])
ax = pylab.gca()
ax.yaxis.set_visible(False)
plt.axvspan(65, 85, color='yellow', alpha=0.5)
plt.xticks([-90, -80, -60,-40,-20,0,20,40,60,80,90])
plt.xticks(rotation=90)

plt.subplot(gs[0,6])
Qa_pole_n=Qs_pole_n-TOA_pole_n
Qa_pole_n.plot(color='black',label='Qa')
TOA_pole_n.plot(color='red',label='TOA')
Qs_pole_n.plot(color='green', label='Qs')
plt.legend(loc='upper left')
plt.title("Pole patch")
plt.ylim([-100,70])
ax = pylab.gca()
ax.yaxis.set_visible(False)
plt.axvspan(80, 90, color='yellow', alpha=0.5)
plt.xticks([-90, -80, -60,-40,-20,0,20,40,60,80,90])
plt.xticks(rotation=90)

# Get the current axis
ax = pylab.gca()
# Set Y-axis visibility to False
ax.yaxis.set_visible(False)

#        plt.set_yticklabels([])

#plt.tight_layout() # do not use this!!
#plt.subplot(gs[0,6])
#plt.colorbar()
plt.show()

# %%
T_pole_n=data_pole_n.T.mean('lon')-data_control.T.mean('lon')
T_pole_n.plot(vmax=5, vmin=-5,yincrease=False, cmap='RdBu_r')
plt.yscale("log")
plt.title('Pole patch')
# Out:
# Text(0.5, 1.0, 'Pole patch')

# %%
T_00=data_00.T.mean('lon')-data_control.T.mean('lon')
T_00.plot(vmax=5, vmin=-5,yincrease=False, cmap='RdBu_r')
plt.yscale("log")
plt.title('Equator patch')
# Out:
# Text(0.5, 1.0, 'Equator patch')

# %%
T_15_n=data_15_n.T.mean('lon')-data_control.T.mean('lon')
T_15_n.plot(vmax=5, vmin=-5,yincrease=False, cmap='RdBu_r')
plt.yscale("log")
plt.title('15 deg patch')
# Out:
# Text(0.5, 1.0, '15 deg patch')

# %%
T_30_n=data_30_n.T.mean('lon')-data_control.T.mean('lon')
T_30_n.plot(vmax=5, vmin=-5,yincrease=False, cmap='RdBu_r')
plt.yscale("log")
plt.title('30 patch')
# Out:
# Text(0.5, 1.0, '30 patch')

# %%
T_45_n=data_45_n.T.mean('lon')-data_control.T.mean('lon')
T_45_n.plot(vmax=5, vmin=-5,yincrease=False, cmap='RdBu_r')
plt.yscale("log")
plt.title('45 deg patch')
# Out:
# Text(0.5, 1.0, '45 deg patch')

# %%
T_60_n=data_60_n.T.mean('lon')-data_control.T.mean('lon')
T_60_n.plot(vmax=5, vmin=-5,yincrease=False, cmap='RdBu_r')
plt.yscale("log")

plt.title('60 deg patch')
# Out:
# Text(0.5, 1.0, '60 deg patch')

# %%
T_75_n=data_75_n.T.mean('lon')-data_control.T.mean('lon')
T_75_n.plot(vmax=5, vmin=-5,yincrease=False, cmap='RdBu_r')
plt.yscale("log")
plt.title('75 deg patch')
plt.axvline(0, color='black')

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
from mpl_toolkits.axes_grid1 import ImageGrid
import pylab

nrow = 1
ncol = 7
fig = plt.figure(figsize=(25, 20))
grid = ImageGrid(fig, 
                 111, # as in plt.subplot(111)
                 nrows_ncols=(nrow,ncol),
                 axes_pad=0,
                 share_all=True,)

#for i in range(1):
#    for j in range(2):
im = np.random.rand(28,28)
gs = gridspec.GridSpec(7, 7)
gs.update(wspace=0.1)

plt.subplot(gs[0,0])
T_00=data_00.T.mean('lon')-data_control.T.mean('lon')
T_00.plot(vmax=5, vmin=-5,yincrease=False, cmap='RdBu_r')
plt.yscale("log")
plt.title('Equator patch')
ax = pylab.gca()
plt.axvline(0, color='black')
plt.xticks([-90, -80, -60,-40,-20,0,20,40,60,80,90])
plt.xticks(rotation=90)

plt.subplot(gs[0,1])
T_15_n=data_15_n.T.mean('lon')-data_control.T.mean('lon')
T_15_n.plot(vmax=5, vmin=-5,yincrease=False, cmap='RdBu_r')
plt.yscale("log")
plt.title('15 deg patch')
ax = pylab.gca()
ax.yaxis.set_visible(False)
plt.axvline(15, color='black')
plt.xticks([-90, -80, -60,-40,-20,0,20,40,60,80,90])
plt.xticks(rotation=90)

plt.subplot(gs[0,2])
T_30_n=data_30_n.T.mean('lon')-data_control.T.mean('lon')
T_30_n.plot(vmax=5, vmin=-5,yincrease=False, cmap='RdBu_r')
plt.yscale("log")
plt.title('30 patch')
ax = pylab.gca()
ax.yaxis.set_visible(False)
plt.axvline(30, color='black')
plt.xticks([-90, -80, -60,-40,-20,0,20,40,60,80,90])
plt.xticks(rotation=90)

plt.subplot(gs[0,3])
T_45_n=data_45_n.T.mean('lon')-data_control.T.mean('lon')
T_45_n.plot(vmax=5, vmin=-5,yincrease=False, cmap='RdBu_r')
plt.yscale("log")
plt.title('45 deg patch')
ax = pylab.gca()
ax.yaxis.set_visible(False)
plt.axvline(45, color='black')
plt.xticks([-90, -80, -60,-40,-20,0,20,40,60,80,90])
plt.xticks(rotation=90)

plt.subplot(gs[0,4])
T_60_n=data_60_n.T.mean('lon')-data_control.T.mean('lon')
T_60_n.plot(vmax=5, vmin=-5,yincrease=False, cmap='RdBu_r')
plt.yscale("log")
plt.title('60 deg patch')
ax = pylab.gca()
ax.yaxis.set_visible(False)
plt.axvline(60, color='black')
plt.xticks([-90, -80, -60,-40,-20,0,20,40,60,80,90])
plt.xticks(rotation=90)

plt.subplot(gs[0,5])
T_75_n=data_75_n.T.mean('lon')-data_control.T.mean('lon')
T_75_n.plot(vmax=5, vmin=-5,yincrease=False, cmap='RdBu_r')
plt.yscale("log")
plt.title('75 deg patch')
ax = pylab.gca()
ax.yaxis.set_visible(False)
plt.axvline(75, color='black')
plt.xticks([-90, -80, -60,-40,-20,0,20,40,60,80,90])
plt.xticks(rotation=90)

plt.subplot(gs[0,6])
T_pole_n=data_pole_n.T.mean('lon')-data_control.T.mean('lon')
T_pole_n.plot(vmax=5, vmin=-5,yincrease=False, cmap='RdBu_r')
plt.yscale("log")
plt.title('Pole patch')
ax = pylab.gca()
ax.yaxis.set_visible(False)
plt.axvline(90, color='black')
plt.xticks([-90, -80, -60,-40,-20,0,20,40,60,80,90])
plt.xticks(rotation=90)

# Get the current axis
ax = pylab.gca()
# Set Y-axis visibility to False
ax.yaxis.set_visible(False)

#        plt.set_yticklabels([])

#plt.tight_layout() # do not use this!!
#plt.subplot(gs[0,6])
#plt.colorbar()
plt.show()

# %%
TOA_pole_avg = (data_pole.FSNT.mean(('lat','lon'))-data_pole.FLNT.mean(('lat','lon')))-(data_control.FSNT.mean(('lat','lon'))-data_control.FLNT.mean(('lat','lon')))
