# %%
# Loading libraries

import xarray as xr
import matplotlib.pyplot as plt
import glob

# %% [markdown]
# # Load Control Data

# %% [markdown]
# # Polar Perturbations

# %%
# Load datasets

pole_path = glob.glob('/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/*')
pole_path_last18 = pole_path[24:240] # Get years 3-20
print(pole_path_last18)
# Out:
# ['/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0003-01.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0003-02.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0003-03.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0003-04.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0003-05.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0003-06.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0003-07.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0003-08.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0003-09.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0003-10.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0003-11.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0003-12.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0004-01.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0004-02.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0004-03.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0004-04.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0004-05.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0004-06.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0004-07.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0004-08.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0004-09.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0004-10.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0004-11.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0004-12.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0005-01.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0005-02.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0005-03.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0005-04.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0005-05.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0005-06.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0005-07.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0005-08.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0005-09.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0005-10.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0005-11.nc', '/data/keeling/a/mailes2/a/CESM_DATA/aqua_poleperturb/outputdata/atm/hist/aqua_poleperturb.cam.h0.0005-12.nc', '/d ...

# %%
pole_data = xr.open_mfdataset(pole_path_last18,combine="by_coords",use_cftime=True)
poles = pole_data.mean('time') # Average over the last 18 years
poles
# Out:
# <xarray.Dataset>
# Dimensions:        (lev: 30, ilev: 31, lat: 96, lon: 144, slat: 95, slon: 144)
# Coordinates:
#   * lev            (lev) float64 3.643 7.595 14.36 24.61 ... 957.5 976.3 992.6
#   * ilev           (ilev) float64 2.255 5.032 10.16 18.56 ... 967.5 985.1 1e+03
#   * lat            (lat) float64 -90.0 -88.11 -86.21 -84.32 ... 86.21 88.11 90.0
#   * lon            (lon) float64 0.0 2.5 5.0 7.5 ... 350.0 352.5 355.0 357.5
#   * slat           (slat) float64 -89.05 -87.16 -85.26 ... 85.26 87.16 89.05
#   * slon           (slon) float64 -1.25 1.25 3.75 6.25 ... 351.2 353.8 356.2
# Data variables: (12/160)
#     hyam           (lev) float64 dask.array<chunksize=(30,), meta=np.ndarray>
#     hybm           (lev) float64 dask.array<chunksize=(30,), meta=np.ndarray>
#     hyai           (ilev) float64 dask.array<chunksize=(31,), meta=np.ndarray>
#     hybi           (ilev) float64 dask.array<chunksize=(31,), meta=np.ndarray>
#     P0             float64 1e+05
#     date           float64 dask.array<chunksize=(), meta=np.ndarray>
#     ...             ...
#     pom_a1_SRF     (lat, lon) float32 dask.array<chunksize=(96, 144), meta=np.ndarray>
#     so4_a1_SRF     (lat, lon) float32 dask.array<chunksize=(96, 144), meta=np.ndarray>
#     so4_a2_SRF     (lat, lon) float32 dask.array<chunksize=(96, 144), meta=np.ndarray>
#     so4_a3_SRF     (lat, lon) float32 dask.array<chunksize=(96, 144), meta=np.ndarray>
#     soa_a1_SRF     (lat, lon) float32 dask.array<chunksize=(96, 144), meta=np.ndarray>
#     soa_a2_SRF     (lat, lon) float32 dask.array<chunksize=(96, 144), meta=np.ndarray>

# %% [markdown]
# ## Surface Temperature

# %%
poles.mean('lon').TS.plot()
plt.title('Surface Temperature - Poles')
# Out:
# Text(0.5, 1.0, 'Surface Temperature - Poles')

# %% [markdown]
# ## Top of Atmosphere radiation

# %%
poles_TOA = poles.FSNT.mean('lon') - poles.FLNT.mean('lon')
poles_TOA.plot()
