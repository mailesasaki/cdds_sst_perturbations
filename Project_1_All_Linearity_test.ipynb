# %% [markdown]
# # Load Data

# %%
from netCDF4 import Dataset as NetCDFFile
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
import netCDF4 as nc
from netCDF4 import Dataset
from matplotlib import gridspec
import glob
import cartopy.crs as ccrs
from matplotlib.pyplot import cm
import numpy as np
from mpl_toolkits.axes_grid1 import ImageGrid
import pylab

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
from mpl_toolkits.axes_grid1 import ImageGrid
import pylab as pl

# %%
#Processed data load
data_control = xr.open_dataset('/data/keeling/a/mailes2/a/processed_aquap_data/control_20yr.nc')
data_pole_n = xr.open_dataset('/data/keeling/a/mailes2/a/processed_aquap_data/perturb_90_n_20yr.nc')
data_85_n = xr.open_dataset('/data/keeling/a/mailes2/a/processed_aquap_data/perturb_85_n_20yr.nc')
data_80_n = xr.open_dataset('/data/keeling/a/mailes2/a/processed_aquap_data/perturb_80_n_20yr.nc')
data_75_n = xr.open_dataset('/data/keeling/a/mailes2/a/processed_aquap_data/perturb_75_n_20yr.nc')
data_70_n = xr.open_dataset('/data/keeling/a/mailes2/a/processed_aquap_data/perturb_70_n_20yr.nc')
data_65_n = xr.open_dataset('/data/keeling/a/mailes2/a/processed_aquap_data/perturb_65_n_20yr.nc')
data_60_n = xr.open_dataset('/data/keeling/a/mailes2/a/processed_aquap_data/perturb_60_n_20yr.nc')
data_55_n = xr.open_dataset('/data/keeling/a/mailes2/a/processed_aquap_data/perturb_55_n_20yr.nc')
data_50_n = xr.open_dataset('/data/keeling/a/mailes2/a/processed_aquap_data/perturb_50_n_20yr.nc')
data_45_n = xr.open_dataset('/data/keeling/a/mailes2/a/processed_aquap_data/perturb_45_n_20yr.nc')
data_40_n = xr.open_dataset('/data/keeling/a/mailes2/a/processed_aquap_data/perturb_40_n_20yr.nc')
data_35_n = xr.open_dataset('/data/keeling/a/mailes2/a/processed_aquap_data/perturb_35_n_20yr.nc')
data_30_n = xr.open_dataset('/data/keeling/a/mailes2/a/processed_aquap_data/perturb_30_n_20yr.nc')
data_25_n = xr.open_dataset('/data/keeling/a/mailes2/a/processed_aquap_data/perturb_25_n_20yr.nc')
data_20_n = xr.open_dataset('/data/keeling/a/mailes2/a/processed_aquap_data/perturb_20_n_20yr.nc')
data_15_n = xr.open_dataset('/data/keeling/a/mailes2/a/processed_aquap_data/perturb_15_n_20yr.nc')
data_10_n = xr.open_dataset('/data/keeling/a/mailes2/a/processed_aquap_data/perturb_10_n_20yr.nc')
data_05_n = xr.open_dataset('/data/keeling/a/mailes2/a/processed_aquap_data/perturb_05_n_20yr.nc')
data_00 = xr.open_dataset('/data/keeling/a/mailes2/a/processed_aquap_data/perturb_00_20yr.nc')

# %%
data_15_both=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_15/CESM_output_data/atm/hist/*")
data_15_last18_both=data_15_both[24:240] # Get years 3-20
data_15_data_both = xr.open_mfdataset(data_15_last18_both,combine="by_coords",use_cftime=True)
data_15 = data_15_data_both.mean('time') # Average over the last 18 years

data_15_path_s=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_15_s/CESM_output_data/atm/hist/*")
data_15_last18_s=data_15_path_s[24:240] # Get years 3-20
data_15_data_s = xr.open_mfdataset(data_15_last18_s,combine="by_coords",use_cftime=True)
data_15_s = data_15_data_s.mean('time') # Average over the last 18 years

data_4k_n_path=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_4k_n/CESM_output_data/atm/hist/*")
data_4k_n_last18=data_4k_n_path[24:240] # Get years 3-20
data_4k_n_data = xr.open_mfdataset(data_4k_n_last18,combine="by_coords",use_cftime=True)
data_4k_n = data_4k_n_data.mean('time') # Average over the last 18 years

data_4k_n_smooth_path=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_4k_n_smooth/CESM_output_data/atm/hist/*")
data_4k_n_smooth_last18=data_4k_n_smooth_path[24:240] # Get years 3-20
data_4k_n_smooth_data = xr.open_mfdataset(data_4k_n_smooth_last18,combine="by_coords",use_cftime=True)
data_4k_n_smooth = data_4k_n_smooth_data.mean('time') # Average over the last 18 years


data_4k_path=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_4k/CESM_output_data/atm/hist/*")
data_4k_last18=data_4k_path[24:240] # Get years 3-20
data_4k_data = xr.open_mfdataset(data_4k_last18,combine="by_coords",use_cftime=True)
data_4k = data_4k_data.mean('time') # Average over the last 18 years

# %%
data_05_s = data_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))

data_05_both=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_05/CESM_output_data/atm/hist/*")
data_05_last18_both=data_05_both[24:240] # Get years 3-20
data_05_data_both = xr.open_mfdataset(data_05_last18_both,combine="by_coords",use_cftime=True)
data_05 = data_05_data_both.mean('time') # Average over the last 18 years


data_10_s = data_10_n.assign_coords(lat=list(reversed(data_10_n.lat)))

data_10_both=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_10/CESM_output_data/atm/hist/*")
data_10_last18_both=data_10_both[24:240] # Get years 3-20
data_10_data_both = xr.open_mfdataset(data_10_last18_both,combine="by_coords",use_cftime=True)
data_10 = data_10_data_both.mean('time') # Average over the last 18 years

# %%
data_05s_00_05n_path=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_5s_00_5n/CESM_output_data/atm/hist/*")
data_05s_00_05n_last18=data_05s_00_05n_path[24:240] # Get years 3-20
data_05s_00_05n_data = xr.open_mfdataset(data_05s_00_05n_last18,combine="by_coords",use_cftime=True)
data_05s_00_05n = data_05s_00_05n_data.mean('time') # Average over the last 18 years

data_10s_05s_00_05n_10n_path=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_10S_5S_00_5N_10N/CESM_output_data/atm/hist/*")
data_10s_05s_00_05n_10n_last18=data_10s_05s_00_05n_10n_path[24:240] # Get years 3-20
data_10s_05s_00_05n_10n_data = xr.open_mfdataset(data_10s_05s_00_05n_10n_last18,combine="by_coords",use_cftime=True)
data_10s_05s_00_05n_10n = data_10s_05s_00_05n_10n_data.mean('time') # Average over the last 18 years

# %%
wdata_50_path=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_50_n_w100/CESM_output_data/atm/hist/*")
wdata_50_last18=wdata_50_path[24:240] # Get years 3-20
wdata_50_data = xr.open_mfdataset(wdata_50_last18,combine="by_coords",use_cftime=True)
wdata_50_n = wdata_50_data.mean('time') # Average over the last 18 years

wdata_50_s=wdata_50_n.assign_coords(lat=list(reversed(wdata_50_n.lat)))

wdata_50_path_ns=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_50_w100/CESM_output_data/atm/hist/*")
wdata_50_last18_ns=wdata_50_path_ns[24:240] # Get years 3-20
wdata_50_data_ns = xr.open_mfdataset(wdata_50_last18_ns,combine="by_coords",use_cftime=True)
wdata_50 = wdata_50_data_ns.mean('time') # Average over the last 18 years

# %%
wdata_00_path = glob.glob("/data/keeling/a/pappup2/a/CESM/cam_00_w100/CESM_output_data/atm/hist/*")
wdata_00_last18=wdata_00_path[24:240] # Get years 3-20
wdata_00_data = xr.open_mfdataset(wdata_00_last18,combine="by_coords",use_cftime=True)
wdata_00 = wdata_00_data.mean('time') # Average over the last 18 years


wdata_25_path = glob.glob("/data/keeling/a/pappup2/a/CESM/cam_25_n_w100/CESM_output_data/atm/hist/*")
wdata_25_last18=wdata_25_path[24:240] # Get years 3-20
wdata_25_data = xr.open_mfdataset(wdata_25_last18,combine="by_coords",use_cftime=True)
wdata_25_n = wdata_25_data.mean('time') # Average over the last 18 years

wdata_50_path=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_50_n_w100/CESM_output_data/atm/hist/*")
wdata_50_last18=wdata_50_path[24:240] # Get years 3-20
wdata_50_data = xr.open_mfdataset(wdata_50_last18,combine="by_coords",use_cftime=True)
wdata_50_n = wdata_50_data.mean('time') # Average over the last 18 years

wdata_75_path=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_75_n_w100/CESM_output_data/atm/hist/*")
wdata_75_last18=wdata_75_path[24:240] # Get years 3-20
wdata_75_data = xr.open_mfdataset(wdata_75_last18,combine="by_coords",use_cftime=True)
wdata_75_n = wdata_75_data.mean('time') # Average over the last 18 years

wdata_100_path=glob.glob("/data/keeling/a/mailes2/a/CESM_DATA/wide_100/outputdata/atm/hist/*")
wdata_100_last18=wdata_100_path[24:240] # Get years 3-20
wdata_100_data = xr.open_mfdataset(wdata_100_last18,combine="by_coords",use_cftime=True)
wdata_100_n = wdata_100_data.mean('time') # Average over the last 18 years

wdata_125_path=glob.glob("/data/keeling/a/mailes2/a/CESM_DATA/wide_125/outputdata/atm/hist/*")
wdata_125_last18=wdata_125_path[24:240] # Get years 3-20
wdata_125_data = xr.open_mfdataset(wdata_125_last18,combine="by_coords",use_cftime=True)
wdata_125_n = wdata_125_data.mean('time') # Average over the last 18 years

# %% [markdown]
# # TOA COLOR PLOT

# %%
TOA_flux_exp_minus_control_00 = (data_00.FSNT.mean('lon')-data_00.FLNT.mean('lon'))-\
                                (data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

TOA_flux_exp_minus_control_05_n = (data_05_n.FSNT.mean('lon')-data_05_n.FLNT.mean('lon'))-\
                                  (data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

TOA_flux_exp_minus_control_10_n = (data_10_n.FSNT.mean('lon')-data_10_n.FLNT.mean('lon'))-\
                                  (data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

TOA_flux_exp_minus_control_05_s=TOA_flux_exp_minus_control_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))

TOA_flux_exp_minus_control_10_s=TOA_flux_exp_minus_control_10_n.assign_coords(lat=list(reversed(data_10_n.lat)))

Sum_TOA_5= TOA_flux_exp_minus_control_10_s+TOA_flux_exp_minus_control_05_s+TOA_flux_exp_minus_control_05_n+\
         TOA_flux_exp_minus_control_10_n+TOA_flux_exp_minus_control_00

TOA_flux_exp_minus_control_Exp_10s_5s_00_5n_10n = (data_10s_05s_00_05n_10n.FSNT.mean('lon')-data_10s_05s_00_05n_10n.FLNT.mean('lon'))-\
                                                    (data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

pp_total_5=np.array(Sum_TOA_5)
exp_total_5=np.linspace(0,1,96)
plat_total_5=np.array(Sum_TOA_5.lat)
expp_total_5, ppp_total_5=np.meshgrid(exp_total_5, pp_total_5)

pp_Exp_10s_5s_00_5n_10n=np.array(TOA_flux_exp_minus_control_Exp_10s_5s_00_5n_10n)
exp_Exp_10s_5s_00_5n_10n=np.linspace(0,1,96)
plat_Exp_10s_5s_00_5n_10n=np.array(TOA_flux_exp_minus_control_Exp_10s_5s_00_5n_10n.lat)
expp_Exp_10s_5s_00_5n_10n, ppp_Exp_10s_5s_00_5n_10n=np.meshgrid(exp_Exp_10s_5s_00_5n_10n, pp_Exp_10s_5s_00_5n_10n)

# %%
TOA_flux_exp_minus_control_00 = (data_00.FSNT.mean('lon')-data_00.FLNT.mean('lon'))-\
                                (data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

TOA_flux_exp_minus_control_05_n = (data_05_n.FSNT.mean('lon')-data_05_n.FLNT.mean('lon'))-\
                                  (data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

TOA_flux_exp_minus_control_05_s=TOA_flux_exp_minus_control_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))
Sum_TOA_3=TOA_flux_exp_minus_control_05_s+TOA_flux_exp_minus_control_05_n+TOA_flux_exp_minus_control_00

TOA_flux_exp_minus_control_Exp_5s_00_5n = (data_05s_00_05n.FSNT.mean('lon')-data_05s_00_05n.FLNT.mean('lon'))-\
                                        (data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
pp_total_3=np.array(Sum_TOA_3)
exp_total_3=np.linspace(0,1,96)
plat_total_3=np.array(Sum_TOA_3.lat)
expp_total_3, ppp_total_3=np.meshgrid(exp_total_3, pp_total_3)

pp_Exp_5s_00_5n=np.array(TOA_flux_exp_minus_control_Exp_5s_00_5n)
exp_Exp_5s_00_5n=np.linspace(0,1,96)
plat_Exp_5s_00_5n=np.array(TOA_flux_exp_minus_control_Exp_5s_00_5n.lat)
expp_Exp_5s_00_5n, ppp_Exp_5s_00_5n=np.meshgrid(exp_Exp_5s_00_5n, pp_Exp_5s_00_5n)

# %%
#+4k NH exp and sum of all NH exp
TOA_flux_exp_minus_control_00 = (data_00.FSNT.mean('lon')-data_00.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_05_n = (data_05_n.FSNT.mean('lon')-data_05_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_10_n = (data_10_n.FSNT.mean('lon')-data_10_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_15_n = (data_15_n.FSNT.mean('lon')-data_15_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_20_n = (data_20_n.FSNT.mean('lon')-data_20_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_25_n = (data_25_n.FSNT.mean('lon')-data_25_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_30_n = (data_30_n.FSNT.mean('lon')-data_30_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_35_n = (data_35_n.FSNT.mean('lon')-data_35_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_40_n = (data_40_n.FSNT.mean('lon')-data_40_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_45_n = (data_45_n.FSNT.mean('lon')-data_45_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_50_n = (data_50_n.FSNT.mean('lon')-data_50_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_55_n = (data_55_n.FSNT.mean('lon')-data_55_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_60_n = (data_60_n.FSNT.mean('lon')-data_60_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_65_n = (data_65_n.FSNT.mean('lon')-data_65_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_70_n = (data_70_n.FSNT.mean('lon')-data_70_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_75_n = (data_75_n.FSNT.mean('lon')-data_75_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_80_n = (data_80_n.FSNT.mean('lon')-data_80_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_85_n = (data_85_n.FSNT.mean('lon')-data_85_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_pole_n = (data_pole_n.FSNT.mean('lon')-data_pole_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

Sum_TOA_NH_exp_19=TOA_flux_exp_minus_control_00+TOA_flux_exp_minus_control_05_n+TOA_flux_exp_minus_control_10_n+TOA_flux_exp_minus_control_15_n+TOA_flux_exp_minus_control_20_n+TOA_flux_exp_minus_control_25_n+TOA_flux_exp_minus_control_30_n+TOA_flux_exp_minus_control_35_n+TOA_flux_exp_minus_control_40_n+TOA_flux_exp_minus_control_45_n+TOA_flux_exp_minus_control_50_n+TOA_flux_exp_minus_control_55_n+TOA_flux_exp_minus_control_60_n+TOA_flux_exp_minus_control_65_n+TOA_flux_exp_minus_control_70_n+TOA_flux_exp_minus_control_75_n+TOA_flux_exp_minus_control_80_n+TOA_flux_exp_minus_control_85_n+TOA_flux_exp_minus_control_pole_n
TOA_flux_exp_minus_control_4k_n = (data_4k_n.FSNT.mean('lon')-data_4k_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

#TOA_flux_exp_minus_control_4k_n = (data_4k_n_smooth.FSNT.mean('lon')-data_4k_n_smooth.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

pp_total_19=np.array(Sum_TOA_NH_exp_19)
exp_total_19=np.linspace(0,1,96)
plat_total_19=np.array(Sum_TOA_NH_exp_19.lat)
expp_total_19, ppp_total_19=np.meshgrid(exp_total_19, pp_total_19)

pp_4k_n=np.array(TOA_flux_exp_minus_control_4k_n)
exp_4k_n=np.linspace(0,1,96)
plat_4k_n=np.array(TOA_flux_exp_minus_control_4k_n.lat)
expp_4k_n, ppp_4k_n=np.meshgrid(exp_4k_n, pp_4k_n)

# %%
TOA_flux_exp_minus_control_05_s=TOA_flux_exp_minus_control_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))
TOA_flux_exp_minus_control_10_s=TOA_flux_exp_minus_control_10_n.assign_coords(lat=list(reversed(data_10_n.lat)))
TOA_flux_exp_minus_control_15_s=TOA_flux_exp_minus_control_15_n.assign_coords(lat=list(reversed(data_15_n.lat)))
TOA_flux_exp_minus_control_20_s=TOA_flux_exp_minus_control_20_n.assign_coords(lat=list(reversed(data_20_n.lat)))
TOA_flux_exp_minus_control_25_s=TOA_flux_exp_minus_control_25_n.assign_coords(lat=list(reversed(data_25_n.lat)))
TOA_flux_exp_minus_control_30_s=TOA_flux_exp_minus_control_30_n.assign_coords(lat=list(reversed(data_30_n.lat)))
TOA_flux_exp_minus_control_35_s=TOA_flux_exp_minus_control_35_n.assign_coords(lat=list(reversed(data_35_n.lat)))
TOA_flux_exp_minus_control_40_s=TOA_flux_exp_minus_control_40_n.assign_coords(lat=list(reversed(data_40_n.lat)))
TOA_flux_exp_minus_control_45_s=TOA_flux_exp_minus_control_45_n.assign_coords(lat=list(reversed(data_45_n.lat)))
TOA_flux_exp_minus_control_50_s=TOA_flux_exp_minus_control_50_n.assign_coords(lat=list(reversed(data_50_n.lat)))
TOA_flux_exp_minus_control_55_s=TOA_flux_exp_minus_control_55_n.assign_coords(lat=list(reversed(data_55_n.lat)))
TOA_flux_exp_minus_control_60_s=TOA_flux_exp_minus_control_60_n.assign_coords(lat=list(reversed(data_60_n.lat)))
TOA_flux_exp_minus_control_65_s=TOA_flux_exp_minus_control_65_n.assign_coords(lat=list(reversed(data_65_n.lat)))
TOA_flux_exp_minus_control_70_s=TOA_flux_exp_minus_control_70_n.assign_coords(lat=list(reversed(data_70_n.lat)))
TOA_flux_exp_minus_control_75_s=TOA_flux_exp_minus_control_75_n.assign_coords(lat=list(reversed(data_75_n.lat)))
TOA_flux_exp_minus_control_80_s=TOA_flux_exp_minus_control_80_n.assign_coords(lat=list(reversed(data_80_n.lat)))
TOA_flux_exp_minus_control_85_s=TOA_flux_exp_minus_control_85_n.assign_coords(lat=list(reversed(data_85_n.lat)))
TOA_flux_exp_minus_control_pole_s=TOA_flux_exp_minus_control_pole_n.assign_coords(lat=list(reversed(data_pole_n.lat)))

Sum_TOA_NH_exp=TOA_flux_exp_minus_control_00+TOA_flux_exp_minus_control_05_n+TOA_flux_exp_minus_control_10_n+\
                TOA_flux_exp_minus_control_15_n+TOA_flux_exp_minus_control_20_n+TOA_flux_exp_minus_control_25_n+\
                TOA_flux_exp_minus_control_30_n+TOA_flux_exp_minus_control_35_n+TOA_flux_exp_minus_control_40_n+\
                TOA_flux_exp_minus_control_45_n+TOA_flux_exp_minus_control_50_n+TOA_flux_exp_minus_control_55_n+\
                TOA_flux_exp_minus_control_60_n+TOA_flux_exp_minus_control_65_n+TOA_flux_exp_minus_control_70_n+\
                TOA_flux_exp_minus_control_75_n+TOA_flux_exp_minus_control_80_n+TOA_flux_exp_minus_control_85_n+\
                TOA_flux_exp_minus_control_pole_n

Sum_TOA_SH_exp=TOA_flux_exp_minus_control_05_s+TOA_flux_exp_minus_control_10_s+TOA_flux_exp_minus_control_15_s+\
                    TOA_flux_exp_minus_control_20_s+TOA_flux_exp_minus_control_25_s+TOA_flux_exp_minus_control_30_s+\
                    TOA_flux_exp_minus_control_35_s+TOA_flux_exp_minus_control_40_s+TOA_flux_exp_minus_control_45_s+\
                    TOA_flux_exp_minus_control_50_s+TOA_flux_exp_minus_control_55_s+TOA_flux_exp_minus_control_60_s+\
                    TOA_flux_exp_minus_control_65_s+TOA_flux_exp_minus_control_70_s+TOA_flux_exp_minus_control_75_s+\
                    TOA_flux_exp_minus_control_80_s+TOA_flux_exp_minus_control_85_s+TOA_flux_exp_minus_control_pole_s
Sum_TOA_ns=Sum_TOA_NH_exp+Sum_TOA_SH_exp
TOA_flux_exp_minus_control_4k = (data_4k.FSNT.mean('lon')-data_4k.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

pp_total_ns=np.array(Sum_TOA_ns)
exp_total_ns=np.linspace(0,1,96)
plat_total_ns=np.array(Sum_TOA_ns.lat)
expp_total_ns, ppp_total_ns=np.meshgrid(exp_total_ns, pp_total_ns)

pp_4k=np.array(TOA_flux_exp_minus_control_4k)
exp_4k=np.linspace(0,1,96)
plat_4k=np.array(TOA_flux_exp_minus_control_4k.lat)
expp_4k, ppp_4k=np.meshgrid(exp_4k, pp_4k)

# %%
TOA_flux_exp_minus_control_10_n = (data_10_n.FSNT.mean('lon')-data_10_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_10_s = (data_10_s.FSNT.mean('lon')-data_10_s.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_10 =(data_10.FSNT.mean('lon')-data_10.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))


TOA_flux_exp_minus_control_10_ns=TOA_flux_exp_minus_control_10_n+TOA_flux_exp_minus_control_10_s

pp_10_ns=np.array(TOA_flux_exp_minus_control_10_ns)
#zp= pp.transpose()
exp_10_ns=np.linspace(0,1,96)
plat_10_ns=np.array(TOA_flux_exp_minus_control_10_ns.lat)
expp_10_ns, ppp_10_ns=np.meshgrid(exp_10_ns, pp_10_ns)

pp_10=np.array(TOA_flux_exp_minus_control_10)
#zp= pp.transpose()
exp_10=np.linspace(0,1,96)
plat_10=np.array(TOA_flux_exp_minus_control_10.lat)
expp_10, ppp_10=np.meshgrid(exp_10, pp_10)

# %%
TOA_flux_exp_minus_control_05_n = (data_05_n.FSNT.mean('lon')-data_05_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_05_s = (data_05_s.FSNT.mean('lon')-data_05_s.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_05 =(data_05.FSNT.mean('lon')-data_05.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))


TOA_flux_exp_minus_control_05_ns=TOA_flux_exp_minus_control_05_n+TOA_flux_exp_minus_control_05_s

pp_05_ns=np.array(TOA_flux_exp_minus_control_05_ns)
#zp= pp.transpose()
exp_05_ns=np.linspace(0,1,96)
plat_05_ns=np.array(TOA_flux_exp_minus_control_05_ns.lat)
expp_05_ns, ppp_05_ns=np.meshgrid(exp_05_ns, pp_05_ns)

pp_05=np.array(TOA_flux_exp_minus_control_05)
#zp= pp.transpose()
exp_05=np.linspace(0,1,96)
plat_05=np.array(TOA_flux_exp_minus_control_05.lat)
expp_05, ppp_05=np.meshgrid(exp_05, pp_05)

# %%
#15 deg linearity test
TOA_flux_exp_minus_control_15_s = (data_15_s.FSNT.mean('lon')-data_15_s.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_15 =(data_15.FSNT.mean('lon')-data_15.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))


TOA_flux_exp_minus_control_15_ns=TOA_flux_exp_minus_control_15_n+TOA_flux_exp_minus_control_15_s

pp_15_ns=np.array(TOA_flux_exp_minus_control_15_ns)
#zp= pp.transpose()
exp_15_ns=np.linspace(0,1,96)
plat_15_ns=np.array(TOA_flux_exp_minus_control_15_ns.lat)
expp_15_ns, ppp_15_ns=np.meshgrid(exp_15_ns, pp_15_ns)

pp_15=np.array(TOA_flux_exp_minus_control_15)
#zp= pp.transpose()
exp_15=np.linspace(0,1,96)
plat_15=np.array(TOA_flux_exp_minus_control_15.lat)
expp_15, ppp_15=np.meshgrid(exp_15, pp_15)

# %%
wTOA_flux_exp_minus_control_50_n = (wdata_50_n.FSNT.mean('lon')-wdata_50_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
wTOA_flux_exp_minus_control_50_s = (wdata_50_s.FSNT.mean('lon')-wdata_50_s.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
wTOA_flux_exp_minus_control_50 =(wdata_50.FSNT.mean('lon')-wdata_50.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))


wTOA_flux_exp_minus_control_50_ns=wTOA_flux_exp_minus_control_50_n+wTOA_flux_exp_minus_control_50_s

wpp_50_ns=np.array(wTOA_flux_exp_minus_control_50_ns)
#zp= pp.transpose()
wexp_50_ns=np.linspace(0,1,96)
wplat_50_ns=np.array(wTOA_flux_exp_minus_control_50_ns.lat)
wexpp_50_ns, wppp_50_ns=np.meshgrid(wexp_50_ns, wpp_50_ns)

wpp_50=np.array(wTOA_flux_exp_minus_control_50)
#zp= pp.transpose()
wexp_50=np.linspace(0,1,96)
wplat_50=np.array(wTOA_flux_exp_minus_control_50.lat)
wexpp_50, wppp_50=np.meshgrid(wexp_50, wpp_50)

# %%
wTOA_flux_exp_minus_control_00 = (wdata_00.FSNT.mean('lon')-wdata_00.FLNT.mean('lon'))-\
                                (data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

wTOA_flux_exp_minus_control_25_n = (wdata_25_n.FSNT.mean('lon')-wdata_25_n.FLNT.mean('lon'))-\
                                  (data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

wTOA_flux_exp_minus_control_50_n = (wdata_50_n.FSNT.mean('lon')-wdata_50_n.FLNT.mean('lon'))-\
                                  (data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

wTOA_flux_exp_minus_control_75_n = (wdata_75_n.FSNT.mean('lon')-wdata_75_n.FLNT.mean('lon'))-\
                                  (data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

wTOA_flux_exp_minus_control_100_n = (wdata_100_n.FSNT.mean('lon')-wdata_100_n.FLNT.mean('lon'))-\
                                  (data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

wTOA_flux_exp_minus_control_125_n = (wdata_125_n.FSNT.mean('lon')-wdata_125_n.FLNT.mean('lon'))-\
                                  (data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

wTOA_flux_exp_minus_control_25_s=wTOA_flux_exp_minus_control_25_n.assign_coords(lat=list(reversed(wdata_25_n.lat)))

wTOA_flux_exp_minus_control_50_s=wTOA_flux_exp_minus_control_50_n.assign_coords(lat=list(reversed(wdata_50_n.lat)))

wTOA_flux_exp_minus_control_75_s=wTOA_flux_exp_minus_control_75_n.assign_coords(lat=list(reversed(wdata_75_n.lat)))

wTOA_flux_exp_minus_control_100_s=wTOA_flux_exp_minus_control_100_n.assign_coords(lat=list(reversed(wdata_100_n.lat)))

wTOA_flux_exp_minus_control_125_s=wTOA_flux_exp_minus_control_125_n.assign_coords(lat=list(reversed(wdata_125_n.lat)))

Sum_TOA_wide= wTOA_flux_exp_minus_control_00+wTOA_flux_exp_minus_control_25_n+wTOA_flux_exp_minus_control_50_n+\
         wTOA_flux_exp_minus_control_75_n+wTOA_flux_exp_minus_control_100_n+wTOA_flux_exp_minus_control_125_n+\
         wTOA_flux_exp_minus_control_25_s+wTOA_flux_exp_minus_control_50_s+wTOA_flux_exp_minus_control_75_s+\
         wTOA_flux_exp_minus_control_100_s+wTOA_flux_exp_minus_control_125_s

TOA_flux_exp_minus_control_Exp_4k = (data_4k.FSNT.mean('lon')-data_4k.FLNT.mean('lon'))-\
                                                    (data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

pp_total_wide=np.array(Sum_TOA_wide)
exp_total_wide=np.linspace(0,1,96)
plat_total_wide=np.array(Sum_TOA_wide.lat)
expp_total_wide, ppp_total_wide=np.meshgrid(exp_total_wide, pp_total_wide)

pp_Exp_4k=np.array(TOA_flux_exp_minus_control_Exp_4k)
exp_Exp_4k=np.linspace(0,1,96)
plat_Exp_4k=np.array(TOA_flux_exp_minus_control_Exp_4k.lat)
expp_Exp_4k, ppp_Exp_4k=np.meshgrid(exp_Exp_4k, pp_Exp_4k)

# %%
nrow = 1
ncol = 3
fig = plt.figure(figsize=(4, 8))
grid = ImageGrid(fig, 
                 111, # as in plt.subplot(111)
                 nrows_ncols=(nrow,ncol),
                 axes_pad=0,
                 share_all=True,)

#for i in range(1):
#    for j in range(2):
im = np.random.rand(28,28)
gs = gridspec.GridSpec(9, 2)
gs.update(wspace=0,hspace=0.05)
vmax=40
vmin=-40
plt.subplot(gs[0,0])
plt.pcolormesh(expp_total_5,plat_total_5,ppp_total_5,cmap='seismic',vmax=vmax,vmin=vmin)
plt.yticks(np.arange(-60, 91, 30))
plt.ylabel("Latitude")
plt.xticks([])
#plt.xlabel("Sum of 5 EXP")
plt.text(0.3, 60, 'Sum_5Exp ', fontsize = 7, color='green',fontweight="bold")

plt.subplot(gs[0,1])
plt.pcolormesh(expp_Exp_10s_5s_00_5n_10n,plat_Exp_10s_5s_00_5n_10n,ppp_Exp_10s_5s_00_5n_10n,cmap='seismic',vmax=vmax,vmin=vmin)
plt.xticks([])
#plt.xlabel("Exp_10s_5s_00_5n_10n")
plt.text(0.1, 60, '10s_5s_00_5n_10n ', fontsize = 7, color='green',fontweight="bold")

ax = pylab.gca()
ax.yaxis.set_visible(False)


plt.subplot(gs[1,0])
plt.pcolormesh(expp_total_3,plat_total_3,ppp_total_3,cmap='seismic',vmax=vmax,vmin=vmin)
plt.yticks(np.arange(-60, 91, 30))
plt.ylabel("Latitude")
plt.xticks([])
#plt.xlabel("Sum of 3 EXP")
plt.text(0.3, 60, 'Sum_3Exp ', fontsize = 7, color='green',fontweight="bold")


plt.subplot(gs[1,1])
plt.pcolormesh(expp_Exp_5s_00_5n,plat_Exp_5s_00_5n,ppp_Exp_5s_00_5n,cmap='seismic',vmax=vmax,vmin=vmin)
plt.xticks([])
#plt.xlabel("Exp_5s_00_5n")
plt.text(0.2, 60, '5s_00_5n ', fontsize = 7, color='green',fontweight="bold")

ax = pylab.gca()
ax.yaxis.set_visible(False)

plt.subplot(gs[2,0])
plt.pcolormesh(expp_total_ns,plat_total_ns,ppp_total_ns,cmap='seismic',vmax=vmax,vmin=vmin)
plt.yticks(np.arange(-60, 91, 30))
plt.ylabel("Latitude")
plt.xticks([])
#plt.xlabel("Sum of all EXP")
plt.text(0.3, 60, 'Sum ', fontsize = 7, color='green',fontweight="bold")

plt.subplot(gs[2,1])
plt.pcolormesh(expp_4k,plat_4k,ppp_4k,cmap='seismic',vmax=vmax,vmin=vmin)
plt.xticks([])
#plt.xlabel("+4K All Over")
plt.text(0.3, 60, '+4K ', fontsize = 7, color='green',fontweight="bold")

ax = pylab.gca()
ax.yaxis.set_visible(False) 

plt.subplot(gs[3,0])
plt.pcolormesh(expp_total_19,plat_total_19,ppp_total_19,cmap='seismic',vmax=vmax,vmin=vmin)
plt.yticks(np.arange(-60, 91, 30))
plt.ylabel("Latitude")
plt.xticks([])
#plt.xlabel("Sum of all NH EXP")
plt.text(0.3, 60, 'Sum_NH ', fontsize = 7, color='green',fontweight="bold")

plt.subplot(gs[3,1])
plt.pcolormesh(expp_4k_n,plat_4k_n,ppp_4k_n,cmap='seismic',vmax=vmax,vmin=vmin)
plt.xticks([])
#plt.xlabel("+4K NH EXP")
plt.text(0.3, 60, '+4K_NH ', fontsize = 7, color='green',fontweight="bold")

ax = pylab.gca()
ax.yaxis.set_visible(False)



plt.subplot(gs[4,0])
plt.pcolormesh(expp_total_wide,plat_total_wide,ppp_total_wide,cmap='seismic',vmax=vmax,vmin=vmin)
plt.yticks(np.arange(-60, 91, 30))
plt.ylabel("Latitude")
plt.xticks([])
#plt.xlabel("50")
plt.text(0.3, 60, 'Sum_Wide ', fontsize = 7, color='green',fontweight="bold")


plt.subplot(gs[4,1])
plt.pcolormesh(expp_Exp_4k,plat_Exp_4k,ppp_Exp_4k,cmap='seismic',vmax=vmax,vmin=vmin)
plt.xticks([])
plt.text(0.3, 60, '+4K ', fontsize = 7, color='green',fontweight="bold")
#plt.xlabel("50_ns")
ax = pylab.gca()
ax.yaxis.set_visible(False)





plt.subplot(gs[5,0])
plt.pcolormesh(expp_05,plat_05,ppp_05,cmap='seismic',vmax=vmax, vmin=vmin)
plt.yticks(np.arange(-60, 91, 30))
plt.ylabel("Latitude")
plt.xticks([])
#plt.xlabel("5")
plt.text(0.3, 60, '5 ', fontsize = 7, color='green',fontweight="bold")

plt.subplot(gs[5,1])
plt.pcolormesh(expp_05_ns,plat_05_ns,ppp_05_ns,cmap='seismic',vmax=vmax, vmin=vmin)
plt.xticks([])
#plt.xlabel("5_ns")
plt.text(0.3, 60, '5_ns ', fontsize = 7, color='green',fontweight="bold")

ax = pylab.gca()
ax.yaxis.set_visible(False)

plt.subplot(gs[6,0])
plt.pcolormesh(expp_10,plat_10,ppp_10,cmap='seismic',vmax=vmax, vmin=vmin)
plt.yticks(np.arange(-60, 91, 30))
plt.ylabel("Latitude")
plt.xticks([])
#plt.xlabel("10")
plt.text(0.3, 60, '10 ', fontsize = 7, color='green',fontweight="bold")

plt.subplot(gs[6,1])
plt.pcolormesh(expp_10_ns,plat_10_ns,ppp_10_ns,cmap='seismic',vmax=vmax, vmin=vmin)
plt.xticks([])
plt.text(0.3, 60, '10_ns ', fontsize = 7, color='green',fontweight="bold")

#plt.xlabel("10_ns")
ax = pylab.gca()
ax.yaxis.set_visible(False)

plt.subplot(gs[7,0])
plt.pcolormesh(expp_15,plat_15,ppp_15,cmap='RdBu_r',vmax=vmax, vmin=vmin)
plt.yticks(np.arange(-60, 91, 30))
plt.ylabel("Latitude")
plt.xticks([])
#plt.xlabel("15")
plt.text(0.3, 60, '15 ', fontsize = 7, color='green',fontweight="bold")

plt.subplot(gs[7,1])
plt.pcolormesh(expp_15_ns,plat_15_ns,ppp_15_ns,cmap='RdBu_r',vmax=vmax, vmin=vmin)
plt.xticks([])
#plt.xlabel("15_ns")
plt.text(0.3, 60, '15_ns ', fontsize = 7, color='green',fontweight="bold")

ax = pylab.gca()
ax.yaxis.set_visible(False)

plt.subplot(gs[8,0])
plt.pcolormesh(wexpp_50,wplat_50,wppp_50,cmap='seismic',vmax=vmax, vmin=vmin)
plt.yticks(np.arange(-90, 91, 30))
plt.ylabel("Latitude")
plt.xticks([])
#plt.xlabel("50")
plt.text(0.3, 60, '50_wide ', fontsize = 7, color='green',fontweight="bold")


plt.subplot(gs[8,1])
plt.pcolormesh(wexpp_50_ns,wplat_50_ns,wppp_50_ns,cmap='seismic',vmax=vmax, vmin=vmin)
plt.xticks([])
plt.text(0.3, 60, '50_ns_Wide ', fontsize = 7, color='green',fontweight="bold")
#plt.xlabel("50_ns")
ax = pylab.gca()
ax.yaxis.set_visible(False)


#plt.colorbar(shrink=1)
#plt.subplot(gs[8,:])
a = np.array([[-40,40]])
pl.figure(figsize=(5, 0.15))
img = pl.imshow(a, cmap="seismic")
pl.gca().set_visible(False)
cax = pl.axes([0.1, 0.8, 0.8, 0.6])
pl.colorbar(orientation="horizontal", cax=cax,label='TOA')
plt.show()

# %%
nrow = 1
ncol = 3
fig = plt.figure(figsize=(5, 5))
grid = ImageGrid(fig, 
                 111, # as in plt.subplot(111)
                 nrows_ncols=(nrow,ncol),
                 axes_pad=0,
                 share_all=True,)

#for i in range(1):
#    for j in range(2):
im = np.random.rand(28,28)
gs = gridspec.GridSpec(2, 2)
gs.update(wspace=0)
vmax=40
vmin=-40
plt.subplot(gs[0,0])
plt.pcolormesh(expp_total_5,plat_total_5,ppp_total_5,cmap='seismic',vmax=vmax,vmin=vmin)
plt.yticks(np.arange(-90, 91, 30))
plt.ylabel("Latitude")
plt.xticks([])
plt.xlabel("Sum of 5 EXP")

plt.subplot(gs[0,1])
plt.pcolormesh(expp_Exp_10s_5s_00_5n_10n,plat_Exp_10s_5s_00_5n_10n,ppp_Exp_10s_5s_00_5n_10n,cmap='seismic',vmax=vmax,vmin=vmin)
plt.xticks([])
plt.xlabel("Exp_10s_5s_00_5n_10n")
ax = pylab.gca()
ax.yaxis.set_visible(False)

plt.colorbar(shrink=1)
plt.show()

# %%
nrow = 1
ncol = 3
fig = plt.figure(figsize=(5, 5))
grid = ImageGrid(fig, 
                 111, # as in plt.subplot(111)
                 nrows_ncols=(nrow,ncol),
                 axes_pad=0,
                 share_all=True,)

#for i in range(1):
#    for j in range(2):
im = np.random.rand(28,28)
gs = gridspec.GridSpec(2, 2)
gs.update(wspace=0)
vmax=30
vmin=-30
plt.subplot(gs[0,0])
plt.pcolormesh(expp_total_3,plat_total_3,ppp_total_3,cmap='seismic',vmax=vmax,vmin=vmin)
plt.yticks(np.arange(-90, 91, 30))
plt.ylabel("Latitude")
plt.xticks([])
plt.xlabel("Sum of 3 EXP")

plt.subplot(gs[0,1])
plt.pcolormesh(expp_Exp_5s_00_5n,plat_Exp_5s_00_5n,ppp_Exp_5s_00_5n,cmap='seismic',vmax=vmax,vmin=vmin)
plt.xticks([])
plt.xlabel("Exp_5s_00_5n")
ax = pylab.gca()
ax.yaxis.set_visible(False)

plt.colorbar(shrink=1)
plt.show()

# %%
nrow = 1
ncol = 3
fig = plt.figure(figsize=(5, 5))
grid = ImageGrid(fig, 
                 111, # as in plt.subplot(111)
                 nrows_ncols=(nrow,ncol),
                 axes_pad=0,
                 share_all=True,)

#for i in range(1):
#    for j in range(2):
im = np.random.rand(28,28)
gs = gridspec.GridSpec(3, 3)
gs.update(wspace=0)
vmax=50
vmin=-50
plt.subplot(gs[0,0])
plt.pcolormesh(expp_total_ns,plat_total_ns,ppp_total_ns,cmap='seismic',vmax=vmax,vmin=vmin)
plt.yticks(np.arange(-90, 91, 30))
plt.ylabel("Latitude")
plt.xticks([])
plt.xlabel("Sum of all EXP")

plt.subplot(gs[0,1])
plt.pcolormesh(expp_4k,plat_4k,ppp_4k,cmap='seismic',vmax=vmax,vmin=vmin)
plt.xticks([])
plt.xlabel("+4K All Over")
ax = pylab.gca()
ax.yaxis.set_visible(False) 
#plt.colorbar(shrink=1, location="bottom")

plt.subplots_adjust(bottom=0.1, right=0.8, top=0.9)
cax = plt.axes([0.59, 0.685, 0.0095, 0.2])
plt.colorbar(cax=cax)
plt.show()

# %%
nrow = 1
ncol = 3
fig = plt.figure(figsize=(5, 5))
grid = ImageGrid(fig, 
                 111, # as in plt.subplot(111)
                 nrows_ncols=(nrow,ncol),
                 axes_pad=0,
                 share_all=True,)

#for i in range(1):
#    for j in range(2):
im = np.random.rand(28,28)
gs = gridspec.GridSpec(2, 2)
gs.update(wspace=0)
vmax=50
vmin=-50
plt.subplot(gs[0,0])
plt.pcolormesh(expp_total_19,plat_total_19,ppp_total_19,cmap='seismic',vmax=vmax,vmin=vmin)
plt.yticks(np.arange(-90, 91, 30))
plt.ylabel("Latitude")
plt.xticks([])
plt.xlabel("Sum of all NH EXP")

plt.subplot(gs[0,1])
plt.pcolormesh(expp_4k_n,plat_4k_n,ppp_4k_n,cmap='seismic',vmax=vmax,vmin=vmin)
plt.xticks([])
plt.xlabel("+4K NH EXP")
ax = pylab.gca()
ax.yaxis.set_visible(False)

plt.colorbar(shrink=1)
plt.show()

# %%
nrow = 1
ncol = 3
fig = plt.figure(figsize=(15, 15))
grid = ImageGrid(fig, 
                 111, # as in plt.subplot(111)
                 nrows_ncols=(nrow,ncol),
                 axes_pad=0,
                 share_all=True,)

#for i in range(1):
#    for j in range(2):
im = np.random.rand(28,28)
gs = gridspec.GridSpec(3, 3)
gs.update(wspace=0)
vmax=30
vmin=-30
plt.subplot(gs[0,0])
plt.pcolormesh(expp_05,plat_05,ppp_05,cmap='seismic',vmax=vmax, vmin=vmin)
plt.yticks(np.arange(-90, 91, 30))
plt.ylabel("Latitude")
plt.xticks([])
plt.xlabel("5")

plt.subplot(gs[0,1])
plt.pcolormesh(expp_05_ns,plat_05_ns,ppp_05_ns,cmap='seismic',vmax=vmax, vmin=vmin)
plt.xticks([])
plt.xlabel("5_ns")
ax = pylab.gca()
ax.yaxis.set_visible(False)



# Get the current axis
ax = pylab.gca()
# Set Y-axis visibility to False
ax.yaxis.set_visible(False)

#        plt.set_yticklabels([])

#plt.tight_layout() # do not use this!!
#plt.subplot(gs[0,8])
plt.colorbar(shrink=1)
plt.show()

# %%
nrow = 1
ncol = 3
fig = plt.figure(figsize=(15, 15))
grid = ImageGrid(fig, 
                 111, # as in plt.subplot(111)
                 nrows_ncols=(nrow,ncol),
                 axes_pad=0,
                 share_all=True,)

#for i in range(1):
#    for j in range(2):
im = np.random.rand(28,28)
gs = gridspec.GridSpec(3, 3)
gs.update(wspace=0)
vmax=30
vmin=-30
plt.subplot(gs[0,0])
plt.pcolormesh(expp_10,plat_10,ppp_10,cmap='seismic',vmax=vmax, vmin=vmin)
plt.yticks(np.arange(-90, 91, 30))
plt.ylabel("Latitude")
plt.xticks([])
plt.xlabel("10")

plt.subplot(gs[0,1])
plt.pcolormesh(expp_10_ns,plat_10_ns,ppp_10_ns,cmap='seismic',vmax=vmax, vmin=vmin)
plt.xticks([])
plt.xlabel("10_ns")
ax = pylab.gca()
ax.yaxis.set_visible(False)



# Get the current axis
ax = pylab.gca()
# Set Y-axis visibility to False
ax.yaxis.set_visible(False)

#        plt.set_yticklabels([])

#plt.tight_layout() # do not use this!!
#plt.subplot(gs[0,8])
plt.colorbar(shrink=1)
plt.show()

# %%
nrow = 1
ncol = 3
fig = plt.figure(figsize=(15, 15))
grid = ImageGrid(fig, 
                 111, # as in plt.subplot(111)
                 nrows_ncols=(nrow,ncol),
                 axes_pad=0,
                 share_all=True,)

#for i in range(1):
#    for j in range(2):
im = np.random.rand(28,28)
gs = gridspec.GridSpec(3, 3)
gs.update(wspace=0)
vmax=20
vmin=-20
plt.subplot(gs[0,0])
plt.pcolormesh(expp_15,plat_15,ppp_15,cmap='RdBu_r',vmax=vmax, vmin=vmin)
plt.yticks(np.arange(-90, 91, 30))
plt.ylabel("Latitude")
plt.xticks([])
plt.xlabel("15")

plt.subplot(gs[0,1])
plt.pcolormesh(expp_15_ns,plat_15_ns,ppp_15_ns,cmap='RdBu_r',vmax=vmax, vmin=vmin)
plt.xticks([])
plt.xlabel("15_ns")
ax = pylab.gca()
ax.yaxis.set_visible(False)



# Get the current axis
ax = pylab.gca()
# Set Y-axis visibility to False
ax.yaxis.set_visible(False)

#        plt.set_yticklabels([])

#plt.tight_layout() # do not use this!!
#plt.subplot(gs[0,8])
plt.colorbar(shrink=1)
plt.show()

# %%
nrow = 1
ncol = 3
fig = plt.figure(figsize=(15, 15))
grid = ImageGrid(fig, 
                 111, # as in plt.subplot(111)
                 nrows_ncols=(nrow,ncol),
                 axes_pad=0,
                 share_all=True,)

#for i in range(1):
#    for j in range(2):
im = np.random.rand(28,28)
gs = gridspec.GridSpec(3, 3)
gs.update(wspace=0)
vmax=15
vmin=-15
plt.subplot(gs[0,0])
plt.pcolormesh(wexpp_50,wplat_50,wppp_50,cmap='seismic',vmax=vmax, vmin=vmin)
plt.yticks(np.arange(-90, 91, 30))
plt.ylabel("Latitude")
plt.xticks([])
plt.xlabel("50")

plt.subplot(gs[0,1])
plt.pcolormesh(wexpp_50_ns,wplat_50_ns,wppp_50_ns,cmap='seismic',vmax=vmax, vmin=vmin)
plt.xticks([])
plt.xlabel("50_ns")
ax = pylab.gca()
ax.yaxis.set_visible(False)



# Get the current axis
ax = pylab.gca()
# Set Y-axis visibility to False
ax.yaxis.set_visible(False)

#        plt.set_yticklabels([])

#plt.tight_layout() # do not use this!!
#plt.subplot(gs[0,8])
plt.colorbar(shrink=1)
plt.show()

# %% [markdown]
# # TOA ZONAL LINE PLOT

# %%
TOA_00 = (data_00.FSNT.mean('lon')-data_00.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_05_n = (data_05_n.FSNT.mean('lon')-data_05_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_05_s=TOA_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))
TOA_10_n = (data_10_n.FSNT.mean('lon')-data_10_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_10_s=TOA_10_n.assign_coords(lat=list(reversed(data_10_n.lat)))

Sum_TOA_zonal_5=TOA_00+TOA_05_n+TOA_05_s+TOA_10_n+TOA_10_s

TOA_Exp_10s_5s_00_5n_10n=(data_10s_05s_00_05n_10n.FSNT.mean('lon')-data_10s_05s_00_05n_10n.FLNT.mean('lon'))-\
                 (data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

# %%
TOA_00 = (data_00.FSNT.mean('lon')-data_00.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_05_n = (data_05_n.FSNT.mean('lon')-data_05_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_05_s=TOA_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))

Sum_TOA_zonal_3=TOA_00+TOA_05_n+TOA_05_s

TOA_Exp_5s_00_5n=(data_05s_00_05n.FSNT.mean('lon')-data_05s_00_05n.FLNT.mean('lon'))-\
                 (data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

# %%
#TOA 4k_N
TOA_00 = (data_00.FSNT.mean('lon')-data_00.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_05_n = (data_05_n.FSNT.mean('lon')-data_05_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_10_n = (data_10_n.FSNT.mean('lon')-data_10_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_15_n = (data_15_n.FSNT.mean('lon')-data_15_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_20_n = (data_20_n.FSNT.mean('lon')-data_20_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_25_n = (data_25_n.FSNT.mean('lon')-data_25_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_30_n = (data_30_n.FSNT.mean('lon')-data_30_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_35_n = (data_35_n.FSNT.mean('lon')-data_35_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_40_n = (data_40_n.FSNT.mean('lon')-data_40_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_45_n = (data_45_n.FSNT.mean('lon')-data_45_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_50_n = (data_50_n.FSNT.mean('lon')-data_50_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_55_n = (data_55_n.FSNT.mean('lon')-data_55_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_60_n = (data_60_n.FSNT.mean('lon')-data_60_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_65_n = (data_65_n.FSNT.mean('lon')-data_65_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_70_n = (data_70_n.FSNT.mean('lon')-data_70_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_75_n = (data_75_n.FSNT.mean('lon')-data_75_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_80_n = (data_80_n.FSNT.mean('lon')-data_80_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_85_n = (data_85_n.FSNT.mean('lon')-data_85_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_pole_n = (data_pole_n.FSNT.mean('lon')-data_pole_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))


#TOA_4k_n=(data_4k_n_smooth.FSNT.mean('lon')-data_4k_n_smooth.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

TOA_4k_n=(data_4k_n.FSNT.mean('lon')-data_4k_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
Sum_TOA_19=TOA_00+TOA_05_n+TOA_10_n+TOA_15_n+TOA_20_n+TOA_25_n+TOA_30_n+TOA_35_n+TOA_40_n+TOA_45_n+TOA_50_n+TOA_55_n+TOA_60_n+TOA_65_n+TOA_70_n+TOA_75_n+TOA_80_n+TOA_85_n+TOA_pole_n

# %%
TOA_05_s=TOA_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))
TOA_10_s=TOA_10_n.assign_coords(lat=list(reversed(data_10_n.lat)))
TOA_15_s=TOA_15_n.assign_coords(lat=list(reversed(data_15_n.lat)))
TOA_20_s=TOA_20_n.assign_coords(lat=list(reversed(data_20_n.lat)))
TOA_25_s=TOA_25_n.assign_coords(lat=list(reversed(data_25_n.lat)))
TOA_30_s=TOA_30_n.assign_coords(lat=list(reversed(data_30_n.lat)))
TOA_35_s=TOA_35_n.assign_coords(lat=list(reversed(data_35_n.lat)))
TOA_40_s=TOA_40_n.assign_coords(lat=list(reversed(data_40_n.lat)))
TOA_45_s=TOA_45_n.assign_coords(lat=list(reversed(data_45_n.lat)))
TOA_50_s=TOA_50_n.assign_coords(lat=list(reversed(data_50_n.lat)))
TOA_55_s=TOA_55_n.assign_coords(lat=list(reversed(data_55_n.lat)))
TOA_60_s=TOA_60_n.assign_coords(lat=list(reversed(data_60_n.lat)))
TOA_65_s=TOA_65_n.assign_coords(lat=list(reversed(data_65_n.lat)))
TOA_70_s=TOA_70_n.assign_coords(lat=list(reversed(data_70_n.lat)))
TOA_75_s=TOA_75_n.assign_coords(lat=list(reversed(data_75_n.lat)))
TOA_80_s=TOA_80_n.assign_coords(lat=list(reversed(data_80_n.lat)))
TOA_85_s=TOA_85_n.assign_coords(lat=list(reversed(data_85_n.lat)))
TOA_pole_s=TOA_pole_n.assign_coords(lat=list(reversed(data_pole_n.lat)))


TOA_4k=(data_4k.FSNT.mean('lon')-data_4k.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
Sum_TOA_NH_Exp=TOA_00+TOA_05_n+TOA_10_n+TOA_15_n+TOA_20_n+TOA_25_n+TOA_30_n+TOA_35_n+TOA_40_n+TOA_45_n+TOA_50_n+TOA_55_n+\
                TOA_60_n+TOA_65_n+TOA_70_n+TOA_75_n+TOA_80_n+TOA_85_n+TOA_pole_n

Sum_TOA_SH_Exp=TOA_05_s+TOA_10_s+TOA_15_s+TOA_20_s+TOA_25_s+TOA_30_s+TOA_35_s+TOA_40_s+TOA_45_s+TOA_50_s+TOA_55_s+TOA_60_s+\
                TOA_65_s+TOA_70_s+TOA_75_s+TOA_80_s+TOA_85_s+TOA_pole_s

Sum_TOA_ns=Sum_TOA_NH_Exp+Sum_TOA_SH_Exp

# %%
TOA_05_n = (data_05_n.FSNT.mean('lon')-data_05_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_05_s = (data_05_s.FSNT.mean('lon')-data_05_s.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

TOA_05_ns=TOA_05_n+TOA_05_s
TOA_05 = (data_05.FSNT.mean('lon')-data_05.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

# %%
TOA_10_n = (data_10_n.FSNT.mean('lon')-data_10_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_10_s = (data_10_s.FSNT.mean('lon')-data_10_s.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

TOA_10_ns=TOA_10_n+TOA_10_s
TOA_10 = (data_10.FSNT.mean('lon')-data_10.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

# %%
TOA_15_n = (data_15_n.FSNT.mean('lon')-data_15_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_15_s = (data_15_s.FSNT.mean('lon')-data_15_s.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

TOA_15_ns=TOA_15_n+TOA_15_s
TOA_15 = (data_15.FSNT.mean('lon')-data_15.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

# %%
wTOA_50_n = (wdata_50_n.FSNT.mean('lon')-wdata_50_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
wTOA_50_s = (wdata_50_s.FSNT.mean('lon')-wdata_50_s.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

wTOA_50_ns=wTOA_50_n+wTOA_50_s
wTOA_50 = (wdata_50.FSNT.mean('lon')-wdata_50.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

# %%
wTOA_00 = (wdata_00.FSNT.mean('lon')-wdata_00.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
wTOA_25_n = (wdata_25_n.FSNT.mean('lon')-wdata_25_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
wTOA_25_s=wTOA_25_n.assign_coords(lat=list(reversed(wdata_25_n.lat)))
wTOA_50_n = (data_50_n.FSNT.mean('lon')-wdata_50_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
wTOA_50_s=wTOA_50_n.assign_coords(lat=list(reversed(wdata_50_n.lat)))
wTOA_75_n = (wdata_75_n.FSNT.mean('lon')-wdata_75_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
wTOA_75_s=wTOA_75_n.assign_coords(lat=list(reversed(wdata_75_n.lat)))
wTOA_100_n = (wdata_100_n.FSNT.mean('lon')-wdata_100_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
wTOA_100_s=wTOA_100_n.assign_coords(lat=list(reversed(wdata_100_n.lat)))
wTOA_125_n = (wdata_125_n.FSNT.mean('lon')-wdata_125_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
wTOA_125_s=wTOA_125_n.assign_coords(lat=list(reversed(wdata_125_n.lat)))


Sum_TOA_zonal_wide=wTOA_00+wTOA_25_n+wTOA_25_s+wTOA_50_n+wTOA_50_s+wTOA_75_n+wTOA_75_s+wTOA_100_n+wTOA_100_s+wTOA_125_n+wTOA_125_s


TOA_Exp_4k=(data_4k.FSNT.mean('lon')-data_4k.FLNT.mean('lon'))-\
                 (data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

# %%
nrow = 1
ncol = 3
fig = plt.figure(figsize=(15, 3))
grid = ImageGrid(fig, 
                 111, # as in plt.subplot(111)
                 nrows_ncols=(nrow,ncol),
                 axes_pad=0,
                 share_all=True,)

#for i in range(1):
#    for j in range(2):
im = np.random.rand(28,28)
gs = gridspec.GridSpec(1, 9)
gs.update(wspace=0,hspace=0.1)

plt.subplot(gs[0,0])
Sum_TOA_zonal_5.plot(label='Sum_5Exp')
TOA_Exp_10s_5s_00_5n_10n.plot(label='10s_5s_00_5n_10n')
plt.legend(loc='lower center',borderpad=0.1,fontsize="6")
#plt.title('TOA flux')
plt.xlabel('')
plt.ylabel('TOA/W/m2')
plt.ylim(-60,20)

plt.subplot(gs[0,1])
Sum_TOA_zonal_3.plot(label='Sum_3Exp')
TOA_Exp_5s_00_5n.plot(label='5s_00_5n')
plt.legend(loc='lower center',borderpad=0.1,fontsize="6")
#plt.title('TOA flux')
plt.ylabel('TOA/W/m2')
ax = pylab.gca()
ax.yaxis.set_visible(False)
plt.xlabel('')
plt.ylim(-60,20)

plt.subplot(gs[0,2])
Sum_TOA_19.plot(label='Sum')
TOA_4k_n.plot(label='+4k_NH')
plt.legend(loc='lower center',borderpad=0.1,fontsize="6")
#plt.title('TOA flux')
ax = pylab.gca()
ax.yaxis.set_visible(False)
plt.xlabel('')
plt.ylim(-60,20)


plt.subplot(gs[0,3])
Sum_TOA_ns.plot(label='Sum')
TOA_4k.plot(label='+4k')
plt.legend(loc='lower center',borderpad=0.1,fontsize="6")
plt.ylabel("TOA (W/m2)")
ax = pylab.gca()
ax.yaxis.set_visible(False)
plt.xlabel('')
plt.ylim(-60,20)

plt.subplot(gs[0,4])
Sum_TOA_zonal_wide.plot(label='Sum_Wide')
TOA_4k.plot(label='+4k')
plt.legend(loc='lower center',borderpad=0.1,fontsize="6")
plt.ylabel("TOA (W/m2)")
ax = pylab.gca()
ax.yaxis.set_visible(False)
plt.xlabel('')
plt.ylim(-60,20)

plt.subplot(gs[0,5])
TOA_05_ns.plot( label='5_ns patch')
TOA_05.plot( label='5 patch')
plt.legend(loc='lower center',borderpad=0.1,fontsize="6")
ax = pylab.gca()
ax.yaxis.set_visible(False)
plt.xlabel('')
plt.ylim(-60,20)

#plt.legend(loc='upper left')
#plt.title('TOA flux')
plt.subplot(gs[0,6])
TOA_10_ns.plot( label='10_ns patch')
TOA_10.plot( label='10 patch')
plt.legend(loc='lower center',borderpad=0.1,fontsize="6")
ax = pylab.gca()
ax.yaxis.set_visible(False)
plt.xlabel('')
plt.ylim(-60,20)

#plt.legend(loc='upper left')
#plt.title('TOA flux')
plt.subplot(gs[0,7])
TOA_15_ns.plot( label='15_ns patch')
TOA_15.plot( label='15 patch')
plt.legend(loc='lower center',borderpad=0.1,fontsize="6")
ax = pylab.gca()
ax.yaxis.set_visible(False)
plt.xlabel('')
plt.ylim(-60,20)

#plt.legend(loc='upper left')
#plt.title('TOA flux')
plt.subplot(gs[0,8])
wTOA_50_ns.plot( label='50_ns patch')
wTOA_50.plot( label='50 patch')
plt.legend(loc='lower center',borderpad=0.1,fontsize="6")
ax = pylab.gca()
ax.yaxis.set_visible(False)
plt.xlabel('')
plt.ylim(-60,20)

#plt.legend(loc='upper left')
#plt.title('TOA flux')
fig.text(0.5, -0.01, 'Latitude', ha='center')

plt.show()

# %%
Sum_TOA_zonal_5.plot(label='Sum of 5 Exp')
TOA_Exp_10s_5s_00_5n_10n.plot(label='10s_5s_00_5n_10n')
plt.legend(loc='upper right',fontsize="6")
plt.title('TOA flux')
plt.ylabel('TOA/W/m2')
# Out:
# Text(0, 0.5, 'TOA/W/m2')

# %%
Sum_TOA_zonal_3.plot(label='Sum of 3 Exp')
TOA_Exp_5s_00_5n.plot(label='5s_00_5n')
plt.legend(loc='upper right')
plt.title('TOA flux')
plt.ylabel('TOA/W/m2')
# Out:
# Text(0, 0.5, 'TOA/W/m2')

# %%
Sum_TOA_19.plot(label='Sum of all NH Exp')
TOA_4k_n.plot(label='+4k NH EXP')
plt.legend(loc='upper right')
plt.title('TOA flux')
# Out:
# Text(0.5, 1.0, 'TOA flux')

# %%
#Sum_TOA_ns.plot(label='Sum of all Exp')
TOA_Exp_4k.plot(label='+4k All Over')
plt.legend(loc='upper right')
plt.ylabel("TOA (W/m2)")
plt.title('TOA flux')
plt.ylim(-70,10)
# Out:
# Text(0.5, 1.0, 'TOA flux')

# %%
TOA_05_ns.plot( label='5_ns patch')
TOA_05.plot( label='5 patch')

plt.legend(loc='upper left')
plt.title('TOA flux')
# Out:
# Text(0.5, 1.0, 'TOA flux')

# %%
TOA_10_ns.plot( label='10_ns patch')
TOA_10.plot( label='10 patch')

plt.legend(loc='upper left')
plt.title('TOA flux')
# Out:
# Text(0.5, 1.0, 'TOA flux')

# %%
TOA_15_ns.plot( label='15_ns patch')
TOA_15.plot( label='15 patch')

plt.legend(loc='upper left')
plt.title('TOA flux')
# Out:
# Text(0.5, 1.0, 'TOA flux')

# %%
wTOA_50_ns.plot( label='50_ns patch')
wTOA_50.plot( label='50 patch')

plt.legend(loc='upper left')
plt.title('TOA flux')
# Out:
# Text(0.5, 1.0, 'TOA flux')

# %% [markdown]
# # Vertical Temperature Plot

# %%
T_00=data_00.T.mean('lon')-data_control.T.mean('lon')
T_05_n=data_05_n.T.mean('lon')-data_control.T.mean('lon')
T_05_s=T_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))
T_10_n=data_10_n.T.mean('lon')-data_control.T.mean('lon')
T_10_s=T_10_n.assign_coords(lat=list(reversed(data_10_n.lat)))

T_sum_5=T_00+T_05_s+T_05_n+T_10_s+T_10_n
T_Exp_10s_5s_00_5n_10n=data_10s_05s_00_05n_10n.T.mean('lon')-data_control.T.mean('lon')

# %%
T_00=data_00.T.mean('lon')-data_control.T.mean('lon')
T_05_n=data_05_n.T.mean('lon')-data_control.T.mean('lon')
T_05_s=T_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))
T_sum_3=T_00+T_05_s+T_05_n
T_Exp_5s_00_5n=data_05s_00_05n.T.mean('lon')-data_control.T.mean('lon')

# %%
T_pole_n=data_pole_n.T.mean('lon')-data_control.T.mean('lon')
T_00=data_00.T.mean('lon')-data_control.T.mean('lon')
T_05_n=data_05_n.T.mean('lon')-data_control.T.mean('lon')
T_10_n=data_10_n.T.mean('lon')-data_control.T.mean('lon')
T_15_n=data_15_n.T.mean('lon')-data_control.T.mean('lon')
T_20_n=data_20_n.T.mean('lon')-data_control.T.mean('lon')
T_25_n=data_25_n.T.mean('lon')-data_control.T.mean('lon')
T_30_n=data_30_n.T.mean('lon')-data_control.T.mean('lon')
T_35_n=data_35_n.T.mean('lon')-data_control.T.mean('lon')
T_40_n=data_40_n.T.mean('lon')-data_control.T.mean('lon')
T_45_n=data_45_n.T.mean('lon')-data_control.T.mean('lon')
T_50_n=data_50_n.T.mean('lon')-data_control.T.mean('lon')
T_55_n=data_55_n.T.mean('lon')-data_control.T.mean('lon')
T_60_n=data_60_n.T.mean('lon')-data_control.T.mean('lon')
T_65_n=data_65_n.T.mean('lon')-data_control.T.mean('lon')
T_70_n=data_70_n.T.mean('lon')-data_control.T.mean('lon')
T_75_n=data_75_n.T.mean('lon')-data_control.T.mean('lon')
T_80_n=data_80_n.T.mean('lon')-data_control.T.mean('lon')
T_85_n=data_85_n.T.mean('lon')-data_control.T.mean('lon')

#T_4k_n=data_4k_n_smooth.T.mean('lon')-data_control.T.mean('lon')

T_4k_n=data_4k_n.T.mean('lon')-data_control.T.mean('lon')
T_total_19=(T_pole_n+T_00+T_05_n+T_10_n+T_15_n+T_20_n+T_25_n+T_30_n+T_35_n+T_40_n+T_45_n+T_50_n+T_55_n+T_60_n+T_65_n+T_70_n+T_75_n+T_80_n+T_85_n)

# %%
T_pole_s=T_pole_n.assign_coords(lat=list(reversed(data_pole_n.lat)))
T_05_s=T_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))
T_10_s=T_10_n.assign_coords(lat=list(reversed(data_10_n.lat)))
T_15_s=T_15_n.assign_coords(lat=list(reversed(data_15_n.lat)))
T_20_s=T_20_n.assign_coords(lat=list(reversed(data_20_n.lat)))
T_25_s=T_25_n.assign_coords(lat=list(reversed(data_25_n.lat)))
T_30_s=T_30_n.assign_coords(lat=list(reversed(data_30_n.lat)))
T_35_s=T_35_n.assign_coords(lat=list(reversed(data_35_n.lat)))
T_40_s=T_40_n.assign_coords(lat=list(reversed(data_40_n.lat)))
T_45_s=T_45_n.assign_coords(lat=list(reversed(data_45_n.lat)))
T_50_s=T_50_n.assign_coords(lat=list(reversed(data_50_n.lat)))
T_55_s=T_55_n.assign_coords(lat=list(reversed(data_55_n.lat)))
T_60_s=T_60_n.assign_coords(lat=list(reversed(data_60_n.lat)))
T_65_s=T_65_n.assign_coords(lat=list(reversed(data_65_n.lat)))
T_70_s=T_70_n.assign_coords(lat=list(reversed(data_70_n.lat)))
T_75_s=T_75_n.assign_coords(lat=list(reversed(data_75_n.lat)))
T_80_s=T_80_n.assign_coords(lat=list(reversed(data_80_n.lat)))
T_85_s=T_85_n.assign_coords(lat=list(reversed(data_85_n.lat)))

T_4k=data_4k.T.mean('lon')-data_control.T.mean('lon')
T_total_NH=(T_pole_n+T_00+T_05_n+T_10_n+T_15_n+T_20_n+T_25_n+T_30_n+T_35_n+T_40_n+T_45_n+T_50_n+T_55_n+T_60_n+T_65_n+T_70_n+T_75_n+T_80_n+T_85_n)
T_total_SH=(T_pole_s+T_05_s+T_10_s+T_15_s+T_20_s+T_25_s+T_30_s+T_35_s+T_40_s+T_45_s+T_50_s+T_55_s+T_60_s+T_65_s+T_70_s+T_75_s+T_80_s+T_85_s)
T_total_ns=T_total_NH+T_total_SH

# %%
T_10_n=data_10_n.T.mean('lon')-data_control.T.mean('lon')
T_10_s=data_10_s.T.mean('lon')-data_control.T.mean('lon')

T_10_ns=T_10_n+T_10_s
T_10=data_10.T.mean('lon')-data_control.T.mean('lon')

# %%
T_05_n=data_05_n.T.mean('lon')-data_control.T.mean('lon')
T_05_s=data_05_s.T.mean('lon')-data_control.T.mean('lon')

T_05_ns=T_05_n+T_05_s
T_05=data_05.T.mean('lon')-data_control.T.mean('lon')

# %%
T_15_n=data_15_n.T.mean('lon')-data_control.T.mean('lon')
T_15_s=data_15_s.T.mean('lon')-data_control.T.mean('lon')

T_15_ns=T_15_n+T_15_s
T_15=data_15.T.mean('lon')-data_control.T.mean('lon')

# %%
wT_50_n=wdata_50_n.T.mean('lon')-data_control.T.mean('lon')
wT_50_s=wdata_50_s.T.mean('lon')-data_control.T.mean('lon')

wT_50_ns=wT_50_n+wT_50_s
wT_50=wdata_50.T.mean('lon')-data_control.T.mean('lon')

# %%
wT_00=wdata_00.T.mean('lon')-data_control.T.mean('lon')
wT_25_n=wdata_25_n.T.mean('lon')-data_control.T.mean('lon')
wT_25_s=wT_25_n.assign_coords(lat=list(reversed(wdata_25_n.lat)))
wT_50_n=wdata_50_n.T.mean('lon')-data_control.T.mean('lon')
wT_50_s=wT_50_n.assign_coords(lat=list(reversed(wdata_50_n.lat)))
wT_75_n=wdata_75_n.T.mean('lon')-data_control.T.mean('lon')
wT_75_s=wT_75_n.assign_coords(lat=list(reversed(wdata_75_n.lat)))
wT_100_n=wdata_100_n.T.mean('lon')-data_control.T.mean('lon')
wT_100_s=wT_100_n.assign_coords(lat=list(reversed(wdata_100_n.lat)))
wT_125_n=wdata_125_n.T.mean('lon')-data_control.T.mean('lon')
wT_125_s=wT_125_n.assign_coords(lat=list(reversed(wdata_125_n.lat)))

T_sum_wide=wT_00+wT_25_s+wT_25_n+wT_50_s+wT_50_n+wT_75_s+wT_75_n+wT_100_s+wT_100_n+wT_125_s+wT_125_n
T_Exp_4k=data_4k.T.mean('lon')-data_control.T.mean('lon')

# %%
nrow = 1
ncol = 7
fig = plt.figure(figsize=(7, 10))
grid = ImageGrid(fig, 
                 111, # as in plt.subplot(111)
                 nrows_ncols=(nrow,ncol),
                 axes_pad=0,
                 share_all=True,)

#for i in range(1):
#    for j in range(2):
im = np.random.rand(28,28)
gs = gridspec.GridSpec(9, 2)
gs.update(wspace=0.1,hspace=0.1)
vmax=20
vmin=-20
plt.subplot(gs[0,0])
T_sum_5.plot(vmax=vmax, vmin=vmin,yincrease=False, cmap='seismic',add_colorbar=False)
#plt.yscale("log")
#plt.title('Sum of 5 Exp')
ax = pylab.gca()
ax.xaxis.set_visible(False)
plt.yticks([1000, 800, 600,400,200])
#plt.hlines(y=1000, xmin=-5, xmax=15, colors='black', linestyles='-', lw=5, label='Single Short Line')
plt.xticks([])
plt.xticks(rotation=45)
#plt.xlabel('Latitude')
plt.text(0.3, 90, 'Sum_5Exp ', fontsize = 7, color='green',fontweight="bold")
plt.ylabel("")

plt.subplot(gs[0,1])
T_Exp_10s_5s_00_5n_10n.plot(vmax=vmax, vmin=vmin,yincrease=False, cmap='seismic',add_colorbar=False)
#plt.yscale("log")
#plt.title('10s_5s_00_5n_10n')
plt.text(0.1, 90, '10s_5s_00_5n_10n ', fontsize = 7, color='green',fontweight="bold")
ax = pylab.gca()
ax.xaxis.set_visible(False)
#plt.hlines(y=1000, xmin=-10, xmax=10, colors='black', linestyles='-', lw=5, label='Single Short Line')
plt.xticks([])
ax.yaxis.set_visible(False)
#plt.yticks([1000, 800, 600,400,200])
plt.xticks(rotation=45)
#plt.xlabel('Latitude')
plt.ylabel("")


plt.subplot(gs[1,0])
T_sum_3.plot(vmax=vmax, vmin=vmin,yincrease=False, cmap='seismic',add_colorbar=False)
#plt.yscale("log")
#plt.title('Sum of 3 Exp')
plt.text(0.3, 90, 'Sum_3Exp ', fontsize = 7, color='green',fontweight="bold")
plt.yticks([1000, 800, 600,400,200])
ax = pylab.gca()
ax.xaxis.set_visible(False)
#plt.hlines(y=1000, xmin=-5, xmax=15, colors='black', linestyles='-', lw=5, label='Single Short Line')
plt.xticks([])
plt.xticks(rotation=45)
plt.xlabel('Latitude')
plt.ylabel("")

plt.subplot(gs[1,1])
T_Exp_5s_00_5n.plot(vmax=vmax, vmin=vmin,yincrease=False, cmap='seismic',add_colorbar=False)
#plt.yscale("log")
#plt.title('5s_00_5n')
plt.text(0.3, 90, '5s_00_5n ', fontsize = 7, color='green',fontweight="bold")
ax = pylab.gca()
ax.xaxis.set_visible(False)
#plt.hlines(y=1000, xmin=-10, xmax=10, colors='black', linestyles='-', lw=5, label='Single Short Line')
plt.xticks([])
plt.xticks(rotation=45)
ax.yaxis.set_visible(False)
plt.ylabel("")


plt.subplot(gs[2,1])
T_4k_n.plot(vmax=vmax, vmin=vmin,yincrease=False, cmap='seismic',add_colorbar=False)
#plt.yscale("log")
#plt.title('4k NH')
plt.text(0.3, 90, '+4k_NH ', fontsize = 7, color='green',fontweight="bold")
ax = pylab.gca()
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
#plt.hlines(y=1000, xmin=-10, xmax=10, colors='black', linestyles='-', lw=5, label='Single Short Line')
plt.xticks([])
plt.xticks(rotation=45)
plt.ylabel("")

plt.subplot(gs[2,0])
T_total_19.plot(vmax=vmax, vmin=vmin,yincrease=False, cmap='seismic',add_colorbar=False)
#plt.yscale("log")
#plt.title('Sum of all NH Exp')
plt.text(0.3, 90, 'Sum_NH ', fontsize = 7, color='green',fontweight="bold")
plt.yticks([1000, 800, 600,400,200])
#plt.hlines(y=1000, xmin=-5, xmax=15, colors='black', linestyles='-', lw=5, label='Single Short Line')
plt.xticks([])
plt.xticks(rotation=45)
ax = pylab.gca()
ax.xaxis.set_visible(False)
plt.ylabel("")


plt.subplot(gs[3,1])
T_4k.plot(vmax=vmax, vmin=vmin,yincrease=False, cmap='seismic',add_colorbar=False)
#plt.yscale("log")
#plt.title('4k All Over')
ax = pylab.gca()
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
#plt.hlines(y=1000, xmin=-10, xmax=10, colors='black', linestyles='-', lw=5, label='Single Short Line')
plt.xticks([])
plt.text(0.3, 90, '4K ', fontsize = 7, color='green',fontweight="bold")
plt.xticks(rotation=45)
plt.xlabel("")
plt.ylabel("")

plt.subplot(gs[3,0])
T_total_ns.plot(vmax=vmax, vmin=vmin,yincrease=False, cmap='seismic',add_colorbar=False)
#plt.yscale("log")
#plt.title('Sum of all Exp')
ax = pylab.gca()
ax.xaxis.set_visible(False)
#plt.hlines(y=1000, xmin=-5, xmax=15, colors='black', linestyles='-', lw=5, label='Single Short Line')
plt.xticks([])
plt.text(0.3, 90, 'Sum ', fontsize = 7, color='green',fontweight="bold")
plt.yticks([1000, 800, 600,400,200])
plt.xticks(rotation=45)
plt.xlabel("")
plt.ylabel("")

plt.subplot(gs[4,0])
T_sum_wide.plot(vmax=vmax, vmin=vmin,yincrease=False, cmap='seismic',add_colorbar=False)
#plt.yscale("log")
#plt.title('Sum of all Exp')
ax = pylab.gca()
ax.xaxis.set_visible(False)
#plt.hlines(y=1000, xmin=-5, xmax=15, colors='black', linestyles='-', lw=5, label='Single Short Line')
plt.xticks([])
plt.text(0.3, 90, 'Sum_wide ', fontsize = 7, color='green',fontweight="bold")
plt.yticks([1000, 800, 600,400,200])
plt.xticks(rotation=45)
plt.xlabel("")
plt.ylabel("")

plt.subplot(gs[4,1])
T_Exp_4k.plot(vmax=vmax, vmin=vmin,yincrease=False, cmap='seismic',add_colorbar=False)
#plt.yscale("log")
#plt.title('4k All Over')
ax = pylab.gca()
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
#plt.hlines(y=1000, xmin=-10, xmax=10, colors='black', linestyles='-', lw=5, label='Single Short Line')
plt.xticks([])
plt.text(0.3, 90, '4K ', fontsize = 7, color='green',fontweight="bold")
plt.xticks(rotation=45)
plt.xlabel("")
plt.ylabel("")

plt.subplot(gs[5,0])
T_05_ns.plot(vmax=vmax, vmin=vmin,yincrease=False, cmap='seismic',add_colorbar=False)
#plt.yscale("log")
#plt.title('5_ns')
ax = pylab.gca()
ax.xaxis.set_visible(False)
plt.xticks([])
plt.yticks([1000, 800, 600,400,200])
plt.text(0.3, 90, '5_ns ', fontsize = 7, color='green',fontweight="bold")
plt.xticks(rotation=45)
plt.ylabel("")

plt.subplot(gs[5,1])
T_05.plot(vmax=vmax, vmin=vmin,yincrease=False, cmap='seismic',add_colorbar=False)
#plt.yscale("log")
#plt.title('5')
ax = pylab.gca()
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
plt.xticks([])
plt.text(0.3, 90, '5 ', fontsize = 7, color='green',fontweight="bold")
plt.xticks(rotation=45)
plt.ylabel("")

plt.subplot(gs[6,0])
T_10_ns.plot(vmax=vmax, vmin=vmin,yincrease=False, cmap='seismic',add_colorbar=False)
#plt.yscale("log")
#plt.title('10_ns')
ax = pylab.gca()
ax.xaxis.set_visible(False)
plt.xticks([])
plt.yticks([1000, 800, 600,400,200])
plt.text(0.3, 90, '10_ns ', fontsize = 7, color='green',fontweight="bold")
plt.xticks(rotation=45)
plt.ylabel("")

plt.subplot(gs[6,1])
T_10.plot(vmax=vmax, vmin=vmin, yincrease=False, cmap='seismic',add_colorbar=False)
#plt.yscale("log")
#plt.title('10')
ax = pylab.gca()
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
plt.xticks([])
plt.text(0.3, 90, '10 ', fontsize = 7, color='green',fontweight="bold")
plt.xticks(rotation=45)
plt.ylabel("")

plt.subplot(gs[7,0])
T_15_ns.plot(vmax=vmax, vmin=vmin, yincrease=False, cmap='seismic',add_colorbar=False)
#plt.yscale("log")
#plt.title('15_ns')
ax = pylab.gca()
ax.xaxis.set_visible(False)
plt.xticks([])
plt.yticks([1000, 800, 600,400,200])
plt.text(0.3, 90, '15_ns ', fontsize = 7, color='green',fontweight="bold")
plt.xticks(rotation=45)
plt.ylabel("")

plt.subplot(gs[7,1])
T_15.plot(vmax=vmax, vmin=vmin, yincrease=False, cmap='seismic',add_colorbar=False)
#plt.yscale("log")
#plt.title('15')
ax = pylab.gca()
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
plt.xticks([])
plt.text(0.3, 90, '15 ', fontsize = 7, color='green',fontweight="bold")
plt.xticks(rotation=45)
plt.ylabel("")

plt.subplot(gs[8,0])
wT_50_ns.plot(vmax=vmax, vmin=vmin, yincrease=False, cmap='seismic',add_colorbar=False)
#plt.yscale("log")
#plt.title('50_ns')
plt.text(0.3, 90, '50 ', fontsize = 7, color='green',fontweight="bold")
ax = pylab.gca()
plt.xticks([-90, -80, -60,-40,-20,0,20,40,60,80,90])
plt.yticks([1000, 800, 600,400,200])
plt.xticks(rotation=45)
plt.xlabel("")
plt.ylabel("")

plt.subplot(gs[8,1])
wT_50.plot(vmax=vmax, vmin=vmin, yincrease=False, cmap='seismic',add_colorbar=False)
#plt.yscale("log")
#plt.title('50')
plt.text(0.3, 90, '50 ', fontsize = 7, color='green',fontweight="bold")
ax = pylab.gca()
ax.yaxis.set_visible(False)
plt.xticks([-90, -80, -60,-40,-20,0,20,40,60,80,90])
plt.xticks(rotation=45)
plt.xlabel("")
plt.ylabel("")

fig.text(0.5, 0.05, 'Latitude', ha='center')
fig.text(0.04, 0.5, 'Pressure Level', va='center', rotation='vertical')

plt.savefig('T.png', bbox_inches='tight')

#plt.colorbar(shrink=1)
#plt.subplot(gs[8,:])
a = np.array([[-20,20]])
pl.figure(figsize=(8, 0.15))
img = pl.imshow(a, cmap="seismic")
pl.gca().set_visible(False)
cax = pl.axes([0.1, 0.8, 0.8, 0.6])
pl.colorbar(orientation="horizontal", cax=cax,label='Temperature')
#plt.show()

# %%
nrow = 1
ncol = 7
fig = plt.figure(figsize=(25, 20))
grid = ImageGrid(fig, 
                 111, # as in plt.subplot(111)
                 nrows_ncols=(nrow,ncol),
                 axes_pad=0,
                 share_all=True,)

#for i in range(1):
#    for j in range(2):
im = np.random.rand(28,28)
gs = gridspec.GridSpec(14, 14)
gs.update(wspace=0.6)
vmax=15
vmin=-15
plt.subplot(gs[0,0])
T_sum_5.plot(vmax=vmax, vmin=vmin,yincrease=False, cmap='RdBu_r',add_colorbar=False)
#plt.yscale("log")
plt.title('Sum of 5 Exp')
ax = pylab.gca()
plt.yticks([1000, 800, 600,400,200])
#plt.hlines(y=1000, xmin=-5, xmax=15, colors='black', linestyles='-', lw=5, label='Single Short Line')
plt.xticks([-90, -60,-30,0,30,60,90])
plt.xticks(rotation=45)
plt.xlabel('Latitude')

plt.subplot(gs[0,1])
T_Exp_10s_5s_00_5n_10n.plot(vmax=vmax, vmin=vmin,yincrease=False, cmap='RdBu_r',add_colorbar=False)
#plt.yscale("log")
plt.title('10s_5s_00_5n_10n')
ax = pylab.gca()
#plt.hlines(y=1000, xmin=-10, xmax=10, colors='black', linestyles='-', lw=5, label='Single Short Line')
plt.xticks([-90, -60,-30,0,30,60,90])
ax.yaxis.set_visible(False)

#plt.yticks([1000, 800, 600,400,200])
plt.xticks(rotation=45)
plt.xlabel('Latitude')

# Get the current axis
ax = pylab.gca()
# Set Y-axis visibility to False
ax.yaxis.set_visible(False)

#        plt.set_yticklabels([])

#plt.tight_layout() # do not use this!!
#plt.subplot(gs[0,6])
#plt.colorbar()
plt.show()

# %%
nrow = 1
ncol = 7
fig = plt.figure(figsize=(25, 20))
grid = ImageGrid(fig, 
                 111, # as in plt.subplot(111)
                 nrows_ncols=(nrow,ncol),
                 axes_pad=0,
                 share_all=True,)

#for i in range(1):
#    for j in range(2):
im = np.random.rand(28,28)
gs = gridspec.GridSpec(14, 14)
gs.update(wspace=0.6)
vmax=10
vmin=-10
plt.subplot(gs[0,0])
T_sum_3.plot(vmax=vmax, vmin=vmin,yincrease=False, cmap='RdBu_r',add_colorbar=False)
#plt.yscale("log")
plt.title('Sum of 3 Exp')
plt.yticks([1000, 800, 600,400,200])

ax = pylab.gca()
#plt.hlines(y=1000, xmin=-5, xmax=15, colors='black', linestyles='-', lw=5, label='Single Short Line')
plt.xticks([-90, -60,-30,0,30,60,90])
plt.xticks(rotation=45)
plt.xlabel('Latitude')

plt.subplot(gs[0,1])
T_Exp_5s_00_5n.plot(vmax=vmax, vmin=vmin,yincrease=False, cmap='RdBu_r')
#plt.yscale("log")
plt.title('5s_00_5n')
ax = pylab.gca()
#plt.hlines(y=1000, xmin=-10, xmax=10, colors='black', linestyles='-', lw=5, label='Single Short Line')
plt.xticks([-90, -60,-30,0,30,60,90])

plt.xticks(rotation=45)
ax.yaxis.set_visible(False)

plt.xlabel('Latitude')

# Get the current axis
ax = pylab.gca()
# Set Y-axis visibility to False
ax.yaxis.set_visible(False)

#        plt.set_yticklabels([])

#plt.tight_layout() # do not use this!!
#plt.subplot(gs[0,6])
#plt.colorbar()
plt.show()

# %%
nrow = 1
ncol = 7
fig = plt.figure(figsize=(25, 20))
grid = ImageGrid(fig, 
                 111, # as in plt.subplot(111)
                 nrows_ncols=(nrow,ncol),
                 axes_pad=0,
                 share_all=True,)

#for i in range(1):
#    for j in range(2):
im = np.random.rand(28,28)
gs = gridspec.GridSpec(14, 14)
gs.update(wspace=0.3)
vmax=10
vmin=-10
plt.subplot(gs[0,1])
T_4k_n.plot(vmax=vmax, vmin=vmin,yincrease=False, cmap='RdBu_r')
#plt.yscale("log")
plt.title('4k NH')
ax = pylab.gca()
ax = pylab.gca()
ax.yaxis.set_visible(False)
#plt.hlines(y=1000, xmin=-10, xmax=10, colors='black', linestyles='-', lw=5, label='Single Short Line')
plt.xticks([-90, -60,-30,0,30,60,90])
plt.xticks(rotation=45)

plt.subplot(gs[0,0])
T_total_19.plot(vmax=vmax, vmin=vmin,yincrease=False, cmap='RdBu_r',add_colorbar=False)
#plt.yscale("log")
plt.title('Sum of all NH Exp')
plt.yticks([1000, 800, 600,400,200])


#plt.hlines(y=1000, xmin=-5, xmax=15, colors='black', linestyles='-', lw=5, label='Single Short Line')
plt.xticks([-90, -60,-30,0,30,60,90])
plt.xticks(rotation=45)


# Get the current axis
ax = pylab.gca()
# Set Y-axis visibility to False
ax.yaxis.set_visible(False)

#        plt.set_yticklabels([])

#plt.tight_layout() # do not use this!!
#plt.subplot(gs[0,6])
#plt.colorbar()
plt.show()

# %%
nrow = 1
ncol = 7
fig = plt.figure(figsize=(25, 20))
grid = ImageGrid(fig, 
                 111, # as in plt.subplot(111)
                 nrows_ncols=(nrow,ncol),
                 axes_pad=1,
                 share_all=True,)

#for i in range(1):
#    for j in range(2):
im = np.random.rand(28,28)
gs = gridspec.GridSpec(14, 14)
gs.update(wspace=0.1)
vmax=20
vmin=-20

 



plt.subplot(gs[0,1])
T_4k.plot(vmax=vmax, vmin=vmin,yincrease=False, cmap='RdBu_r')
#plt.yscale("log")
plt.title('4k All Over')
ax = pylab.gca()
ax.yaxis.set_visible(False)

#plt.hlines(y=1000, xmin=-10, xmax=10, colors='black', linestyles='-', lw=5, label='Single Short Line')
plt.xticks([-90, -60,-30,0,30,60,90])
plt.xticks(rotation=45)
plt.xlabel("")

plt.subplot(gs[0,0])
T_total_ns.plot(vmax=vmax, vmin=vmin,yincrease=False, cmap='RdBu_r',add_colorbar=False)
#plt.yscale("log")
plt.title('Sum of all Exp')
ax = pylab.gca()
#plt.hlines(y=1000, xmin=-5, xmax=15, colors='black', linestyles='-', lw=5, label='Single Short Line')
plt.xticks([-90, -60,-30,0,30,60,90])
plt.yticks([1000, 800, 600,400,200])

plt.xticks(rotation=45)
plt.xlabel("")


# Get the current axis
ax = pylab.gca()
# Set Y-axis visibility to False

#        plt.set_yticklabels([])

#plt.tight_layout() # do not use this!!
#plt.subplot(gs[0,6])
#plt.colorbar()
plt.show()

# %%
im = np.random.rand(28,28)
gs = gridspec.GridSpec(2, 2)
gs.update(wspace=0.1)

plt.subplot(gs[0,0])
T_05_ns.plot(yincrease=False, cmap='RdBu_r',add_colorbar=False)
#plt.yscale("log")
plt.title('5_ns')
ax = pylab.gca()
plt.xticks([-90, -80, -60,-40,-20,0,20,40,60,80,90])
plt.yticks([1000, 800, 600,400,200])
plt.xticks(rotation=45)

plt.subplot(gs[0,1])
T_05.plot(yincrease=False, cmap='RdBu_r')
#plt.yscale("log")
plt.title('5')
ax = pylab.gca()
ax.yaxis.set_visible(False)
plt.xticks([-90, -80, -60,-40,-20,0,20,40,60,80,90])
plt.xticks(rotation=45)

# Get the current axis
ax = pylab.gca()
# Set Y-axis visibility to False
ax.yaxis.set_visible(False)

#        plt.set_yticklabels([])

#plt.tight_layout() # do not use this!!
#plt.subplot(gs[0,6])
#plt.colorbar()
plt.show()

# %%
im = np.random.rand(28,28)
gs = gridspec.GridSpec(2, 2)
gs.update(wspace=0.1)

plt.subplot(gs[0,0])
T_10_ns.plot(yincrease=False, cmap='RdBu_r',add_colorbar=False)
#plt.yscale("log")
plt.title('10_ns')
ax = pylab.gca()
plt.xticks([-90, -80, -60,-40,-20,0,20,40,60,80,90])
plt.yticks([1000, 800, 600,400,200])
plt.xticks(rotation=45)

plt.subplot(gs[0,1])
T_10.plot(yincrease=False, cmap='RdBu_r')
#plt.yscale("log")
plt.title('10')
ax = pylab.gca()
ax.yaxis.set_visible(False)
plt.xticks([-90, -80, -60,-40,-20,0,20,40,60,80,90])
plt.xticks(rotation=45)

# Get the current axis
ax = pylab.gca()
# Set Y-axis visibility to False
ax.yaxis.set_visible(False)

#        plt.set_yticklabels([])

#plt.tight_layout() # do not use this!!
#plt.subplot(gs[0,6])
#plt.colorbar()
plt.show()

# %%
im = np.random.rand(28,28)
gs = gridspec.GridSpec(2, 2)
gs.update(wspace=0.1)

plt.subplot(gs[0,0])
T_15_ns.plot(yincrease=False, cmap='RdBu_r',add_colorbar=False)
#plt.yscale("log")
plt.title('15_ns')
ax = pylab.gca()
plt.xticks([-90, -80, -60,-40,-20,0,20,40,60,80,90])
plt.yticks([1000, 800, 600,400,200])
plt.xticks(rotation=45)

plt.subplot(gs[0,1])
T_15.plot(yincrease=False, cmap='RdBu_r')
#plt.yscale("log")
plt.title('15')
ax = pylab.gca()
ax.yaxis.set_visible(False)
plt.xticks([-90, -80, -60,-40,-20,0,20,40,60,80,90])
plt.xticks(rotation=45)

# Get the current axis
ax = pylab.gca()
# Set Y-axis visibility to False
ax.yaxis.set_visible(False)

#        plt.set_yticklabels([])

#plt.tight_layout() # do not use this!!
#plt.subplot(gs[0,6])
#plt.colorbar()
plt.show()

# %%
im = np.random.rand(28,28)
gs = gridspec.GridSpec(2, 2)
gs.update(wspace=0.1)

plt.subplot(gs[0,0])
wT_50_ns.plot(yincrease=False, cmap='RdBu_r',add_colorbar=False)
#plt.yscale("log")
plt.title('50_ns')
ax = pylab.gca()
plt.xticks([-90, -80, -60,-40,-20,0,20,40,60,80,90])
plt.yticks([1000, 800, 600,400,200])
plt.xticks(rotation=45)

plt.subplot(gs[0,1])
wT_50.plot(yincrease=False, cmap='RdBu_r')
#plt.yscale("log")
plt.title('50')
ax = pylab.gca()
ax.yaxis.set_visible(False)
plt.xticks([-90, -80, -60,-40,-20,0,20,40,60,80,90])
plt.xticks(rotation=45)

# Get the current axis
ax = pylab.gca()
# Set Y-axis visibility to False
ax.yaxis.set_visible(False)

#        plt.set_yticklabels([])

#plt.tight_layout() # do not use this!!
#plt.subplot(gs[0,6])
#plt.colorbar()
plt.show()

# %% [markdown]
# # CRE, All Sky, Clear Sky Line Plot

# %%
#clear sky short wave
css_00=data_00.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_05_n=data_05_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_05_s=css_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))
css_10_n=data_10_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_10_s=css_10_n.assign_coords(lat=list(reversed(data_10_n.lat)))

css_total_5=css_00+css_05_n+css_05_s+css_10_n+css_10_s
css_Exp_10s_5s_00_5n_10n=data_10s_05s_00_05n_10n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')




#clear sky long wave
csl_00=data_00.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_05_n=data_05_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_05_s=csl_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))
csl_10_n=data_10_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_10_s=csl_10_n.assign_coords(lat=list(reversed(data_10_n.lat)))

csl_total_5=csl_00+csl_05_n+csl_05_s+csl_10_n+csl_10_s
csl_Exp_10s_5s_00_5n_10n=data_10s_05s_00_05n_10n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')




#all sky short wave
ass_00=data_00.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_05_n=data_05_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_05_s=ass_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))
ass_10_n=data_10_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_10_s=ass_10_n.assign_coords(lat=list(reversed(data_10_n.lat)))

ass_total_5=ass_00+ass_05_n+ass_05_s+ass_10_n+ass_10_s
ass_Exp_10s_5s_00_5n_10n=data_10s_05s_00_05n_10n.FSNT.mean('lon')-data_control.FSNT.mean('lon')




#all sky long wave
asl_00=data_00.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_05_n=data_05_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_05_s=asl_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))
asl_10_n=data_10_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_10_s=asl_10_n.assign_coords(lat=list(reversed(data_10_n.lat)))

asl_total_5=asl_00+asl_05_n+asl_05_s+asl_10_n+asl_10_s
asl_Exp_10s_5s_00_5n_10n=data_10s_05s_00_05n_10n.FLNT.mean('lon')-data_control.FLNT.mean('lon')




#CRE short wave-zonal
CRES_00 = (data_00.FSNT.mean('lon')-data_00.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_05_n = (data_05_n.FSNT.mean('lon')-data_05_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_05_s=CRES_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))
CRES_10_n = (data_10_n.FSNT.mean('lon')-data_10_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_10_s=CRES_10_n.assign_coords(lat=list(reversed(data_10_n.lat)))

CRES_total_5=CRES_00+CRES_05_n+CRES_05_s+CRES_10_n+CRES_10_s
CRES_Exp_10s_5s_00_5n_10n=(data_10s_05s_00_05n_10n.FSNT.mean('lon')-data_10s_05s_00_05n_10n.FSNTC.mean('lon'))-\
                    (data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))



#CRE Long wave-zonal
CREL_00 = (data_00.FLNT.mean('lon')-data_00.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_05_n = (data_05_n.FLNT.mean('lon')-data_05_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_05_s=CREL_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))
CREL_10_n = (data_10_n.FLNT.mean('lon')-data_10_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_10_s=CREL_10_n.assign_coords(lat=list(reversed(data_10_n.lat)))

CREL_total_5=CREL_00+CREL_05_n+CREL_05_s+CREL_10_n+CREL_10_s
CREL_Exp_10s_5s_00_5n_10n=(data_10s_05s_00_05n_10n.FLNT.mean('lon')-data_10s_05s_00_05n_10n.FLNTC.mean('lon'))-\
                    (data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))

# %%
# total clear sky
tcs_00=css_00-csl_00
tcs_05_n=css_05_n-csl_05_n
tcs_05_s=tcs_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))
tcs_10_n=css_10_n-csl_10_n
tcs_10_s=tcs_10_n.assign_coords(lat=list(reversed(data_10_n.lat)))

# total all sky
tas_00=ass_00-asl_00
tas_05_n=ass_05_n-asl_05_n
tas_05_s=tas_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))
tas_10_n=ass_10_n-asl_10_n
tas_10_s=tas_10_n.assign_coords(lat=list(reversed(data_10_n.lat)))


#total CRE
tCRE_00=CRES_00-CREL_00
tCRE_05_n=CRES_05_n-CREL_05_n
tCRE_05_s=tCRE_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))
tCRE_10_n=CRES_10_n-CREL_10_n
tCRE_10_s=tCRE_10_n.assign_coords(lat=list(reversed(data_10_n.lat)))

tcs_total_5=tcs_00+tcs_05_n+tcs_05_s+tcs_10_n+tcs_10_s
tcs_Exp_10s_5s_00_5n_10n=css_Exp_10s_5s_00_5n_10n-csl_Exp_10s_5s_00_5n_10n

tas_total_5=tas_00+tas_05_n+tas_05_s+tas_10_n+tas_10_s
tas_Exp_10s_5s_00_5n_10n=ass_Exp_10s_5s_00_5n_10n-asl_Exp_10s_5s_00_5n_10n

tCRE_total_5=tCRE_00+tCRE_05_s+tCRE_05_n+tCRE_10_s+tCRE_10_n
tCRE_Exp_10s_5s_00_5n_10n=CRES_Exp_10s_5s_00_5n_10n-CREL_Exp_10s_5s_00_5n_10n

# %%
#clear sky short wave
css_00=data_00.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_05_n=data_05_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_05_s=css_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))

css_total_3=css_00+css_05_n+css_05_s
css_Exp_5s_00_5n=data_05s_00_05n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')




#clear sky long wave
csl_00=data_00.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_05_n=data_05_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_05_s=csl_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))

csl_total_3=csl_00+csl_05_n+csl_05_s
csl_Exp_5s_00_5n=data_05s_00_05n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')




#all sky short wave
ass_00=data_00.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_05_n=data_05_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_05_s=ass_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))

ass_total_3=ass_00+ass_05_n+ass_05_s
ass_Exp_5s_00_5n=data_05s_00_05n.FSNT.mean('lon')-data_control.FSNT.mean('lon')




#all sky long wave
asl_00=data_00.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_05_n=data_05_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_05_s=asl_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))

asl_total_3=asl_00+asl_05_n+asl_05_s
asl_Exp_5s_00_5n=data_05s_00_05n.FLNT.mean('lon')-data_control.FLNT.mean('lon')




#CRE short wave-zonal
CRES_00 = (data_00.FSNT.mean('lon')-data_00.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_05_n = (data_05_n.FSNT.mean('lon')-data_05_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_05_s=CRES_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))

CRES_total_3=CRES_00+CRES_05_n+CRES_05_s
CRES_Exp_5s_00_5n=(data_05s_00_05n.FSNT.mean('lon')-data_05s_00_05n.FSNTC.mean('lon'))-\
                    (data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))



#CRE Long wave-zonal
CREL_00 = (data_00.FLNT.mean('lon')-data_00.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_05_n = (data_05_n.FLNT.mean('lon')-data_05_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_05_s=CREL_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))

CREL_total_3=CREL_00+CREL_05_n+CREL_05_s
CREL_Exp_5s_00_5n=(data_05s_00_05n.FLNT.mean('lon')-data_05s_00_05n.FLNTC.mean('lon'))-\
                    (data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))

# %%
# total clear sky
tcs_00=css_00-csl_00
tcs_05_n=css_05_n-csl_05_n
tcs_05_s=tcs_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))

# total all sky
tas_00=ass_00-asl_00
tas_05_n=ass_05_n-asl_05_n
tas_05_s=tas_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))


#total CRE
tCRE_00=CRES_00-CREL_00
tCRE_05_n=CRES_05_n-CREL_05_n
tCRE_05_s=tCRE_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))


tcs_total_3=tcs_00+tcs_05_n+tcs_05_s
tcs_Exp_5s_00_5n=css_Exp_5s_00_5n-csl_Exp_5s_00_5n

tas_total_3=tas_00+tas_05_n+tas_05_s
tas_Exp_5s_00_5n=ass_Exp_5s_00_5n-asl_Exp_5s_00_5n

tCRE_total_3=tCRE_00+tCRE_05_s+tCRE_05_n
tCRE_Exp_5s_00_5n=CRES_Exp_5s_00_5n-CREL_Exp_5s_00_5n

# %%
#clear sky short wave
css_pole_n=data_pole_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_00=data_00.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_05_n=data_05_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_10_n=data_10_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_15_n=data_15_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_20_n=data_20_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_25_n=data_25_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_30_n=data_30_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_35_n=data_35_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_40_n=data_40_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_45_n=data_45_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_50_n=data_50_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_55_n=data_55_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_60_n=data_60_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_65_n=data_65_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_70_n=data_70_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_75_n=data_75_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_80_n=data_80_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_85_n=data_85_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')


#clear sky long wave
csl_pole_n=data_pole_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_00=data_00.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_05_n=data_05_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_10_n=data_10_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_15_n=data_15_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_20_n=data_20_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_25_n=data_25_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_30_n=data_30_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_35_n=data_35_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_40_n=data_40_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_45_n=data_45_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_50_n=data_50_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_55_n=data_55_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_60_n=data_60_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_65_n=data_65_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_70_n=data_70_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_75_n=data_75_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_80_n=data_80_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_85_n=data_85_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')


#all sky short wave
ass_pole_n=data_pole_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_00=data_00.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_05_n=data_05_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_10_n=data_10_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_15_n=data_15_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_20_n=data_20_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_25_n=data_25_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_30_n=data_30_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_35_n=data_35_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_40_n=data_40_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_45_n=data_45_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_50_n=data_50_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_55_n=data_55_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_60_n=data_60_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_65_n=data_65_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_70_n=data_70_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_75_n=data_75_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_80_n=data_80_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_85_n=data_85_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')



#all sky long wave
asl_pole_n=data_pole_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_00=data_00.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_05_n=data_05_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_10_n=data_10_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_15_n=data_15_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_20_n=data_20_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_25_n=data_25_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_30_n=data_30_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_35_n=data_35_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_40_n=data_40_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_45_n=data_45_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_50_n=data_50_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_55_n=data_55_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_60_n=data_60_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_65_n=data_65_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_70_n=data_70_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_75_n=data_75_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_80_n=data_80_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_85_n=data_85_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')



#CRE short wave-zonal
CRES_pole_n = (data_pole_n.FSNT.mean('lon')-data_pole_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_00 = (data_00.FSNT.mean('lon')-data_00.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_05_n = (data_05_n.FSNT.mean('lon')-data_05_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_10_n = (data_10_n.FSNT.mean('lon')-data_10_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_15_n = (data_15_n.FSNT.mean('lon')-data_15_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_20_n = (data_20_n.FSNT.mean('lon')-data_20_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_25_n = (data_25_n.FSNT.mean('lon')-data_25_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_30_n = (data_30_n.FSNT.mean('lon')-data_30_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_35_n = (data_35_n.FSNT.mean('lon')-data_35_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_40_n = (data_40_n.FSNT.mean('lon')-data_40_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_45_n = (data_45_n.FSNT.mean('lon')-data_45_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_50_n = (data_50_n.FSNT.mean('lon')-data_50_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_55_n = (data_55_n.FSNT.mean('lon')-data_55_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_60_n = (data_60_n.FSNT.mean('lon')-data_60_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_65_n = (data_65_n.FSNT.mean('lon')-data_65_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_70_n = (data_70_n.FSNT.mean('lon')-data_70_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_75_n = (data_75_n.FSNT.mean('lon')-data_75_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_80_n = (data_80_n.FSNT.mean('lon')-data_80_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_85_n = (data_85_n.FSNT.mean('lon')-data_85_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))


#CRE long wave-zonal
CREL_pole_n = (data_pole_n.FLNT.mean('lon')-data_pole_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_00 = (data_00.FLNT.mean('lon')-data_00.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_05_n = (data_05_n.FLNT.mean('lon')-data_05_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_10_n = (data_10_n.FLNT.mean('lon')-data_10_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_15_n = (data_15_n.FLNT.mean('lon')-data_15_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_20_n = (data_20_n.FLNT.mean('lon')-data_20_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_25_n = (data_25_n.FLNT.mean('lon')-data_25_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_30_n = (data_30_n.FLNT.mean('lon')-data_30_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_35_n = (data_35_n.FLNT.mean('lon')-data_35_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_40_n = (data_40_n.FLNT.mean('lon')-data_40_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_45_n = (data_45_n.FLNT.mean('lon')-data_45_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_50_n = (data_50_n.FLNT.mean('lon')-data_50_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_55_n = (data_55_n.FLNT.mean('lon')-data_55_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_60_n = (data_60_n.FLNT.mean('lon')-data_60_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_65_n = (data_65_n.FLNT.mean('lon')-data_65_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_70_n = (data_70_n.FLNT.mean('lon')-data_70_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_75_n = (data_75_n.FLNT.mean('lon')-data_75_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_80_n = (data_80_n.FLNT.mean('lon')-data_80_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_85_n = (data_85_n.FLNT.mean('lon')-data_85_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))

# %%
CRES_total_19=(CRES_pole_n+CRES_00+CRES_05_n+CRES_10_n+CRES_15_n+CRES_20_n+CRES_25_n+CRES_30_n+CRES_35_n+CRES_40_n+CRES_45_n+CRES_50_n+CRES_55_n+CRES_60_n+CRES_65_n+CRES_70_n+CRES_75_n+CRES_80_n+CRES_85_n)
CRES_4k_n=(data_4k_n_smooth.FSNT.mean('lon')-data_4k_n_smooth.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))

CREL_total_19=(CREL_pole_n+CREL_00+CREL_05_n+CREL_10_n+CREL_15_n+CREL_20_n+CREL_25_n+CREL_30_n+CREL_35_n+CREL_40_n+CREL_45_n+CREL_50_n+CREL_55_n+CREL_60_n+CREL_65_n+CREL_70_n+CREL_75_n+CREL_80_n+CREL_85_n)
CREL_4k_n=(data_4k_n_smooth.FLNT.mean('lon')-data_4k_n_smooth.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))

ass_total_19=(ass_pole_n+ass_00+ass_05_n+ass_10_n+ass_15_n+ass_20_n+ass_25_n+ass_30_n+ass_35_n+ass_40_n+ass_45_n+ass_50_n+ass_55_n+ass_60_n+ass_65_n+ass_70_n+ass_75_n+ass_80_n+ass_85_n)
ass_4k_n=data_4k_n_smooth.FSNT.mean('lon')-data_control.FSNT.mean('lon')

asl_total_19=(asl_pole_n+asl_00+asl_05_n+asl_10_n+asl_15_n+asl_20_n+asl_25_n+asl_30_n+asl_35_n+asl_40_n+asl_45_n+asl_50_n+asl_55_n+asl_60_n+asl_65_n+asl_70_n+asl_75_n+asl_80_n+asl_85_n)
asl_4k_n=data_4k_n_smooth.FLNT.mean('lon')-data_control.FLNT.mean('lon')

css_total_19=(css_pole_n+css_00+css_05_n+css_10_n+css_15_n+css_20_n+css_25_n+css_30_n+css_35_n+css_40_n+css_45_n+css_50_n+css_55_n+css_60_n+css_65_n+css_70_n+css_75_n+css_80_n+css_85_n)
css_4k_n=data_4k_n_smooth.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')

csl_total_19=(csl_pole_n+csl_00+csl_05_n+csl_10_n+csl_15_n+csl_20_n+csl_25_n+csl_30_n+csl_35_n+csl_40_n+csl_45_n+csl_50_n+csl_55_n+csl_60_n+csl_65_n+csl_70_n+csl_75_n+csl_80_n+csl_85_n)
csl_4k_n=data_4k_n_smooth.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')

# %%
CRES_total_19=(CRES_pole_n+CRES_00+CRES_05_n+CRES_10_n+CRES_15_n+CRES_20_n+CRES_25_n+CRES_30_n+CRES_35_n+CRES_40_n+CRES_45_n+CRES_50_n+CRES_55_n+CRES_60_n+CRES_65_n+CRES_70_n+CRES_75_n+CRES_80_n+CRES_85_n)
CRES_4k_n=(data_4k_n.FSNT.mean('lon')-data_4k_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))

CREL_total_19=(CREL_pole_n+CREL_00+CREL_05_n+CREL_10_n+CREL_15_n+CREL_20_n+CREL_25_n+CREL_30_n+CREL_35_n+CREL_40_n+CREL_45_n+CREL_50_n+CREL_55_n+CREL_60_n+CREL_65_n+CREL_70_n+CREL_75_n+CREL_80_n+CREL_85_n)
CREL_4k_n=(data_4k_n.FLNT.mean('lon')-data_4k_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))

ass_total_19=(ass_pole_n+ass_00+ass_05_n+ass_10_n+ass_15_n+ass_20_n+ass_25_n+ass_30_n+ass_35_n+ass_40_n+ass_45_n+ass_50_n+ass_55_n+ass_60_n+ass_65_n+ass_70_n+ass_75_n+ass_80_n+ass_85_n)
ass_4k_n=data_4k_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')

asl_total_19=(asl_pole_n+asl_00+asl_05_n+asl_10_n+asl_15_n+asl_20_n+asl_25_n+asl_30_n+asl_35_n+asl_40_n+asl_45_n+asl_50_n+asl_55_n+asl_60_n+asl_65_n+asl_70_n+asl_75_n+asl_80_n+asl_85_n)
asl_4k_n=data_4k_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')

css_total_19=(css_pole_n+css_00+css_05_n+css_10_n+css_15_n+css_20_n+css_25_n+css_30_n+css_35_n+css_40_n+css_45_n+css_50_n+css_55_n+css_60_n+css_65_n+css_70_n+css_75_n+css_80_n+css_85_n)
css_4k_n=data_4k_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')

csl_total_19=(csl_pole_n+csl_00+csl_05_n+csl_10_n+csl_15_n+csl_20_n+csl_25_n+csl_30_n+csl_35_n+csl_40_n+csl_45_n+csl_50_n+csl_55_n+csl_60_n+csl_65_n+csl_70_n+csl_75_n+csl_80_n+csl_85_n)
csl_4k_n=data_4k_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')

# %%
# total clear sky
tcs_pole_n=css_pole_n-csl_pole_n
tcs_00=css_00-csl_00
tcs_05_n=css_05_n-csl_05_n
tcs_10_n=css_10_n-csl_10_n
tcs_15_n=css_15_n-csl_15_n
tcs_20_n=css_20_n-csl_20_n
tcs_25_n=css_25_n-csl_25_n
tcs_30_n=css_30_n-csl_30_n
tcs_35_n=css_35_n-csl_35_n
tcs_40_n=css_40_n-csl_40_n
tcs_45_n=css_45_n-csl_45_n
tcs_50_n=css_50_n-csl_50_n
tcs_55_n=css_55_n-csl_55_n
tcs_60_n=css_60_n-csl_60_n
tcs_65_n=css_65_n-csl_65_n
tcs_70_n=css_70_n-csl_70_n
tcs_75_n=css_75_n-csl_75_n
tcs_80_n=css_80_n-csl_80_n
tcs_85_n=css_85_n-csl_85_n

# total all sky
tas_pole_n=ass_pole_n-asl_pole_n
tas_00=ass_00-asl_00
tas_05_n=ass_05_n-asl_05_n
tas_10_n=ass_10_n-asl_10_n
tas_15_n=ass_15_n-asl_15_n
tas_20_n=ass_20_n-asl_20_n
tas_25_n=ass_25_n-asl_25_n
tas_30_n=ass_30_n-asl_30_n
tas_35_n=ass_35_n-asl_35_n
tas_40_n=ass_40_n-asl_40_n
tas_45_n=ass_45_n-asl_45_n
tas_50_n=ass_50_n-asl_50_n
tas_55_n=ass_55_n-asl_55_n
tas_60_n=ass_60_n-asl_60_n
tas_65_n=ass_65_n-asl_65_n
tas_70_n=ass_70_n-asl_70_n
tas_75_n=ass_75_n-asl_75_n
tas_80_n=ass_80_n-asl_80_n
tas_85_n=ass_85_n-asl_85_n

#total CRE
tCRE_pole_n=CRES_pole_n-CREL_pole_n
tCRE_00=CRES_00-CREL_00
tCRE_05_n=CRES_05_n-CREL_05_n
tCRE_10_n=CRES_10_n-CREL_10_n
tCRE_15_n=CRES_15_n-CREL_15_n
tCRE_20_n=CRES_20_n-CREL_20_n
tCRE_25_n=CRES_25_n-CREL_25_n
tCRE_30_n=CRES_30_n-CREL_30_n
tCRE_35_n=CRES_35_n-CREL_35_n
tCRE_40_n=CRES_40_n-CREL_40_n
tCRE_45_n=CRES_45_n-CREL_45_n
tCRE_50_n=CRES_50_n-CREL_50_n
tCRE_55_n=CRES_55_n-CREL_55_n
tCRE_60_n=CRES_60_n-CREL_60_n
tCRE_65_n=CRES_65_n-CREL_65_n
tCRE_70_n=CRES_70_n-CREL_70_n

tCRE_75_n=CRES_75_n-CREL_75_n
tCRE_80_n=CRES_80_n-CREL_80_n
tCRE_85_n=CRES_85_n-CREL_85_n

tcs_total_19=(tcs_pole_n+tcs_00+tcs_05_n+tcs_10_n+tcs_15_n+tcs_20_n+tcs_25_n+tcs_30_n+tcs_35_n+tcs_40_n+tcs_45_n+tcs_50_n+tcs_55_n+tcs_60_n+tcs_65_n+tcs_70_n+tcs_75_n+tcs_80_n+tcs_85_n)
tcs_4k_n=css_4k_n-csl_4k_n

tas_total_19=(tas_pole_n+tas_00+tas_05_n+tas_10_n+tas_15_n+tas_20_n+tas_25_n+tas_30_n+tas_35_n+tas_40_n+tas_45_n+tas_50_n+tas_55_n+tas_60_n+tas_65_n+tas_70_n+tas_75_n+tas_80_n+tas_85_n)
tas_4k_n=ass_4k_n-asl_4k_n

tCRE_total_19=(tCRE_pole_n+tCRE_00+tCRE_05_n+tCRE_10_n+tCRE_15_n+tCRE_20_n+tCRE_25_n+tCRE_30_n+tCRE_35_n+tCRE_40_n+tCRE_45_n+tCRE_50_n+tCRE_55_n+tCRE_60_n+tCRE_65_n+tCRE_70_n+tCRE_75_n+tCRE_80_n+tCRE_85_n)
tCRE_4k_n=CRES_4k_n-CREL_4k_n

# %%
#clear sky short wave
css_pole_n=data_pole_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_00=data_00.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_05_n=data_05_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_10_n=data_10_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_15_n=data_15_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_20_n=data_20_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_25_n=data_25_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_30_n=data_30_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_35_n=data_35_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_40_n=data_40_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_45_n=data_45_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_50_n=data_50_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_55_n=data_55_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_60_n=data_60_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_65_n=data_65_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_70_n=data_70_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_75_n=data_75_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_80_n=data_80_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_85_n=data_85_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')


#clear sky long wave
csl_pole_n=data_pole_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_00=data_00.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_05_n=data_05_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_10_n=data_10_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_15_n=data_15_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_20_n=data_20_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_25_n=data_25_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_30_n=data_30_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_35_n=data_35_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_40_n=data_40_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_45_n=data_45_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_50_n=data_50_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_55_n=data_55_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_60_n=data_60_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_65_n=data_65_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_70_n=data_70_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_75_n=data_75_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_80_n=data_80_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_85_n=data_85_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')


#all sky short wave
ass_pole_n=data_pole_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_00=data_00.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_05_n=data_05_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_10_n=data_10_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_15_n=data_15_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_20_n=data_20_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_25_n=data_25_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_30_n=data_30_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_35_n=data_35_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_40_n=data_40_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_45_n=data_45_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_50_n=data_50_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_55_n=data_55_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_60_n=data_60_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_65_n=data_65_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_70_n=data_70_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_75_n=data_75_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_80_n=data_80_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_85_n=data_85_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')



#all sky long wave
asl_pole_n=data_pole_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_00=data_00.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_05_n=data_05_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_10_n=data_10_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_15_n=data_15_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_20_n=data_20_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_25_n=data_25_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_30_n=data_30_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_35_n=data_35_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_40_n=data_40_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_45_n=data_45_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_50_n=data_50_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_55_n=data_55_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_60_n=data_60_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_65_n=data_65_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_70_n=data_70_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_75_n=data_75_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_80_n=data_80_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_85_n=data_85_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')



#CRE short wave-zonal
CRES_pole_n = (data_pole_n.FSNT.mean('lon')-data_pole_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_00 = (data_00.FSNT.mean('lon')-data_00.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_05_n = (data_05_n.FSNT.mean('lon')-data_05_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_10_n = (data_10_n.FSNT.mean('lon')-data_10_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_15_n = (data_15_n.FSNT.mean('lon')-data_15_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_20_n = (data_20_n.FSNT.mean('lon')-data_20_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_25_n = (data_25_n.FSNT.mean('lon')-data_25_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_30_n = (data_30_n.FSNT.mean('lon')-data_30_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_35_n = (data_35_n.FSNT.mean('lon')-data_35_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_40_n = (data_40_n.FSNT.mean('lon')-data_40_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_45_n = (data_45_n.FSNT.mean('lon')-data_45_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_50_n = (data_50_n.FSNT.mean('lon')-data_50_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_55_n = (data_55_n.FSNT.mean('lon')-data_55_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_60_n = (data_60_n.FSNT.mean('lon')-data_60_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_65_n = (data_65_n.FSNT.mean('lon')-data_65_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_70_n = (data_70_n.FSNT.mean('lon')-data_70_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_75_n = (data_75_n.FSNT.mean('lon')-data_75_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_80_n = (data_80_n.FSNT.mean('lon')-data_80_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_85_n = (data_85_n.FSNT.mean('lon')-data_85_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))


#CRE long wave-zonal
CREL_pole_n = (data_pole_n.FLNT.mean('lon')-data_pole_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_00 = (data_00.FLNT.mean('lon')-data_00.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_05_n = (data_05_n.FLNT.mean('lon')-data_05_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_10_n = (data_10_n.FLNT.mean('lon')-data_10_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_15_n = (data_15_n.FLNT.mean('lon')-data_15_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_20_n = (data_20_n.FLNT.mean('lon')-data_20_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_25_n = (data_25_n.FLNT.mean('lon')-data_25_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_30_n = (data_30_n.FLNT.mean('lon')-data_30_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_35_n = (data_35_n.FLNT.mean('lon')-data_35_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_40_n = (data_40_n.FLNT.mean('lon')-data_40_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_45_n = (data_45_n.FLNT.mean('lon')-data_45_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_50_n = (data_50_n.FLNT.mean('lon')-data_50_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_55_n = (data_55_n.FLNT.mean('lon')-data_55_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_60_n = (data_60_n.FLNT.mean('lon')-data_60_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_65_n = (data_65_n.FLNT.mean('lon')-data_65_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_70_n = (data_70_n.FLNT.mean('lon')-data_70_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_75_n = (data_75_n.FLNT.mean('lon')-data_75_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_80_n = (data_80_n.FLNT.mean('lon')-data_80_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_85_n = (data_85_n.FLNT.mean('lon')-data_85_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))

# %%
#clear sky short wave
css_pole_s=css_pole_n.assign_coords(lat=list(reversed(data_pole_n.lat)))
css_05_s=css_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))
css_10_s=css_10_n.assign_coords(lat=list(reversed(data_10_n.lat)))
css_15_s=css_15_n.assign_coords(lat=list(reversed(data_15_n.lat)))
css_20_s=css_20_n.assign_coords(lat=list(reversed(data_20_n.lat)))
css_25_s=css_25_n.assign_coords(lat=list(reversed(data_25_n.lat)))
css_30_s=css_30_n.assign_coords(lat=list(reversed(data_30_n.lat)))
css_35_s=css_35_n.assign_coords(lat=list(reversed(data_35_n.lat)))
css_40_s=css_40_n.assign_coords(lat=list(reversed(data_40_n.lat)))
css_45_s=css_45_n.assign_coords(lat=list(reversed(data_45_n.lat)))
css_50_s=css_50_n.assign_coords(lat=list(reversed(data_50_n.lat)))
css_55_s=css_55_n.assign_coords(lat=list(reversed(data_55_n.lat)))
css_60_s=css_60_n.assign_coords(lat=list(reversed(data_60_n.lat)))
css_65_s=css_65_n.assign_coords(lat=list(reversed(data_65_n.lat)))
css_70_s=css_70_n.assign_coords(lat=list(reversed(data_70_n.lat)))
css_75_s=css_75_n.assign_coords(lat=list(reversed(data_75_n.lat)))
css_80_s=css_80_n.assign_coords(lat=list(reversed(data_80_n.lat)))
css_85_s=css_85_n.assign_coords(lat=list(reversed(data_85_n.lat)))


#clear sky long wave
csl_pole_s=csl_pole_n.assign_coords(lat=list(reversed(data_pole_n.lat)))
csl_05_s=csl_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))
csl_10_s=csl_10_n.assign_coords(lat=list(reversed(data_10_n.lat)))
csl_15_s=csl_15_n.assign_coords(lat=list(reversed(data_15_n.lat)))
csl_20_s=csl_20_n.assign_coords(lat=list(reversed(data_20_n.lat)))
csl_25_s=csl_25_n.assign_coords(lat=list(reversed(data_25_n.lat)))
csl_30_s=csl_30_n.assign_coords(lat=list(reversed(data_30_n.lat)))
csl_35_s=csl_35_n.assign_coords(lat=list(reversed(data_35_n.lat)))
csl_40_s=csl_40_n.assign_coords(lat=list(reversed(data_40_n.lat)))
csl_45_s=csl_45_n.assign_coords(lat=list(reversed(data_45_n.lat)))
csl_50_s=csl_50_n.assign_coords(lat=list(reversed(data_50_n.lat)))
csl_55_s=csl_55_n.assign_coords(lat=list(reversed(data_55_n.lat)))
csl_60_s=csl_60_n.assign_coords(lat=list(reversed(data_60_n.lat)))
csl_65_s=csl_65_n.assign_coords(lat=list(reversed(data_65_n.lat)))
csl_70_s=csl_70_n.assign_coords(lat=list(reversed(data_70_n.lat)))
csl_75_s=csl_75_n.assign_coords(lat=list(reversed(data_75_n.lat)))
csl_80_s=csl_80_n.assign_coords(lat=list(reversed(data_80_n.lat)))
csl_85_s=csl_85_n.assign_coords(lat=list(reversed(data_85_n.lat)))


#all sky short wave
ass_pole_s=ass_pole_n.assign_coords(lat=list(reversed(data_pole_n.lat)))
ass_05_s=ass_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))
ass_10_s=ass_10_n.assign_coords(lat=list(reversed(data_10_n.lat)))
ass_15_s=ass_15_n.assign_coords(lat=list(reversed(data_15_n.lat)))
ass_20_s=ass_20_n.assign_coords(lat=list(reversed(data_20_n.lat)))
ass_25_s=ass_25_n.assign_coords(lat=list(reversed(data_25_n.lat)))
ass_30_s=ass_30_n.assign_coords(lat=list(reversed(data_30_n.lat)))
ass_35_s=ass_35_n.assign_coords(lat=list(reversed(data_35_n.lat)))
ass_40_s=ass_40_n.assign_coords(lat=list(reversed(data_40_n.lat)))
ass_45_s=ass_45_n.assign_coords(lat=list(reversed(data_45_n.lat)))
ass_50_s=ass_50_n.assign_coords(lat=list(reversed(data_50_n.lat)))
ass_55_s=ass_55_n.assign_coords(lat=list(reversed(data_55_n.lat)))
ass_60_s=ass_60_n.assign_coords(lat=list(reversed(data_60_n.lat)))
ass_65_s=ass_65_n.assign_coords(lat=list(reversed(data_65_n.lat)))
ass_70_s=ass_70_n.assign_coords(lat=list(reversed(data_70_n.lat)))
ass_75_s=ass_75_n.assign_coords(lat=list(reversed(data_75_n.lat)))
ass_80_s=ass_80_n.assign_coords(lat=list(reversed(data_80_n.lat)))
ass_85_s=ass_85_n.assign_coords(lat=list(reversed(data_85_n.lat)))



#all sky long wave
asl_pole_s=asl_pole_n.assign_coords(lat=list(reversed(data_pole_n.lat)))
asl_05_s=asl_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))
asl_10_s=asl_10_n.assign_coords(lat=list(reversed(data_10_n.lat)))
asl_15_s=asl_15_n.assign_coords(lat=list(reversed(data_15_n.lat)))
asl_20_s=asl_20_n.assign_coords(lat=list(reversed(data_20_n.lat)))
asl_25_s=asl_25_n.assign_coords(lat=list(reversed(data_25_n.lat)))
asl_30_s=asl_30_n.assign_coords(lat=list(reversed(data_30_n.lat)))
asl_35_s=asl_35_n.assign_coords(lat=list(reversed(data_35_n.lat)))
asl_40_s=asl_40_n.assign_coords(lat=list(reversed(data_40_n.lat)))
asl_45_s=asl_45_n.assign_coords(lat=list(reversed(data_45_n.lat)))
asl_50_s=asl_50_n.assign_coords(lat=list(reversed(data_50_n.lat)))
asl_55_s=asl_55_n.assign_coords(lat=list(reversed(data_55_n.lat)))
asl_60_s=asl_60_n.assign_coords(lat=list(reversed(data_60_n.lat)))
asl_65_s=asl_65_n.assign_coords(lat=list(reversed(data_65_n.lat)))
asl_70_s=asl_70_n.assign_coords(lat=list(reversed(data_70_n.lat)))
asl_75_s=asl_75_n.assign_coords(lat=list(reversed(data_75_n.lat)))
asl_80_s=asl_80_n.assign_coords(lat=list(reversed(data_80_n.lat)))
asl_85_s=asl_85_n.assign_coords(lat=list(reversed(data_85_n.lat)))

#CRE short wave-zonal
CRES_pole_s=CRES_pole_n.assign_coords(lat=list(reversed(data_pole_n.lat)))
CRES_05_s=CRES_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))
CRES_10_s=CRES_10_n.assign_coords(lat=list(reversed(data_10_n.lat)))
CRES_15_s=CRES_15_n.assign_coords(lat=list(reversed(data_15_n.lat)))
CRES_20_s=CRES_20_n.assign_coords(lat=list(reversed(data_20_n.lat)))
CRES_25_s=CRES_25_n.assign_coords(lat=list(reversed(data_25_n.lat)))
CRES_30_s=CRES_30_n.assign_coords(lat=list(reversed(data_30_n.lat)))
CRES_35_s=CRES_35_n.assign_coords(lat=list(reversed(data_35_n.lat)))
CRES_40_s=CRES_40_n.assign_coords(lat=list(reversed(data_40_n.lat)))
CRES_45_s=CRES_45_n.assign_coords(lat=list(reversed(data_45_n.lat)))
CRES_50_s=CRES_50_n.assign_coords(lat=list(reversed(data_50_n.lat)))
CRES_55_s=CRES_55_n.assign_coords(lat=list(reversed(data_55_n.lat)))
CRES_60_s=CRES_60_n.assign_coords(lat=list(reversed(data_60_n.lat)))
CRES_65_s=CRES_65_n.assign_coords(lat=list(reversed(data_65_n.lat)))
CRES_70_s=CRES_70_n.assign_coords(lat=list(reversed(data_70_n.lat)))
CRES_75_s=CRES_75_n.assign_coords(lat=list(reversed(data_75_n.lat)))
CRES_80_s=CRES_80_n.assign_coords(lat=list(reversed(data_80_n.lat)))
CRES_85_s=CRES_85_n.assign_coords(lat=list(reversed(data_85_n.lat)))


#CRE long wave-zonal
CREL_pole_s=CREL_pole_n.assign_coords(lat=list(reversed(data_pole_n.lat)))
CREL_05_s=CREL_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))
CREL_10_s=CREL_10_n.assign_coords(lat=list(reversed(data_10_n.lat)))
CREL_15_s=CREL_15_n.assign_coords(lat=list(reversed(data_15_n.lat)))
CREL_20_s=CREL_20_n.assign_coords(lat=list(reversed(data_20_n.lat)))
CREL_25_s=CREL_25_n.assign_coords(lat=list(reversed(data_25_n.lat)))
CREL_30_s=CREL_30_n.assign_coords(lat=list(reversed(data_30_n.lat)))
CREL_35_s=CREL_35_n.assign_coords(lat=list(reversed(data_35_n.lat)))
CREL_40_s=CREL_40_n.assign_coords(lat=list(reversed(data_40_n.lat)))
CREL_45_s=CREL_45_n.assign_coords(lat=list(reversed(data_45_n.lat)))
CREL_50_s=CREL_50_n.assign_coords(lat=list(reversed(data_50_n.lat)))
CREL_55_s=CREL_55_n.assign_coords(lat=list(reversed(data_55_n.lat)))
CREL_60_s=CREL_60_n.assign_coords(lat=list(reversed(data_60_n.lat)))
CREL_65_s=CREL_65_n.assign_coords(lat=list(reversed(data_65_n.lat)))
CREL_70_s=CREL_70_n.assign_coords(lat=list(reversed(data_70_n.lat)))
CREL_75_s=CREL_75_n.assign_coords(lat=list(reversed(data_75_n.lat)))
CREL_80_s=CREL_80_n.assign_coords(lat=list(reversed(data_80_n.lat)))
CREL_85_s=CREL_85_n.assign_coords(lat=list(reversed(data_85_n.lat)))

# %%
CRES_total_NH=(CRES_pole_n+CRES_00+CRES_05_n+CRES_10_n+CRES_15_n+CRES_20_n+CRES_25_n+CRES_30_n+CRES_35_n+CRES_40_n+CRES_45_n+CRES_50_n+\
               CRES_55_n+CRES_60_n+CRES_65_n+CRES_70_n+CRES_75_n+CRES_80_n+CRES_85_n)

CRES_total_SH=(CRES_pole_s+CRES_05_s+CRES_10_s+CRES_15_s+CRES_20_s+CRES_25_s+CRES_30_s+CRES_35_s+CRES_40_s+CRES_45_s+CRES_50_s+CRES_55_s+\
               CRES_60_s+CRES_65_s+CRES_70_s+CRES_75_s+CRES_80_s+CRES_85_s)

CRES_total_ns=CRES_total_NH+CRES_total_SH
CRES_4k=(data_4k.FSNT.mean('lon')-data_4k.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))

CREL_total_NH=(CREL_pole_n+CREL_00+CREL_05_n+CREL_10_n+CREL_15_n+CREL_20_n+CREL_25_n+CREL_30_n+CREL_35_n+CREL_40_n+CREL_45_n+CREL_50_n+\
               CREL_55_n+CREL_60_n+CREL_65_n+CREL_70_n+CREL_75_n+CREL_80_n+CREL_85_n)

CREL_total_SH=(CREL_pole_s+CREL_05_s+CREL_10_s+CREL_15_s+CREL_20_s+CREL_25_s+CREL_30_s+CREL_35_s+CREL_40_s+CREL_45_s+CREL_50_s+CREL_55_s+\
               CREL_60_s+CREL_65_s+CREL_70_s+CREL_75_s+CREL_80_s+CREL_85_s)

CREL_total_ns=CREL_total_NH+CREL_total_SH
CREL_4k=(data_4k.FLNT.mean('lon')-data_4k.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))

ass_total_NH=(ass_pole_n+ass_00+ass_05_n+ass_10_n+ass_15_n+ass_20_n+ass_25_n+ass_30_n+ass_35_n+ass_40_n+ass_45_n+ass_50_n+ass_55_n+\
              ass_60_n+ass_65_n+ass_70_n+ass_75_n+ass_80_n+ass_85_n)

ass_total_SH=(ass_pole_s+ass_05_s+ass_10_s+ass_15_s+ass_20_s+ass_25_s+ass_30_s+ass_35_s+ass_40_s+ass_45_s+ass_50_s+ass_55_s+ass_60_s+\
              ass_65_s+ass_70_s+ass_75_s+ass_80_s+ass_85_s)

ass_total_ns=ass_total_NH+ass_total_SH
ass_4k=data_4k.FSNT.mean('lon')-data_control.FSNT.mean('lon')

asl_total_NH=(asl_pole_n+asl_00+asl_05_n+asl_10_n+asl_15_n+asl_20_n+asl_25_n+asl_30_n+asl_35_n+asl_40_n+asl_45_n+asl_50_n+asl_55_n+asl_60_n+\
              asl_65_n+asl_70_n+asl_75_n+asl_80_n+asl_85_n)

asl_total_SH=(asl_pole_s+asl_05_s+asl_10_s+asl_15_s+asl_20_s+asl_25_s+asl_30_s+asl_35_s+asl_40_s+asl_45_s+asl_50_s+asl_55_s+asl_60_s+asl_65_s+\
              asl_70_s+asl_75_s+asl_80_s+asl_85_s)

asl_total_ns=asl_total_NH+asl_total_SH
asl_4k=data_4k.FLNT.mean('lon')-data_control.FLNT.mean('lon')

css_total_NH=(css_pole_n+css_00+css_05_n+css_10_n+css_15_n+css_20_n+css_25_n+css_30_n+css_35_n+css_40_n+css_45_n+css_50_n+css_55_n+css_60_n+css_65_n+\
              css_70_n+css_75_n+css_80_n+css_85_n)

css_total_SH=(css_pole_s+css_05_s+css_10_s+css_15_s+css_20_s+css_25_s+css_30_s+css_35_s+css_40_s+css_45_s+css_50_s+css_55_s+css_60_s+css_65_s+css_70_s+\
              css_75_s+css_80_s+css_85_s)

css_total_ns=css_total_NH+css_total_SH
css_4k=data_4k.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')

csl_total_NH=(csl_pole_n+csl_00+csl_05_n+csl_10_n+csl_15_n+csl_20_n+csl_25_n+csl_30_n+csl_35_n+csl_40_n+csl_45_n+csl_50_n+csl_55_n+csl_60_n+csl_65_n+\
              csl_70_n+csl_75_n+csl_80_n+csl_85_n)

csl_total_SH=(csl_pole_s+csl_05_s+csl_10_s+csl_15_s+csl_20_s+csl_25_s+csl_30_s+csl_35_s+csl_40_s+csl_45_s+csl_50_s+csl_55_s+csl_60_s+csl_65_s+csl_70_s+\
              csl_75_s+csl_80_s+csl_85_s)

csl_total_ns=csl_total_NH+csl_total_SH
csl_4k=data_4k.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')

# %%
# total clear sky
tcs_pole_n=css_pole_n-csl_pole_n
tcs_00=css_00-csl_00
tcs_05_n=css_05_n-csl_05_n
tcs_10_n=css_10_n-csl_10_n
tcs_15_n=css_15_n-csl_15_n
tcs_20_n=css_20_n-csl_20_n
tcs_25_n=css_25_n-csl_25_n
tcs_30_n=css_30_n-csl_30_n
tcs_35_n=css_35_n-csl_35_n
tcs_40_n=css_40_n-csl_40_n
tcs_45_n=css_45_n-csl_45_n
tcs_50_n=css_50_n-csl_50_n
tcs_55_n=css_55_n-csl_55_n
tcs_60_n=css_60_n-csl_60_n
tcs_65_n=css_65_n-csl_65_n
tcs_70_n=css_70_n-csl_70_n
tcs_75_n=css_75_n-csl_75_n
tcs_80_n=css_80_n-csl_80_n
tcs_85_n=css_85_n-csl_85_n


tcs_pole_s=tcs_pole_n.assign_coords(lat=list(reversed(data_pole_n.lat)))
tcs_05_s=tcs_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))
tcs_10_s=tcs_10_n.assign_coords(lat=list(reversed(data_10_n.lat)))
tcs_15_s=tcs_15_n.assign_coords(lat=list(reversed(data_15_n.lat)))
tcs_20_s=tcs_20_n.assign_coords(lat=list(reversed(data_20_n.lat)))
tcs_25_s=tcs_25_n.assign_coords(lat=list(reversed(data_25_n.lat)))
tcs_30_s=tcs_30_n.assign_coords(lat=list(reversed(data_30_n.lat)))
tcs_35_s=tcs_35_n.assign_coords(lat=list(reversed(data_35_n.lat)))
tcs_40_s=tcs_40_n.assign_coords(lat=list(reversed(data_40_n.lat)))
tcs_45_s=tcs_45_n.assign_coords(lat=list(reversed(data_45_n.lat)))
tcs_50_s=tcs_50_n.assign_coords(lat=list(reversed(data_50_n.lat)))
tcs_55_s=tcs_55_n.assign_coords(lat=list(reversed(data_55_n.lat)))
tcs_60_s=tcs_60_n.assign_coords(lat=list(reversed(data_60_n.lat)))
tcs_65_s=tcs_65_n.assign_coords(lat=list(reversed(data_65_n.lat)))
tcs_70_s=tcs_70_n.assign_coords(lat=list(reversed(data_70_n.lat)))
tcs_75_s=tcs_75_n.assign_coords(lat=list(reversed(data_75_n.lat)))
tcs_80_s=tcs_80_n.assign_coords(lat=list(reversed(data_80_n.lat)))
tcs_85_s=tcs_85_n.assign_coords(lat=list(reversed(data_85_n.lat)))
# total all sky
tas_pole_n=ass_pole_n-asl_pole_n
tas_00=ass_00-asl_00
tas_05_n=ass_05_n-asl_05_n
tas_10_n=ass_10_n-asl_10_n
tas_15_n=ass_15_n-asl_15_n
tas_20_n=ass_20_n-asl_20_n
tas_25_n=ass_25_n-asl_25_n
tas_30_n=ass_30_n-asl_30_n
tas_35_n=ass_35_n-asl_35_n
tas_40_n=ass_40_n-asl_40_n
tas_45_n=ass_45_n-asl_45_n
tas_50_n=ass_50_n-asl_50_n
tas_55_n=ass_55_n-asl_55_n
tas_60_n=ass_60_n-asl_60_n
tas_65_n=ass_65_n-asl_65_n
tas_70_n=ass_70_n-asl_70_n
tas_75_n=ass_75_n-asl_75_n
tas_80_n=ass_80_n-asl_80_n
tas_85_n=ass_85_n-asl_85_n


tas_pole_s=tas_pole_n.assign_coords(lat=list(reversed(data_pole_n.lat)))
tas_05_s=tas_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))
tas_10_s=tas_10_n.assign_coords(lat=list(reversed(data_10_n.lat)))
tas_15_s=tas_15_n.assign_coords(lat=list(reversed(data_15_n.lat)))
tas_20_s=tas_20_n.assign_coords(lat=list(reversed(data_20_n.lat)))
tas_25_s=tas_25_n.assign_coords(lat=list(reversed(data_25_n.lat)))
tas_30_s=tas_30_n.assign_coords(lat=list(reversed(data_30_n.lat)))
tas_35_s=tas_35_n.assign_coords(lat=list(reversed(data_35_n.lat)))
tas_40_s=tas_40_n.assign_coords(lat=list(reversed(data_40_n.lat)))
tas_45_s=tas_45_n.assign_coords(lat=list(reversed(data_45_n.lat)))
tas_50_s=tas_50_n.assign_coords(lat=list(reversed(data_50_n.lat)))
tas_55_s=tas_55_n.assign_coords(lat=list(reversed(data_55_n.lat)))
tas_60_s=tas_60_n.assign_coords(lat=list(reversed(data_60_n.lat)))
tas_65_s=tas_65_n.assign_coords(lat=list(reversed(data_65_n.lat)))
tas_70_s=tas_70_n.assign_coords(lat=list(reversed(data_70_n.lat)))
tas_75_s=tas_75_n.assign_coords(lat=list(reversed(data_75_n.lat)))
tas_80_s=tas_80_n.assign_coords(lat=list(reversed(data_80_n.lat)))
tas_85_s=tas_85_n.assign_coords(lat=list(reversed(data_85_n.lat)))

#total CRE
tCRE_pole_n=CRES_pole_n-CREL_pole_n
tCRE_00=CRES_00-CREL_00
tCRE_05_n=CRES_05_n-CREL_05_n
tCRE_10_n=CRES_10_n-CREL_10_n
tCRE_15_n=CRES_15_n-CREL_15_n
tCRE_20_n=CRES_20_n-CREL_20_n
tCRE_25_n=CRES_25_n-CREL_25_n
tCRE_30_n=CRES_30_n-CREL_30_n
tCRE_35_n=CRES_35_n-CREL_35_n
tCRE_40_n=CRES_40_n-CREL_40_n
tCRE_45_n=CRES_45_n-CREL_45_n
tCRE_50_n=CRES_50_n-CREL_50_n
tCRE_55_n=CRES_55_n-CREL_55_n
tCRE_60_n=CRES_60_n-CREL_60_n
tCRE_65_n=CRES_65_n-CREL_65_n
tCRE_70_n=CRES_70_n-CREL_70_n
tCRE_75_n=CRES_75_n-CREL_75_n
tCRE_80_n=CRES_80_n-CREL_80_n
tCRE_85_n=CRES_85_n-CREL_85_n

tCRE_pole_s=tCRE_pole_n.assign_coords(lat=list(reversed(data_pole_n.lat)))
tCRE_05_s=tCRE_05_n.assign_coords(lat=list(reversed(data_05_n.lat)))
tCRE_10_s=tCRE_10_n.assign_coords(lat=list(reversed(data_10_n.lat)))
tCRE_15_s=tCRE_15_n.assign_coords(lat=list(reversed(data_15_n.lat)))
tCRE_20_s=tCRE_20_n.assign_coords(lat=list(reversed(data_20_n.lat)))
tCRE_25_s=tCRE_25_n.assign_coords(lat=list(reversed(data_25_n.lat)))
tCRE_30_s=tCRE_30_n.assign_coords(lat=list(reversed(data_30_n.lat)))
tCRE_35_s=tCRE_35_n.assign_coords(lat=list(reversed(data_35_n.lat)))
tCRE_40_s=tCRE_40_n.assign_coords(lat=list(reversed(data_40_n.lat)))
tCRE_45_s=tCRE_45_n.assign_coords(lat=list(reversed(data_45_n.lat)))
tCRE_50_s=tCRE_50_n.assign_coords(lat=list(reversed(data_50_n.lat)))
tCRE_55_s=tCRE_55_n.assign_coords(lat=list(reversed(data_55_n.lat)))
tCRE_60_s=tCRE_60_n.assign_coords(lat=list(reversed(data_60_n.lat)))
tCRE_65_s=tCRE_65_n.assign_coords(lat=list(reversed(data_65_n.lat)))
tCRE_70_s=tCRE_70_n.assign_coords(lat=list(reversed(data_70_n.lat)))
tCRE_75_s=tCRE_75_n.assign_coords(lat=list(reversed(data_75_n.lat)))
tCRE_80_s=tCRE_80_n.assign_coords(lat=list(reversed(data_80_n.lat)))
tCRE_85_s=tCRE_85_n.assign_coords(lat=list(reversed(data_85_n.lat)))


tcs_total_NH=(tcs_pole_n+tcs_00+tcs_05_n+tcs_10_n+tcs_15_n+tcs_20_n+tcs_25_n+tcs_30_n+tcs_35_n+tcs_40_n+tcs_45_n+tcs_50_n+\
              tcs_55_n+tcs_60_n+tcs_65_n+tcs_70_n+tcs_75_n+tcs_80_n+tcs_85_n)
tcs_total_SH=(tcs_pole_s+tcs_05_s+tcs_10_s+tcs_15_s+tcs_20_s+tcs_25_s+tcs_30_s+tcs_35_s+tcs_40_s+tcs_45_s+tcs_50_s+tcs_55_s+\
              tcs_60_s+tcs_65_s+tcs_70_s+tcs_75_s+tcs_80_s+tcs_85_s)
tcs_total_ns=tcs_total_NH+tcs_total_SH
tcs_4k=css_4k-csl_4k

tas_total_NH=(tas_pole_n+tas_00+tas_05_n+tas_10_n+tas_15_n+tas_20_n+tas_25_n+tas_30_n+tas_35_n+tas_40_n+tas_45_n+tas_50_n+\
              tas_55_n+tas_60_n+tas_65_n+tas_70_n+tas_75_n+tas_80_n+tas_85_n)
tas_total_SH=(tas_pole_s+tas_05_s+tas_10_s+tas_15_s+tas_20_s+tas_25_s+tas_30_s+tas_35_s+tas_40_s+tas_45_s+tas_50_s+tas_55_s+\
              tas_60_s+tas_65_s+tas_70_s+tas_75_s+tas_80_s+tas_85_s)
tas_total_ns=tas_total_NH+tas_total_SH
tas_4k=ass_4k-asl_4k

tCRE_total_NH=(tCRE_pole_n+tCRE_00+tCRE_05_n+tCRE_10_n+tCRE_15_n+tCRE_20_n+tCRE_25_n+tCRE_30_n+tCRE_35_n+tCRE_40_n+tCRE_45_n+\
               tCRE_50_n+tCRE_55_n+tCRE_60_n+tCRE_65_n+tCRE_70_n+tCRE_75_n+tCRE_80_n+tCRE_85_n)
tCRE_total_SH=(tCRE_pole_s+tCRE_05_s+tCRE_10_s+tCRE_15_s+tCRE_20_s+tCRE_25_s+tCRE_30_s+tCRE_35_s+tCRE_40_s+tCRE_45_s+tCRE_50_s+\
               tCRE_55_s+tCRE_60_s+tCRE_65_s+tCRE_70_s+tCRE_75_s+tCRE_80_s+tCRE_85_s)
tCRE_total_ns=tCRE_total_NH+tCRE_total_SH
tCRE_4k=CRES_4k-CREL_4k

# %%
css_05_n=data_05_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_05_s=data_05_s.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')

css_05_ns=css_05_n+css_05_s
css_05=data_05.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')

csl_05_n=data_05_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_05_s=data_05_s.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')

csl_05_ns=csl_05_n+csl_05_s
csl_05=data_05.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')

ass_05_n=data_05_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_05_s=data_05_s.FSNT.mean('lon')-data_control.FSNT.mean('lon')

ass_05_ns=ass_05_n+ass_05_s
ass_05=data_05.FSNT.mean('lon')-data_control.FSNT.mean('lon')

asl_05_n=data_05_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_05_s=data_05_s.FLNT.mean('lon')-data_control.FLNT.mean('lon')

asl_05_ns=asl_05_n+asl_05_s
asl_05=data_05.FLNT.mean('lon')-data_control.FLNT.mean('lon')

CRES_05_n = (data_05_n.FSNT.mean('lon')-data_05_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_05_s = (data_05_s.FSNT.mean('lon')-data_05_s.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))

CRES_05_ns=CRES_05_n+CRES_05_s
CRES_05 = (data_05.FSNT.mean('lon')-data_05.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))

CREL_05_n = (data_05_n.FLNT.mean('lon')-data_05_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_05_s = (data_05_s.FLNT.mean('lon')-data_05_s.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))

CREL_05_ns=CREL_05_n+CREL_05_s
CREL_05 = (data_05.FLNT.mean('lon')-data_05.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))

# %%
tcs_05_n=css_05_n-csl_05_n
tcs_05_s=css_05_s-csl_05_s

tcs_05_ns=tcs_05_n+tcs_05_s
tcs_05=css_05-csl_05

tas_05_n=ass_05_n-asl_05_n
tas_05_s=ass_05_s-asl_05_s

tas_05_ns=tas_05_n+tas_05_s
tas_05=ass_05-asl_05

tCRE_05_n=CRES_05_n-CREL_05_n
tCRE_05_s=CRES_05_s-CREL_05_s

tCRE_05_ns=tCRE_05_n+tCRE_05_s
tCRE_05=CRES_05-CREL_05

# %%
css_10_n=data_10_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_10_s=data_10_s.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')

css_10_ns=css_10_n+css_10_s
css_10=data_10.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')

csl_10_n=data_10_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_10_s=data_10_s.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')

csl_10_ns=csl_10_n+csl_10_s
csl_10=data_10.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')

ass_10_n=data_10_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_10_s=data_10_s.FSNT.mean('lon')-data_control.FSNT.mean('lon')

ass_10_ns=ass_10_n+ass_10_s
ass_10=data_10.FSNT.mean('lon')-data_control.FSNT.mean('lon')

asl_10_n=data_10_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_10_s=data_10_s.FLNT.mean('lon')-data_control.FLNT.mean('lon')

asl_10_ns=asl_10_n+asl_10_s
asl_10=data_10.FLNT.mean('lon')-data_control.FLNT.mean('lon')

CRES_10_n = (data_10_n.FSNT.mean('lon')-data_10_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_10_s = (data_10_s.FSNT.mean('lon')-data_10_s.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))

CRES_10_ns=CRES_10_n+CRES_10_s
CRES_10 = (data_10.FSNT.mean('lon')-data_10.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))

CREL_10_n = (data_10_n.FLNT.mean('lon')-data_10_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_10_s = (data_10_s.FLNT.mean('lon')-data_10_s.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))

CREL_10_ns=CREL_10_n+CREL_10_s
CREL_10 = (data_10.FLNT.mean('lon')-data_10.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))

# %%
tcs_10_n=css_10_n-csl_10_n
tcs_10_s=css_10_s-csl_10_s

tcs_10_ns=tcs_10_n+tcs_10_s
tcs_10=css_10-csl_10

tas_10_n=ass_10_n-asl_10_n
tas_10_s=ass_10_s-asl_10_s

tas_10_ns=tas_10_n+tas_10_s
tas_10=ass_10-asl_10

tCRE_10_n=CRES_10_n-CREL_10_n
tCRE_10_s=CRES_10_s-CREL_10_s

tCRE_10_ns=tCRE_10_n+tCRE_10_s
tCRE_10=CRES_10-CREL_10

# %%
css_15_n=data_15_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_15_s=data_15_s.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')

css_15_ns=css_15_n+css_15_s
css_15=data_15.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')

csl_15_n=data_15_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_15_s=data_15_s.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')

csl_15_ns=csl_15_n+csl_15_s
csl_15=data_15.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')

ass_15_n=data_15_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_15_s=data_15_s.FSNT.mean('lon')-data_control.FSNT.mean('lon')

ass_15_ns=ass_15_n+ass_15_s
ass_15=data_15.FSNT.mean('lon')-data_control.FSNT.mean('lon')

asl_15_n=data_15_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_15_s=data_15_s.FLNT.mean('lon')-data_control.FLNT.mean('lon')

asl_15_ns=asl_15_n+asl_15_s
asl_15=data_15.FLNT.mean('lon')-data_control.FLNT.mean('lon')

CRES_15_n = (data_15_n.FSNT.mean('lon')-data_15_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_15_s = (data_15_s.FSNT.mean('lon')-data_15_s.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))

CRES_15_ns=CRES_15_n+CRES_15_s
CRES_15 = (data_15.FSNT.mean('lon')-data_15.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))

CREL_15_n = (data_15_n.FLNT.mean('lon')-data_15_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_15_s = (data_15_s.FLNT.mean('lon')-data_15_s.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))

CREL_15_ns=CREL_15_n+CREL_15_s
CREL_15 = (data_15.FLNT.mean('lon')-data_15.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))

# %%
tcs_15_n=css_15_n-csl_15_n
tcs_15_s=css_15_s-csl_15_s

tcs_15_ns=tcs_15_n+tcs_15_s
tcs_15=css_15-csl_15

tas_15_n=ass_15_n-asl_15_n
tas_15_s=ass_15_s-asl_15_s

tas_15_ns=tas_15_n+tas_15_s
tas_15=ass_15-asl_15

tCRE_15_n=CRES_15_n-CREL_15_n
tCRE_15_s=CRES_15_s-CREL_15_s

tCRE_15_ns=tCRE_15_n+tCRE_15_s
tCRE_15=CRES_15-CREL_15

# %%
wcss_50_n=wdata_50_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
wcss_50_s=wdata_50_s.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')

wcss_50_ns=wcss_50_n+wcss_50_s
wcss_50=wdata_50.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')

wcsl_50_n=wdata_50_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
wcsl_50_s=wdata_50_s.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')

wcsl_50_ns=wcsl_50_n+wcsl_50_s
wcsl_50=wdata_50.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')

wass_50_n=wdata_50_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
wass_50_s=wdata_50_s.FSNT.mean('lon')-data_control.FSNT.mean('lon')

wass_50_ns=wass_50_n+wass_50_s
wass_50=wdata_50.FSNT.mean('lon')-data_control.FSNT.mean('lon')

wasl_50_n=wdata_50_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
wasl_50_s=wdata_50_s.FLNT.mean('lon')-data_control.FLNT.mean('lon')

wasl_50_ns=wasl_50_n+wasl_50_s
wasl_50=wdata_50.FLNT.mean('lon')-data_control.FLNT.mean('lon')

wCRES_50_n = (wdata_50_n.FSNT.mean('lon')-wdata_50_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
wCRES_50_s = (wdata_50_s.FSNT.mean('lon')-wdata_50_s.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))

wCRES_50_ns=wCRES_50_n+wCRES_50_s
wCRES_50 = (wdata_50.FSNT.mean('lon')-wdata_50.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))

wCREL_50_n = (wdata_50_n.FLNT.mean('lon')-wdata_50_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
wCREL_50_s = (wdata_50_s.FLNT.mean('lon')-wdata_50_s.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))

wCREL_50_ns=wCREL_50_n+wCREL_50_s
wCREL_50 = (wdata_50.FLNT.mean('lon')-wdata_50.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))

# %%
wtcs_50_n=wcss_50_n-wcsl_50_n
wtcs_50_s=wcss_50_s-wcsl_50_s

wtcs_50_ns=wtcs_50_n+wtcs_50_s
wtcs_50=wcss_50-wcsl_50

wtas_50_n=wass_50_n-wasl_50_n
wtas_50_s=wass_50_s-wasl_50_s

wtas_50_ns=wtas_50_n+wtas_50_s
wtas_50=wass_50-wasl_50

wtCRE_50_n=wCRES_50_n-wCREL_50_n
wtCRE_50_s=wCRES_50_s-wCREL_50_s

wtCRE_50_ns=wtCRE_50_n+wtCRE_50_s
wtCRE_50=wCRES_50-wCREL_50

# %%
#clear sky short wave
wcss_00=wdata_00.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
wcss_25_n=wdata_25_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
wcss_25_s=wcss_25_n.assign_coords(lat=list(reversed(wdata_25_n.lat)))
wcss_50_n=wdata_50_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
wcss_50_s=wcss_50_n.assign_coords(lat=list(reversed(wdata_50_n.lat)))
wcss_75_n=wdata_75_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
wcss_75_s=wcss_75_n.assign_coords(lat=list(reversed(wdata_75_n.lat)))
wcss_100_n=wdata_100_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
wcss_100_s=wcss_100_n.assign_coords(lat=list(reversed(wdata_100_n.lat)))
wcss_125_n=wdata_125_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
wcss_125_s=wcss_125_n.assign_coords(lat=list(reversed(wdata_125_n.lat)))

css_total_wide=wcss_00+wcss_25_n+wcss_25_s+wcss_50_n+wcss_50_s+wcss_75_n+wcss_75_s+wcss_100_n+wcss_100_s+wcss_125_n+wcss_125_s
css_Exp_4k=data_4k.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')




#clear sky long wave
wcsl_00=wdata_00.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
wcsl_25_n=wdata_25_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
wcsl_25_s=wcsl_25_n.assign_coords(lat=list(reversed(wdata_25_n.lat)))
wcsl_50_n=wdata_50_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
wcsl_50_s=wcsl_50_n.assign_coords(lat=list(reversed(wdata_50_n.lat)))
wcsl_75_n=wdata_75_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
wcsl_75_s=wcsl_75_n.assign_coords(lat=list(reversed(wdata_75_n.lat)))
wcsl_100_n=wdata_100_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
wcsl_100_s=wcsl_100_n.assign_coords(lat=list(reversed(wdata_100_n.lat)))
wcsl_125_n=wdata_125_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
wcsl_125_s=wcsl_125_n.assign_coords(lat=list(reversed(wdata_125_n.lat)))

csl_total_wide=wcsl_00+wcsl_25_n+wcsl_25_s+wcsl_50_n+wcsl_50_s+wcsl_75_n+wcsl_75_s+wcsl_100_n+wcsl_100_s+wcsl_125_n+wcsl_125_s
csl_Exp_4k=data_4k.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')




#all sky short wave
wass_00=wdata_00.FSNT.mean('lon')-data_control.FSNT.mean('lon')
wass_25_n=wdata_25_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
wass_25_s=wass_25_n.assign_coords(lat=list(reversed(wdata_25_n.lat)))
wass_50_n=wdata_50_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
wass_50_s=wass_50_n.assign_coords(lat=list(reversed(wdata_50_n.lat)))
wass_75_n=wdata_75_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
wass_75_s=wass_75_n.assign_coords(lat=list(reversed(wdata_75_n.lat)))
wass_100_n=wdata_100_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
wass_100_s=wass_100_n.assign_coords(lat=list(reversed(wdata_100_n.lat)))
wass_125_n=wdata_125_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
wass_125_s=wass_125_n.assign_coords(lat=list(reversed(wdata_125_n.lat)))

ass_total_wide=wass_00+wass_25_n+wass_25_s+wass_50_n+wass_50_s+wass_75_n+wass_75_s+wass_100_n+wass_100_s+wass_125_n+wass_125_s
ass_Exp_4k=data_4k.FSNT.mean('lon')-data_control.FSNT.mean('lon')




#all sky long wave
wasl_00=wdata_00.FLNT.mean('lon')-data_control.FLNT.mean('lon')
wasl_25_n=wdata_25_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
wasl_25_s=wasl_25_n.assign_coords(lat=list(reversed(wdata_25_n.lat)))
wasl_50_n=wdata_50_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
wasl_50_s=wasl_50_n.assign_coords(lat=list(reversed(wdata_50_n.lat)))
wasl_75_n=wdata_75_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
wasl_75_s=wasl_75_n.assign_coords(lat=list(reversed(wdata_75_n.lat)))
wasl_100_n=wdata_100_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
wasl_100_s=wasl_100_n.assign_coords(lat=list(reversed(wdata_100_n.lat)))
wasl_125_n=wdata_125_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
wasl_125_s=wasl_125_n.assign_coords(lat=list(reversed(wdata_125_n.lat)))

asl_total_wide=wasl_00+wasl_25_n+wasl_25_s+wasl_50_n+wasl_50_s+wasl_75_n+wasl_75_s+wasl_100_n+wasl_100_s+wasl_125_n+wasl_125_s
asl_Exp_4k=data_4k.FLNT.mean('lon')-data_control.FLNT.mean('lon')




#CRE short wave-zonal
wCRES_00 = (wdata_00.FSNT.mean('lon')-wdata_00.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
wCRES_25_n = (wdata_25_n.FSNT.mean('lon')-wdata_25_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
wCRES_25_s=wCRES_25_n.assign_coords(lat=list(reversed(wdata_25_n.lat)))
wCRES_50_n = (wdata_50_n.FSNT.mean('lon')-wdata_50_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
wCRES_50_s=wCRES_50_n.assign_coords(lat=list(reversed(wdata_50_n.lat)))
wCRES_75_n = (wdata_75_n.FSNT.mean('lon')-wdata_75_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
wCRES_75_s=wCRES_75_n.assign_coords(lat=list(reversed(wdata_75_n.lat)))
wCRES_100_n = (wdata_100_n.FSNT.mean('lon')-wdata_100_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
wCRES_100_s=wCRES_100_n.assign_coords(lat=list(reversed(wdata_100_n.lat)))
wCRES_125_n = (wdata_125_n.FSNT.mean('lon')-wdata_125_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
wCRES_125_s=wCRES_125_n.assign_coords(lat=list(reversed(wdata_125_n.lat)))

CRES_total_wide=wCRES_00+wCRES_25_n+wCRES_25_s+wCRES_50_n+wCRES_50_s+wCRES_75_n+wCRES_75_s+wCRES_100_n+wCRES_100_s+wCRES_125_n+wCRES_125_s
CRES_Exp_4k=(data_4k.FSNT.mean('lon')-data_4k.FSNTC.mean('lon'))-\
                    (data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))



#CRE Long wave-zonal
wCREL_00 = (wdata_00.FLNT.mean('lon')-wdata_00.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
wCREL_25_n = (wdata_25_n.FLNT.mean('lon')-wdata_25_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
wCREL_25_s=wCREL_25_n.assign_coords(lat=list(reversed(wdata_25_n.lat)))
wCREL_50_n = (wdata_50_n.FLNT.mean('lon')-wdata_50_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
wCREL_50_s=wCREL_50_n.assign_coords(lat=list(reversed(wdata_50_n.lat)))
wCREL_75_n = (wdata_75_n.FLNT.mean('lon')-wdata_75_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
wCREL_75_s=wCREL_75_n.assign_coords(lat=list(reversed(wdata_75_n.lat)))
wCREL_100_n = (wdata_100_n.FLNT.mean('lon')-wdata_100_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
wCREL_100_s=wCREL_100_n.assign_coords(lat=list(reversed(data_100_n.lat)))
wCREL_125_n = (wdata_125_n.FLNT.mean('lon')-wdata_125_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
wCREL_125_s=wCREL_125_n.assign_coords(lat=list(reversed(wdata_125_n.lat)))

CREL_total_wide=wCREL_00+wCREL_25_n+wCREL_25_s+wCREL_50_n+wCREL_50_s+wCREL_75_n+wCREL_75_s+wCREL_100_n+wCREL_100_s+wCREL_125_n+wCREL_125_s
CREL_Exp_4k=(data_4k.FLNT.mean('lon')-data_4k.FLNTC.mean('lon'))-\
                    (data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))

# %%
# total clear sky
wtcs_00=wcss_00-wcsl_00
wtcs_25_n=wcss_25_n-wcsl_25_n
wtcs_25_s=wtcs_25_n.assign_coords(lat=list(reversed(wdata_25_n.lat)))
wtcs_50_n=wcss_50_n-wcsl_50_n
wtcs_50_s=wtcs_50_n.assign_coords(lat=list(reversed(wdata_50_n.lat)))
wtcs_75_n=wcss_75_n-wcsl_75_n
wtcs_75_s=wtcs_75_n.assign_coords(lat=list(reversed(wdata_75_n.lat)))
wtcs_100_n=wcss_100_n-wcsl_100_n
wtcs_100_s=wtcs_100_n.assign_coords(lat=list(reversed(wdata_100_n.lat)))
wtcs_125_n=wcss_125_n-wcsl_125_n
wtcs_125_s=wtcs_125_n.assign_coords(lat=list(reversed(wdata_125_n.lat)))

# total all sky
wtas_00=wass_00-wasl_00
wtas_25_n=wass_25_n-wasl_25_n
wtas_25_s=wtas_25_n.assign_coords(lat=list(reversed(wdata_25_n.lat)))
wtas_50_n=wass_50_n-wasl_50_n
wtas_50_s=wtas_50_n.assign_coords(lat=list(reversed(wdata_50_n.lat)))
wtas_75_n=wass_75_n-wasl_75_n
wtas_75_s=wtas_75_n.assign_coords(lat=list(reversed(wdata_75_n.lat)))
wtas_100_n=wass_100_n-wasl_100_n
wtas_100_s=wtas_100_n.assign_coords(lat=list(reversed(wdata_100_n.lat)))
wtas_125_n=wass_125_n-wasl_125_n
wtas_125_s=wtas_125_n.assign_coords(lat=list(reversed(wdata_125_n.lat)))


#total CRE
wtCRE_00=wCRES_00-wCREL_00
wtCRE_25_n=wCRES_25_n-wCREL_25_n
wtCRE_25_s=wtCRE_25_n.assign_coords(lat=list(reversed(wdata_25_n.lat)))
wtCRE_50_n=wCRES_50_n-wCREL_50_n
wtCRE_50_s=wtCRE_50_n.assign_coords(lat=list(reversed(wdata_50_n.lat)))
wtCRE_75_n=wCRES_75_n-wCREL_75_n
wtCRE_75_s=wtCRE_75_n.assign_coords(lat=list(reversed(wdata_75_n.lat)))
wtCRE_100_n=wCRES_100_n-wCREL_100_n
wtCRE_100_s=wtCRE_100_n.assign_coords(lat=list(reversed(wdata_100_n.lat)))
wtCRE_125_n=wCRES_125_n-wCREL_125_n
wtCRE_125_s=wtCRE_125_n.assign_coords(lat=list(reversed(wdata_125_n.lat)))

tcs_total_wide=wtcs_00+wtcs_25_n+wtcs_25_s+wtcs_50_n+wtcs_50_s+wtcs_75_n+wtcs_75_s+wtcs_100_n+wtcs_100_s+wtcs_125_n+wtcs_125_s
tcs_Exp_4k=css_Exp_4k-csl_Exp_4k

tas_total_wide=wtas_00+wtas_25_n+wtas_25_s+wtas_50_n+wtas_50_s+wtas_75_n+wtas_75_s+wtas_100_n+wtas_100_s+wtas_125_n+wtas_125_s
tas_Exp_4k=ass_Exp_4k-asl_Exp_4k

tCRE_total_wide=wtCRE_00+wtCRE_25_s+wtCRE_25_n+wtCRE_50_s+wtCRE_50_n+wtCRE_75_s+wtCRE_75_n+wtCRE_100_s+wtCRE_100_n+wtCRE_125_s+wtCRE_125_n
tCRE_Exp_4k=CRES_Exp_4k-CREL_Exp_4k

# %%
nrow = 1
ncol = 3
fig = plt.figure(figsize=(18, 8))
grid = ImageGrid(fig, 
                 111, # as in plt.subplot(111)
                 nrows_ncols=(nrow,ncol),
                 axes_pad=0,
                 share_all=True,)

#for i in range(1):
#    for j in range(2):
im = np.random.rand(28,28)
gs = gridspec.GridSpec(3, 9)
gs.update(wspace=0,hspace=0.1)

plt.subplot(gs[0,0])
tCRE_total_5.plot(label='Sum_5Exp')
tCRE_Exp_10s_5s_00_5n_10n.plot(label='Exp_10s_5s_00_5n_10n')
plt.legend(loc='upper center',borderpad=0.1,fontsize="6")
#plt.title('TOA flux')
plt.ylabel('CRE/W/m2')
ax = pylab.gca()
ax.xaxis.set_visible(False)
plt.xlabel('')
plt.ylim(-40,20)

plt.subplot(gs[0,1])
tCRE_total_3.plot(label='Sum_3Exp')
tCRE_Exp_5s_00_5n.plot(label='Exp_5s_00_5n')
plt.legend(loc='upper center',borderpad=0.1,fontsize="6")
#plt.title('TOA flux')
plt.ylabel('W/m2')
ax = pylab.gca()
ax.yaxis.set_visible(False)
ax.xaxis.set_visible(False)
plt.xlabel('')
plt.ylim(-40,20)

plt.subplot(gs[0,2])
tCRE_total_19.plot(label='Sum')
tCRE_4k_n.plot(label='4k_NH')
plt.legend(loc='upper center',borderpad=0.1,fontsize="6")
#plt.title('TOA flux')
ax = pylab.gca()
ax.yaxis.set_visible(False)
ax.xaxis.set_visible(False)
plt.xlabel('')
plt.ylim(-40,20)


plt.subplot(gs[0,3])
tCRE_total_ns.plot(label='Sum')
tCRE_4k.plot(label='4k')
plt.legend(loc='upper center',borderpad=0.1,fontsize="6")
#plt.ylabel("W/m2")
ax = pylab.gca()
ax.yaxis.set_visible(False)
ax.xaxis.set_visible(False)
plt.xlabel('')
plt.ylim(-40,20)


plt.subplot(gs[0,4])
tCRE_total_wide.plot(label='Sum_Wide')
tCRE_Exp_4k.plot(label='4k')
plt.legend(loc='upper center',borderpad=0.1,fontsize="6")
#plt.ylabel("W/m2")
ax = pylab.gca()
ax.yaxis.set_visible(False)
ax.xaxis.set_visible(False)
plt.xlabel('')
plt.ylim(-40,20)

plt.subplot(gs[0,5])
tCRE_05_ns.plot(label='5_ns')
tCRE_05.plot(label='5')
plt.legend(loc='upper center',borderpad=0.1,fontsize="6")
ax = pylab.gca()
ax.yaxis.set_visible(False)
ax.xaxis.set_visible(False)
plt.xlabel('')
plt.ylim(-40,20)

#plt.legend(loc='upper left')
#plt.title('TOA flux')
plt.subplot(gs[0,6])
tCRE_10_ns.plot(label='10_ns')
tCRE_10.plot(label='10')
plt.legend(loc='upper center',borderpad=0.1,fontsize="6")
ax = pylab.gca()
ax.yaxis.set_visible(False)
ax.xaxis.set_visible(False)
plt.xlabel('')
plt.ylim(-40,20)

#plt.legend(loc='upper left')
#plt.title('TOA flux')
plt.subplot(gs[0,7])
tCRE_15_ns.plot(label='15_ns')
tCRE_15.plot(label='15')
plt.legend(loc='upper center',borderpad=0.1,fontsize="6")
ax = pylab.gca()
ax.yaxis.set_visible(False)
ax.xaxis.set_visible(False)
plt.xlabel('')
plt.ylim(-40,20)

#plt.legend(loc='upper left')
#plt.title('TOA flux')
plt.subplot(gs[0,8])
wtCRE_50_ns.plot(label='50_ns')
wtCRE_50.plot(label='50')
plt.legend(loc='upper center',borderpad=0.1,fontsize="6")
ax = pylab.gca()
ax.yaxis.set_visible(False)
ax.xaxis.set_visible(False)
plt.xlabel('')
plt.ylim(-40,20)









plt.subplot(gs[1,0])
tas_total_5.plot(label='Sum_5Exp')
tas_Exp_10s_5s_00_5n_10n.plot(label='Exp_10s_5s_00_5n_10n')
plt.legend(loc='upper center',borderpad=0.1,fontsize="6")
#plt.title('TOA flux')
plt.xlabel('')
plt.ylabel('All_Sky/W/m2')
ax = pylab.gca()
ax.xaxis.set_visible(False)
plt.xlabel('')
plt.ylim(-60,20)

plt.subplot(gs[1,1])
tas_total_3.plot(label='Sum_3Exp')
tas_Exp_5s_00_5n.plot(label='Exp_5s_00_5n')
plt.legend(loc='upper center',borderpad=0.1,fontsize="6")
#plt.title('TOA flux')
plt.ylabel('W/m2')
ax = pylab.gca()
ax.yaxis.set_visible(False)
ax.xaxis.set_visible(False)
plt.xlabel('')
plt.ylim(-60,20)

plt.subplot(gs[1,2])
tas_total_19.plot(label='Sum')
tas_4k_n.plot(label='4k_NH')
plt.legend(loc='upper center',borderpad=0.1,fontsize="6")
#plt.title('TOA flux')
ax = pylab.gca()
ax.yaxis.set_visible(False)
ax.xaxis.set_visible(False)
plt.xlabel('')
plt.ylim(-60,20)


plt.subplot(gs[1,3])
tas_total_ns.plot(label='sum')
tas_4k.plot(label='4k')
plt.legend(loc='upper center',borderpad=0.1,fontsize="6")
#plt.ylabel("W/m2")
ax = pylab.gca()
ax.yaxis.set_visible(False)
ax.xaxis.set_visible(False)
plt.xlabel('')
plt.ylim(-60,20)


plt.subplot(gs[1,4])
tas_total_wide.plot(label='Sum_Wide')
tas_Exp_4k.plot(label='4k')
plt.legend(loc='upper center',borderpad=0.1,fontsize="6")
#plt.ylabel("W/m2")
ax = pylab.gca()
ax.yaxis.set_visible(False)
ax.xaxis.set_visible(False)
plt.xlabel('')
plt.ylim(-60,20)

plt.subplot(gs[1,5])
tas_05_ns.plot(label='5_ns')
tas_05.plot(label='5')
plt.legend(loc='upper center',borderpad=0.1,fontsize="6")
ax = pylab.gca()
ax.yaxis.set_visible(False)
ax.xaxis.set_visible(False)
plt.xlabel('')
plt.ylim(-60,20)

#plt.legend(loc='upper left')
#plt.title('TOA flux')
plt.subplot(gs[1,6])
tas_10_ns.plot(label='10_ns')
tas_10.plot(label='10')
plt.legend(loc='upper center',borderpad=0.1,fontsize="6")
ax = pylab.gca()
ax.yaxis.set_visible(False)
ax.xaxis.set_visible(False)
plt.xlabel('')
plt.ylim(-60,20)

#plt.legend(loc='upper left')
#plt.title('TOA flux')
plt.subplot(gs[1,7])
tas_15_ns.plot(label='15_ns')
tas_15.plot(label='15')
plt.legend(loc='upper center',borderpad=0.1,fontsize="6")
ax = pylab.gca()
ax.yaxis.set_visible(False)
ax.xaxis.set_visible(False)
plt.xlabel('')
plt.ylim(-60,20)

#plt.legend(loc='upper left')
#plt.title('TOA flux')
plt.subplot(gs[1,8])
wtas_50_ns.plot(label='50_ns')
wtas_50.plot(label='50')
plt.legend(loc='upper center',borderpad=0.1,fontsize="6")
ax = pylab.gca()
ax.yaxis.set_visible(False)
ax.xaxis.set_visible(False)
plt.xlabel('')
plt.ylim(-60,20)








plt.subplot(gs[2,0])
tcs_total_5.plot(label='Sum_5Exp')
tcs_Exp_10s_5s_00_5n_10n.plot(label='Exp_10s_5s_00_5n_10n')
plt.legend(loc='upper center',borderpad=0.1,fontsize="6")
#plt.title('TOA flux')
plt.xlabel('')
plt.ylabel('Clear_Sky/W/m2')
plt.ylim(-40,15)

plt.subplot(gs[2,1])
tcs_total_3.plot(label='Sum_3Exp')
tcs_Exp_5s_00_5n.plot(label='Exp_5s_00_5n')
plt.legend(loc='upper center',borderpad=0.1,fontsize="6")
#plt.title('TOA flux')
plt.ylabel('W/m2')
ax = pylab.gca()
ax.yaxis.set_visible(False)
plt.xlabel('')
plt.ylim(-40,15)

plt.subplot(gs[2,2])
tcs_total_19.plot(label='Sum')
tcs_4k_n.plot(label='4k_NH')
plt.legend(loc='upper center',borderpad=0.1,fontsize="6")
#plt.title('TOA flux')
ax = pylab.gca()
ax.yaxis.set_visible(False)
plt.xlabel('')
plt.ylim(-40,15)


plt.subplot(gs[2,3])
tcs_total_ns.plot(label='Sum')
tcs_4k.plot(label='4k')
plt.legend(loc='upper center',borderpad=0.1,fontsize="6")
#plt.ylabel("W/m2")
ax = pylab.gca()
ax.yaxis.set_visible(False)
plt.xlabel('')
plt.ylim(-40,15)

plt.subplot(gs[2,4])
tcs_total_wide.plot(label='Linear_Sum')
tcs_Exp_4k.plot(label='4k')
plt.legend(loc='upper center',borderpad=0.1,fontsize="6")
#plt.ylabel("W/m2")
ax = pylab.gca()
ax.yaxis.set_visible(False)
plt.xlabel('')
plt.ylim(-40,15)

plt.subplot(gs[2,5])
tcs_05_ns.plot(label='5_ns')
tcs_05.plot(label='5')
plt.legend(loc='upper center',borderpad=0.1,fontsize="6")
ax = pylab.gca()
ax.yaxis.set_visible(False)
plt.xlabel('')
plt.ylim(-40,15)

#plt.legend(loc='upper left')
#plt.title('TOA flux')
plt.subplot(gs[2,6])
tcs_10_ns.plot(label='10_ns')
tcs_10.plot(label='10')
plt.legend(loc='upper center',borderpad=0.1,fontsize="6")
ax = pylab.gca()
ax.yaxis.set_visible(False)
plt.xlabel('')
plt.ylim(-40,15)

#plt.legend(loc='upper left')
#plt.title('TOA flux')
plt.subplot(gs[2,7])
tcs_15_ns.plot(label='15_ns')
tcs_15.plot(label='15')
plt.legend(loc='upper center',borderpad=0.1,fontsize="6")
ax = pylab.gca()
ax.yaxis.set_visible(False)
plt.xlabel('')
plt.ylim(-40,15)

#plt.legend(loc='upper left')
#plt.title('TOA flux')
plt.subplot(gs[2,8])
wtcs_50_ns.plot(label='50_ns')
wtcs_50.plot(label='50')
plt.legend(loc='upper center',borderpad=0.1,fontsize="6")
ax = pylab.gca()
ax.yaxis.set_visible(False)
plt.xlabel('')
plt.ylim(-40,15)

#plt.legend(loc='upper left')
#plt.title('TOA flux')
fig.text(0.5, 0.00, 'Latitude', ha='center')

plt.show()

# %%
tCRE_total_5.plot(label='CRE:sum of 5 exp')
tCRE_Exp_10s_5s_00_5n_10n.plot(label='Exp_10s_5s_00_5n_10n')
plt.legend(loc='lower left')
plt.title(" CRE")
plt.ylabel('W/m2')

# %%
tCRE_total_3.plot(label='CRE:sum of 3 exp')
tCRE_Exp_5s_00_5n.plot(label='Exp_5s_00_5n')
plt.legend(loc='lower left')
plt.title("Total CRE")
plt.ylabel('W/m2')
# Out:
# Text(0, 0.5, 'W/m2')

# %%
tCRE_total_19.plot(label='Total CRE (Total)')
tCRE_4k_n.plot(label='Total CRE 4k NH')
plt.legend(loc='lower left')
plt.title("Total CRE")
# Out:
# Text(0.5, 1.0, 'Total CRE')

# %%
tCRE_total_ns.plot(label='CRE-sum of all patches')
tCRE_4k.plot(label='CRE-4k')
plt.legend(loc='lower left')
plt.ylabel("CRE (W/m2)")
plt.title("CRE")
# Out:
# Text(0.5, 1.0, 'CRE')

# %%
tCRE_05_ns.plot(label='5_ns')
tCRE_05.plot(label='5')


plt.legend(loc='lower left')
plt.title("Total CRE")
# Out:
# Text(0.5, 1.0, 'Total CRE')

# %%
tCRE_10_ns.plot(label='10_ns')
tCRE_10.plot(label='10')


plt.legend(loc='lower left')
plt.title("Total CRE")
# Out:
# Text(0.5, 1.0, 'Total CRE')

# %%
tCRE_15_ns.plot(label='15_ns')
tCRE_15.plot(label='15')


plt.legend(loc='lower left')
plt.title("Total CRE")
# Out:
# Text(0.5, 1.0, 'Total CRE')

# %%
wtCRE_50_ns.plot(label='50_ns')
wtCRE_50.plot(label='50')


plt.legend(loc='lower left')
plt.title("Total CRE")
# Out:
# Text(0.5, 1.0, 'Total CRE')

# %%
tas_total_5.plot(label='Total all Sky(Total)')
tas_Exp_10s_5s_00_5n_10n.plot(label='Exp_10s_5s_00_5n_10n')
plt.legend(loc='lower left')
plt.title("All Sky")
plt.ylabel('W/m2')
# Out:
# Text(0, 0.5, 'W/m2')

# %%
tas_total_3.plot(label='Total all Sky(Total)')
tas_Exp_5s_00_5n.plot(label='Exp_5s_00_5n')
plt.legend(loc='lower left')
plt.title("All Sky")
plt.ylabel('W/m2')
# Out:
# Text(0, 0.5, 'W/m2')

# %%
tas_total_19.plot(label='Total all Sky(Total)')
tas_4k_n.plot(label='Total all Sky 4k NH')
plt.legend(loc='lower left')
plt.title("All Sky")
# Out:
# Text(0.5, 1.0, 'All Sky')

# %%
tas_total_ns.plot(label='All Sky-sum of all patches')
tas_4k.plot(label='All Sky-4k')
plt.legend(loc='lower left')
plt.ylabel("All Sky Radiative Flux (W/m2)")
plt.title("All Sky")
# Out:
# Text(0.5, 1.0, 'All Sky')

# %%
tas_05_ns.plot(label='5_ns')
tas_05.plot(label='5')


plt.legend(loc='lower left')
plt.title("Total All Sky")
# Out:
# Text(0.5, 1.0, 'Total All Sky')

# %%
tas_10_ns.plot(label='10_ns')
tas_10.plot(label='10')


plt.legend(loc='lower left')
plt.title("Total All Sky")
# Out:
# Text(0.5, 1.0, 'Total All Sky')

# %%
tas_15_ns.plot(label='15_ns')
tas_15.plot(label='15')


plt.legend(loc='lower left')
plt.title("Total All Sky")
# Out:
# Text(0.5, 1.0, 'Total All Sky')

# %%
wtas_50_ns.plot(label='50_ns')
wtas_50.plot(label='50')


plt.legend(loc='lower left')
plt.title("Total All Sky")
# Out:
# Text(0.5, 1.0, 'Total All Sky')

# %%
tcs_total_5.plot(label='Total Clear Sky(Total)')
tcs_Exp_10s_5s_00_5n_10n.plot(label='Exp_10s_5s_00_5n_10n')
plt.legend(loc='lower left')
plt.title("Clear Sky")
plt.ylabel('W/m2')
# Out:
# Text(0, 0.5, 'W/m2')

# %%
tcs_total_3.plot(label='Total Clear Sky(Total)')
tcs_Exp_5s_00_5n.plot(label='Exp_5s_00_5n')
plt.legend(loc='lower left')
plt.title("Clear Sky")
plt.ylabel('W/m2')
# Out:
# Text(0, 0.5, 'W/m2')

# %%
tcs_total_19.plot(label='Total Clear Sky(Total)')
tcs_4k_n.plot(label='Total Clear Sky 4k NH')
plt.legend(loc='lower left')
plt.title("Clear Sky")
# Out:
# Text(0.5, 1.0, 'Clear Sky')

# %%
tcs_total_ns.plot(label='Clear Sky-sum of all patches')
tcs_4k.plot(label='Clear Sky- 4k')
plt.legend(loc='lower left')
plt.ylabel("Clear Sky Radiative Flux (W/m2)")
plt.title("Clear Sky")
# Out:
# Text(0.5, 1.0, 'Clear Sky')

# %%
tcs_05_ns.plot(label='5_ns')
tcs_05.plot(label='5')


plt.legend(loc='lower left')
plt.title("Total Clear Sky")
# Out:
# Text(0.5, 1.0, 'Total Clear Sky')

# %%
tcs_10_ns.plot(label='10_ns')
tcs_10.plot(label='10')


plt.legend(loc='lower left')
plt.title("Total Clear Sky")
# Out:
# Text(0.5, 1.0, 'Total Clear Sky')

# %%
tcs_15_ns.plot(label='15_ns')
tcs_15.plot(label='15')


plt.legend(loc='lower left')
plt.title("Total Clear Sky")
# Out:
# Text(0.5, 1.0, 'Total Clear Sky')

# %%
wtcs_50_ns.plot(label='50_ns')
wtcs_50.plot(label='50')


plt.legend(loc='lower left')
plt.title("Total Clear Sky")
# Out:
# Text(0.5, 1.0, 'Total Clear Sky')
