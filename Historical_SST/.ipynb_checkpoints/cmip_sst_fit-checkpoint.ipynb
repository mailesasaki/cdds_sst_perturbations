# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import xarray as xr
import zarr
import gcsfs

# %%
# Read in data catalog

df = pd.read_csv('https://storage.googleapis.com/cmip6/cmip6-zarr-consolidated-stores.csv')
df.head()
# Out:
#   activity_id institution_id     source_id       experiment_id member_id  \
# 0  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
# 1  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
# 2  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
# 3  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
# 4  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
#
#   table_id variable_id grid_label  \
# 0     Amon          ps         gn
# 1     Amon        rsds         gn
# 2     Amon        rlus         gn
# 3     Amon        rlds         gn
# 4     Amon         psl         gn
#
#                                               zstore  dcpp_init_year   version
# 0  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706
# 1  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706
# 2  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706
# 3  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706
# 4  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706

# %%
# Find sea surface temperature

df_tos = df.query("activity_id=='CMIP' & table_id == 'Omon' & variable_id == 'tos' & experiment_id == 'historical' & member_id=='r1i1p1f1'")
df_tos
# Out:
#        activity_id       institution_id          source_id experiment_id  \
# 9976          CMIP            NOAA-GFDL           GFDL-CM4    historical
# 9977          CMIP            NOAA-GFDL           GFDL-CM4    historical
# 28719         CMIP                 IPSL       IPSL-CM6A-LR    historical
# 32357         CMIP            NASA-GISS        GISS-E2-1-G    historical
# 43345         CMIP                  BCC        BCC-CSM2-MR    historical
# 43554         CMIP                  BCC           BCC-ESM1    historical
# 44567         CMIP                MIROC             MIROC6    historical
# 45844         CMIP                  AWI      AWI-CM-1-1-MR    historical
# 59298         CMIP                 NCAR              CESM2    historical
# 59347         CMIP                 NCAR              CESM2    historical
# 68262         CMIP                  SNU        SAM0-UNICON    historical
# 69870         CMIP            NASA-GISS        GISS-E2-1-H    historical
# 98632         CMIP                CCCma            CanESM5    historical
# 204252        CMIP                  INM          INM-CM4-8    historical
# 206565        CMIP                  INM          INM-CM5-0    historical
# 211080        CMIP    HAMMOZ-Consortium    MPI-ESM-1-2-HAM    historical
# 215370        CMIP                NUIST              NESM3    historical
# 217465        CMIP                 CAMS        CAMS-CSM1-0    historical
# 222197        CMIP                MPI-M      MPI-ESM1-2-LR    historical
# 237776        CMIP                MPI-M      MPI-ESM1-2-HR    historical
# 245207        CMIP            NOAA-GFDL          GFDL-ESM4    historical
# 245208        CMIP            NOAA-GFDL          GFDL-ESM4    historical
# 246169        CMIP                   UA         MCM-UA-1-0    historical
# 248625        CMIP                 NCAR        CESM2-WACCM    historical
# 248626        CMIP                 NCAR        CESM2-WACCM    historical
# 254085        CMIP            NASA-GISS     GISS-E2-1-G-CC    historical
# 254493        CMIP                  NCC         NorESM2-LM    historical
# 277835        CMIP         E3SM-Project           E3SM-1-0    historical
# 280913        CMIP                  MRI         MRI-ESM2-0    historical
# 280949        CMIP                  MRI         MRI-ESM2-0    historical
# 319696        CMIP                  CAS        FGOALS-f3-L    historical
# 377605        CMIP                  CAS          FGOALS-g3    historical
# 377978        CMIP         CSIRO-ARCCSS         ACCESS-CM2    historical
# 380919        CMIP                  NCC         NorESM2-MM    historical
# 383199        CMIP                CSIRO      ACCESS-ESM1-5    historical
# 385659        CMIP                 NCAR          CESM2-FV2    historical
# 385660        CMIP                 NCAR          CESM2-FV2    historical
# 386028        CMIP                 NCAR    CESM2-WACCM-FV2    historical
# 386029        CMIP                 NCAR    CESM2-WACCM-FV2    historical
# 390335        CMIP             FIO-QLNM        FIO-ESM-2-0    historical
# 393148        CMIP         E3SM-Project           E3SM-1-1    historical
# 409875        CMIP         E3SM-Project       E3SM-1-1-ECA    historical
# 409995        CMIP             NIMS-KMA         KACE-1-0-G    historical
# 415980        CMIP                  AWI     AWI-ESM-1-1-LR    historical
# 419206        CMIP                  THU              CIESM    historical
# 425209        CMIP                  CAS         CAS-ESM2-0    historical
# 450314        CMIP                 CMCC       CMCC-CM2-SR5    historical
# 457423        CMIP  EC-Earth-Consortium  EC-Earth3-AerChem    historical
# 457609        CMIP              AS-RCEC            TaiESM1    historical
# 461021        CMIP                  NCC            NorCPM1    historical
# 462924        CMIP                 IPSL    IPSL-CM5A2-INCA    historical
# 469536        CMIP                 CMCC       CMCC-CM2-HR4    historical
# 470847        CMIP            CCCR-IITM           IITM-ESM    historical
# 471291        CMIP  EC-Earth-Consortium          EC-Earth3    historical
# 472357        CMIP  EC-Earth-Consortium   EC-Earth3-Veg-LR    historical
# 472458        CMIP  EC-Earth-Consortium      EC-Earth3-Veg    historical
# 511600        CMIP  EC-Earth-Consortium       EC-Earth3-CC    historical
# 512114        CMIP                 CMCC          CMCC-ESM2    historical
# 514880        CMIP                 IPSL  IPSL-CM6A-LR-INCA    historical
#
#        member_id table_id variable_id grid_label  \
# 9976    r1i1p1f1     Omon         tos         gr
# 9977    r1i1p1f1     Omon         tos         gn
# 28719   r1i1p1f1     Omon         tos         gn
# 32357   r1i1p1f1     Omon         tos         gn
# 43345   r1i1p1f1     Omon         tos         gn
# 43554   r1i1p1f1     Omon         tos         gn
# 44567   r1i1p1f1     Omon         tos         gn
# 45844   r1i1p1f1     Omon         tos         gn
# 59298   r1i1p1f1     Omon         tos         gr
# 59347   r1i1p1f1     Omon         tos         gn
# 68262   r1i1p1f1     Omon         tos         gn
# 69870   r1i1p1f1     Omon         tos         gn
# 98632   r1i1p1f1     Omon         tos         gn
# 204252  r1i1p1f1     Omon         tos        gr1
# 206565  r1i1p1f1     Omon         tos        gr1
# 211080  r1i1p1f1     Omon         tos         gn
# 215370  r1i1p1f1     Omon         tos         gn
# 217465  r1i1p1f1     Omon         tos         gn
# 222197  r1i1p1f1     Omon         tos         gn
# 237776  r1i1p1f1     Omon         tos         gn
# 245207  r1i1p1f1     Omon         tos         gn
# 245208  r1i1p1f1     Omon         tos         gr
# 246169  r1i1p1f1     Omon         tos         gn
# 248625  r1i1p1f1     Omon         tos         gn
# 248626  r1i1p1f1     Omon         tos         gr
# 254085  r1i1p1f1     Omon         tos         gn
# 254493  r1i1p1f1     Omon         tos         gn
# 277835  r1i1p1f1     Omon         tos         gr
# 280913  r1i1p1f1     Omon         tos         gr
# 280949  r1i1p1f1     Omon         tos         gn
# 319696  r1i1p1f1     Omon         tos         gn
# 377605  r1i1p1f1     Omon         tos         gn
# 377978  r1i1p1f1     Omon         tos         gn
# 380919  r1i1p1f1     Omon         tos         gn
# 383199  r1i1p1f1     Omon         tos         gn
# 385659  r1i1p1f1     Omon         tos         gr
# 385660  r1i1p1f1     Omon         tos         gn
# 386028  r1i1p1f1     Omon         tos         gn
# 386029  r1i1p1f1     Omon         tos         gr
# 390335  r1i1p1f1     Omon         tos         gn
# 393148  r1i1p1f1     Omon         tos         gr
# 409875  r1i1p1f1     Omon         tos         gr
# 409995  r1i1p1f1     Omon         tos         gr
# 415980  r1i1p1f1     Omon         tos         gn
# 419206  r1i1p1f1     Omon         tos         gn
# 425209  r1i1p1f1     Omon         tos         gn
# 450314  r1i1p1f1     Omon         tos         gn
# 457423  r1i1p1f1     Omon         tos         gn
# 457609  r1i1p1f1     Omon         tos         gn
# 461021  r1i1p1f1     Omon         tos         gn
# 462924  r1i1p1f1     Omon         tos         gn
# 469536  r1i1p1f1     Omon         tos         gn
# 470847  r1i1p1f1     Omon         tos         gn
# 471291  r1i1p1f1     Omon         tos         gn
# 472357  r1i1p1f1     Omon         tos         gn
# 472458  r1i1p1f1     Omon         tos         gn
# 511600  r1i1p1f1     Omon         tos         gn
# 512114  r1i1p1f1     Omon         tos         gn
# 514880  r1i1p1f1     Omon         tos         gn
#
#                                                    zstore  dcpp_init_year  \
# 9976    gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-CM4/histo...             NaN
# 9977    gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-CM4/histo...             NaN
# 28719   gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 32357   gs://cmip6/CMIP6/CMIP/NASA-GISS/GISS-E2-1-G/hi...             NaN
# 43345   gs://cmip6/CMIP6/CMIP/BCC/BCC-CSM2-MR/historic...             NaN
# 43554   gs://cmip6/CMIP6/CMIP/BCC/BCC-ESM1/historical/...             NaN
# 44567   gs://cmip6/CMIP6/CMIP/MIROC/MIROC6/historical/...             NaN
# 45844   gs://cmip6/CMIP6/CMIP/AWI/AWI-CM-1-1-MR/histor...             NaN
# 59298   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/historical/r1...             NaN
# 59347   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/historical/r1...             NaN
# 68262   gs://cmip6/CMIP6/CMIP/SNU/SAM0-UNICON/historic...             NaN
# 69870   gs://cmip6/CMIP6/CMIP/NASA-GISS/GISS-E2-1-H/hi...             NaN
# 98632   gs://cmip6/CMIP6/CMIP/CCCma/CanESM5/historical...             NaN
# 204252  gs://cmip6/CMIP6/CMIP/INM/INM-CM4-8/historical...             NaN
# 206565  gs://cmip6/CMIP6/CMIP/INM/INM-CM5-0/historical...             NaN
# 211080  gs://cmip6/CMIP6/CMIP/HAMMOZ-Consortium/MPI-ES...             NaN
# 215370  gs://cmip6/CMIP6/CMIP/NUIST/NESM3/historical/r...             NaN
# 217465  gs://cmip6/CMIP6/CMIP/CAMS/CAMS-CSM1-0/histori...             NaN
# 222197  gs://cmip6/CMIP6/CMIP/MPI-M/MPI-ESM1-2-LR/hist...             NaN
# 237776  gs://cmip6/CMIP6/CMIP/MPI-M/MPI-ESM1-2-HR/hist...             NaN
# 245207  gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-ESM4/hist...             NaN
# 245208  gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-ESM4/hist...             NaN
# 246169  gs://cmip6/CMIP6/CMIP/UA/MCM-UA-1-0/historical...             NaN
# 248625  gs://cmip6/CMIP6/CMIP/NCAR/CESM2-WACCM/histori...             NaN
# 248626  gs://cmip6/CMIP6/CMIP/NCAR/CESM2-WACCM/histori...             NaN
# 254085  gs://cmip6/CMIP6/CMIP/NASA-GISS/GISS-E2-1-G-CC...             NaN
# 254493  gs://cmip6/CMIP6/CMIP/NCC/NorESM2-LM/historica...             NaN
# 277835  gs://cmip6/CMIP6/CMIP/E3SM-Project/E3SM-1-0/hi...             NaN
# 280913  gs://cmip6/CMIP6/CMIP/MRI/MRI-ESM2-0/historica...             NaN
# 280949  gs://cmip6/CMIP6/CMIP/MRI/MRI-ESM2-0/historica...             NaN
# 319696  gs://cmip6/CMIP6/CMIP/CAS/FGOALS-f3-L/historic...             NaN
# 377605  gs://cmip6/CMIP6/CMIP/CAS/FGOALS-g3/historical...             NaN
# 377978  gs://cmip6/CMIP6/CMIP/CSIRO-ARCCSS/ACCESS-CM2/...             NaN
# 380919  gs://cmip6/CMIP6/CMIP/NCC/NorESM2-MM/historica...             NaN
# 383199  gs://cmip6/CMIP6/CMIP/CSIRO/ACCESS-ESM1-5/hist...             NaN
# 385659  gs://cmip6/CMIP6/CMIP/NCAR/CESM2-FV2/historica...             NaN
# 385660  gs://cmip6/CMIP6/CMIP/NCAR/CESM2-FV2/historica...             NaN
# 386028  gs://cmip6/CMIP6/CMIP/NCAR/CESM2-WACCM-FV2/his...             NaN
# 386029  gs://cmip6/CMIP6/CMIP/NCAR/CESM2-WACCM-FV2/his...             NaN
# 390335  gs://cmip6/CMIP6/CMIP/FIO-QLNM/FIO-ESM-2-0/his...             NaN
# 393148  gs://cmip6/CMIP6/CMIP/E3SM-Project/E3SM-1-1/hi...             NaN
# 409875  gs://cmip6/CMIP6/CMIP/E3SM-Project/E3SM-1-1-EC...             NaN
# 409995  gs://cmip6/CMIP6/CMIP/NIMS-KMA/KACE-1-0-G/hist...             NaN
# 415980  gs://cmip6/CMIP6/CMIP/AWI/AWI-ESM-1-1-LR/histo...             NaN
# 419206  gs://cmip6/CMIP6/CMIP/THU/CIESM/historical/r1i...             NaN
# 425209  gs://cmip6/CMIP6/CMIP/CAS/CAS-ESM2-0/historica...             NaN
# 450314  gs://cmip6/CMIP6/CMIP/CMCC/CMCC-CM2-SR5/histor...             NaN
# 457423  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
# 457609  gs://cmip6/CMIP6/CMIP/AS-RCEC/TaiESM1/historic...             NaN
# 461021  gs://cmip6/CMIP6/CMIP/NCC/NorCPM1/historical/r...             NaN
# 462924  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM5A2-INCA/his...             NaN
# 469536  gs://cmip6/CMIP6/CMIP/CMCC/CMCC-CM2-HR4/histor...             NaN
# 470847  gs://cmip6/CMIP6/CMIP/CCCR-IITM/IITM-ESM/histo...             NaN
# 471291  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
# 472357  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
# 472458  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
# 511600  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
# 512114  gs://cmip6/CMIP6/CMIP/CMCC/CMCC-ESM2/historica...             NaN
# 514880  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR-INCA/h...             NaN
#
#          version
# 9976    20180701
# 9977    20180701
# 28719   20180803
# 32357   20180827
# 43345   20181126
# 43554   20181129
# 44567   20181212
# 45844   20181218
# 59298   20190308
# 59347   20190308
# 68262   20190323
# 69870   20190403
# 98632   20190429
# 204252  20190530
# 206565  20190610
# 211080  20190627
# 215370  20190703
# 217465  20190708
# 222197  20190710
# 237776  20190710
# 245207  20190726
# 245208  20190726
# 246169  20190731
# 248625  20190808
# 248626  20190808
# 254085  20190815
# 254493  20190815
# 277835  20190826
# 280913  20190904
# 280949  20190904
# 319696  20191007
# 377605  20191107
# 377978  20191108
# 380919  20191108
# 383199  20191115
# 385659  20191120
# 385660  20191120
# 386028  20191120
# 386029  20191120
# 390335  20191122
# 393148  20191204
# 409875  20200127
# 409995  20200130
# 415980  20200212
# 419206  20200220
# 425209  20200306
# 450314  20200616
# 457423  20200624
# 457609  20200630
# 461021  20200724
# 462924  20200729
# 469536  20200904
# 470847  20200915
# 471291  20200918
# 472357  20200919
# 472458  20200919
# 511600  20210113
# 512114  20210114
# 514880  20210216

# %%
df_ts = df_tos.drop_duplicates('source_id').head(20)
df_ts
# Out:
#        activity_id     institution_id        source_id experiment_id  \
# 9976          CMIP          NOAA-GFDL         GFDL-CM4    historical
# 28719         CMIP               IPSL     IPSL-CM6A-LR    historical
# 32357         CMIP          NASA-GISS      GISS-E2-1-G    historical
# 43345         CMIP                BCC      BCC-CSM2-MR    historical
# 43554         CMIP                BCC         BCC-ESM1    historical
# 44567         CMIP              MIROC           MIROC6    historical
# 45844         CMIP                AWI    AWI-CM-1-1-MR    historical
# 59298         CMIP               NCAR            CESM2    historical
# 68262         CMIP                SNU      SAM0-UNICON    historical
# 69870         CMIP          NASA-GISS      GISS-E2-1-H    historical
# 98632         CMIP              CCCma          CanESM5    historical
# 204252        CMIP                INM        INM-CM4-8    historical
# 206565        CMIP                INM        INM-CM5-0    historical
# 211080        CMIP  HAMMOZ-Consortium  MPI-ESM-1-2-HAM    historical
# 215370        CMIP              NUIST            NESM3    historical
# 217465        CMIP               CAMS      CAMS-CSM1-0    historical
# 222197        CMIP              MPI-M    MPI-ESM1-2-LR    historical
# 237776        CMIP              MPI-M    MPI-ESM1-2-HR    historical
# 245207        CMIP          NOAA-GFDL        GFDL-ESM4    historical
# 246169        CMIP                 UA       MCM-UA-1-0    historical
#
#        member_id table_id variable_id grid_label  \
# 9976    r1i1p1f1     Omon         tos         gr
# 28719   r1i1p1f1     Omon         tos         gn
# 32357   r1i1p1f1     Omon         tos         gn
# 43345   r1i1p1f1     Omon         tos         gn
# 43554   r1i1p1f1     Omon         tos         gn
# 44567   r1i1p1f1     Omon         tos         gn
# 45844   r1i1p1f1     Omon         tos         gn
# 59298   r1i1p1f1     Omon         tos         gr
# 68262   r1i1p1f1     Omon         tos         gn
# 69870   r1i1p1f1     Omon         tos         gn
# 98632   r1i1p1f1     Omon         tos         gn
# 204252  r1i1p1f1     Omon         tos        gr1
# 206565  r1i1p1f1     Omon         tos        gr1
# 211080  r1i1p1f1     Omon         tos         gn
# 215370  r1i1p1f1     Omon         tos         gn
# 217465  r1i1p1f1     Omon         tos         gn
# 222197  r1i1p1f1     Omon         tos         gn
# 237776  r1i1p1f1     Omon         tos         gn
# 245207  r1i1p1f1     Omon         tos         gn
# 246169  r1i1p1f1     Omon         tos         gn
#
#                                                    zstore  dcpp_init_year  \
# 9976    gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-CM4/histo...             NaN
# 28719   gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 32357   gs://cmip6/CMIP6/CMIP/NASA-GISS/GISS-E2-1-G/hi...             NaN
# 43345   gs://cmip6/CMIP6/CMIP/BCC/BCC-CSM2-MR/historic...             NaN
# 43554   gs://cmip6/CMIP6/CMIP/BCC/BCC-ESM1/historical/...             NaN
# 44567   gs://cmip6/CMIP6/CMIP/MIROC/MIROC6/historical/...             NaN
# 45844   gs://cmip6/CMIP6/CMIP/AWI/AWI-CM-1-1-MR/histor...             NaN
# 59298   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/historical/r1...             NaN
# 68262   gs://cmip6/CMIP6/CMIP/SNU/SAM0-UNICON/historic...             NaN
# 69870   gs://cmip6/CMIP6/CMIP/NASA-GISS/GISS-E2-1-H/hi...             NaN
# 98632   gs://cmip6/CMIP6/CMIP/CCCma/CanESM5/historical...             NaN
# 204252  gs://cmip6/CMIP6/CMIP/INM/INM-CM4-8/historical...             NaN
# 206565  gs://cmip6/CMIP6/CMIP/INM/INM-CM5-0/historical...             NaN
# 211080  gs://cmip6/CMIP6/CMIP/HAMMOZ-Consortium/MPI-ES...             NaN
# 215370  gs://cmip6/CMIP6/CMIP/NUIST/NESM3/historical/r...             NaN
# 217465  gs://cmip6/CMIP6/CMIP/CAMS/CAMS-CSM1-0/histori...             NaN
# 222197  gs://cmip6/CMIP6/CMIP/MPI-M/MPI-ESM1-2-LR/hist...             NaN
# 237776  gs://cmip6/CMIP6/CMIP/MPI-M/MPI-ESM1-2-HR/hist...             NaN
# 245207  gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-ESM4/hist...             NaN
# 246169  gs://cmip6/CMIP6/CMIP/UA/MCM-UA-1-0/historical...             NaN
#
#          version
# 9976    20180701
# 28719   20180803
# 32357   20180827
# 43345   20181126
# 43554   20181129
# 44567   20181212
# 45844   20181218
# 59298   20190308
# 68262   20190323
# 69870   20190403
# 98632   20190429
# 204252  20190530
# 206565  20190610
# 211080  20190627
# 215370  20190703
# 217465  20190708
# 222197  20190710
# 237776  20190710
# 245207  20190726
# 246169  20190731

# %%
# this only needs to be created once
# From Ryan Abernathy's tutorial - Way 2
gcs = gcsfs.GCSFileSystem(token='anon')
fs = gcsfs.GCSFileSystem(token='anon', access='read_only')

dset_list = []
for zstore in df_ts.zstore.unique():
    # make a nice concise name from the zstore value
    name = zstore.split('gs://cmip6/CMIP6/')[1].replace('/','.')[:-1]
    print(name)
    ds = xr.open_zarr(fs.get_mapper(zstore),consolidated=True)
    ds_tos = ds.tos.isel(time=-1).mean('lon') # Last time available (2014?), taking the mean over the longitude
    #print(dict(ds.dims))
    ds_tos['name'] = name # Creating a new dimension for each ensemble member
    dset_list.append(ds_tos)
# Out:
# CMIP.NOAA-GFDL.GFDL-CM4.historical.r1i1p1f1.Omon.tos.gr.v20180701
# CMIP.IPSL.IPSL-CM6A-LR.historical.r1i1p1f1.Omon.tos.gn.v20180803
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/envs/paleoproj/lib/python3.10/site-packages/xarray/core/common.py:215, in AbstractArray._get_axis_num(self, dim)
#     214 try:
# --> 215     return self.dims.index(dim)
#     216 except ValueError:
#
# ValueError: tuple.index(x): x not in tuple
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [25], in <cell line: 7>()
#      10 print(name)
#      11 ds = xr.open_zarr(fs.get_mapper(zstore),consolidated=True)
# ---> 12 ds_tos = ds.tos.isel(time=-1).mean('lon') # Last time available (2014?), taking the mean over the longitude
#      13 #print(dict(ds.dims))
#      14 ds_tos['name'] = name # Creating a new dimension for each ensemble member
#
# File ~/miniconda3/envs/paleoproj/lib/python3.10/site-packages/xarray/core/_reductions.py:1479, in DataArrayReductions.mean(self, dim, skipna, keep_attrs, **kwargs)
#    1404 def mean(
#    1405     self,
#    1406     dim: Dims = None,
#    (...)
#    1410     **kwargs: Any,
#    1411 ) -> DataArray:
#    1412     """
#    1413     Reduce this DataArray's data by applying ``mean`` along some dimension(s).
#    1414
#    (...)
#    1477     array(nan)
#    1478     """
# -> 1479     return self.reduce(
#    1480         duck_array_ops.mean,
#    1481         dim=dim,
#    1482         skipna=skipna,
#    1483         keep_attrs=keep_attrs,
#    1484         **kwargs,
#    1485     )
#
# File ~/miniconda3/envs/paleoproj/lib/python3.10/site-packages/xarray/core/dataarray.py:3455, in DataArray.reduce(self, func, dim, axis, keep_attrs, keepdims, **kwargs)
#    3411 def reduce(
#    3412     self: T_DataArray,
#    3413     func: Callable[..., Any],
#    (...)
#    3419     **kwargs: Any,
#    3420 ) -> T_DataArray:
#    3421     """Reduce this array by applying `func` along some dimension(s).
#    3422
#    3423     Parameters
#    (...)
#    3452         summarized data and the indicated dimension(s) removed.
#    3453     """
# -> 3455     var = self.variable.reduce(func, dim, axis, keep_attrs, keepdims, **kwargs)
#    3456     return self._replace_maybe_drop_dims(var)
#
# File ~/miniconda3/envs/paleoproj/lib/python3.10/site-packages/xarray/core/variable.py:1888, in Variable.reduce(self, func, dim, axis, keep_attrs, keepdims, **kwargs)
#    1885     raise ValueError("cannot supply both 'axis' and 'dim' arguments")
#    1887 if dim is not None:
# -> 1888     axis = self.get_axis_num(dim)
#    1890 with warnings.catch_warnings():
#    1891     warnings.filterwarnings(
#    1892         "ignore", r"Mean of empty slice", category=RuntimeWarning
#    1893     )
#
# File ~/miniconda3/envs/paleoproj/lib/python3.10/site-packages/xarray/core/common.py:211, in AbstractArray.get_axis_num(self, dim)
#     209     return tuple(self._get_axis_num(d) for d in dim)
#     210 else:
# --> 211     return self._get_axis_num(dim)
#
# File ~/miniconda3/envs/paleoproj/lib/python3.10/site-packages/xarray/core/common.py:217, in AbstractArray._get_axis_num(self, dim)
#     215     return self.dims.index(dim)
#     216 except ValueError:
# --> 217     raise ValueError(f"{dim!r} not found in array dimensions {self.dims!r}")
#
# ValueError: 'lon' not found in array dimensions ('y', 'x')

# %%
print(dset_list)
# Out:
# [<xarray.DataArray 'tos' (lat: 180, lon: 360)>
# dask.array<getitem, shape=(180, 360), dtype=float32, chunksize=(180, 360), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float64 -89.5 -88.5 -87.5 -86.5 -85.5 ... 86.5 87.5 88.5 89.5
#   * lon      (lon) float64 0.5 1.5 2.5 3.5 4.5 ... 355.5 356.5 357.5 358.5 359.5
#     time     object 2014-12-16 12:00:00
#     name     <U65 'CMIP.NOAA-GFDL.GFDL-CM4.historical.r1i1p1f1.Omon.tos.gr.v2...
# Attributes:
#     cell_measures:  area: areacello
#     cell_methods:   area: mean where sea time: mean
#     comment:        Model data on the 1x1 grid includes values in all cells f...
#     interp_method:  conserve_order1
#     long_name:      Sea Surface Temperature
#     original_name:  tos
#     standard_name:  sea_surface_temperature
#     units:          degC, <xarray.DataArray 'tos' (y: 332, x: 362)>
# dask.array<getitem, shape=(332, 362), dtype=float32, chunksize=(332, 362), chunktype=numpy.ndarray>
# Coordinates:
#     nav_lat  (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     nav_lon  (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     time     datetime64[ns] 2014-12-16T12:00:00
#     name     <U64 'CMIP.IPSL.IPSL-CM6A-LR.historical.r1i1p1f1.Omon.tos.gn.v20...
# Dimensions without coordinates: y, x
# Attributes:
#     cell_measures:       area: areacello
#     cell_methods:        area: mean where sea time: mean
#     description:         This may differ from "surface temperature" in region...
#     history:             none
#     interval_operation:  2700 s
#     interval_write:      1 month
#     long_name:           Sea Surface Temperature
#     online_operation:    average
#     standard_name:       sea_surface_temperature
#     units:               degC, <xarray.DataArray 'tos' (lat: 90, lon: 144)>
# dask.array<getitem, shape=(90, 144), dtype=float32, chunksize=(90, 144), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float64 -89.0 -87.0 -85.0 -83.0 -81.0 ... 83.0 85.0 87.0 89.0
#   * lon      (lon) float64 1.25 3.75 6.25 8.75 11.25 ... 351.2 353.8 356.2 358.8
#     time     object 2014-12-16 12:00:00
#     name     <U68 'CMIP.NASA-GISS.GISS-E2-1-G.historical.r1i1p1f1.Omon.tos.gn...
# Attributes:
#     cell_measures:   area: areacello
#     cell_methods:    area: mean where sea time: mean
#     comment:         Temperature of upper boundary of the liquid ocean, inclu...
#     long_name:       Sea Surface Temperature
#     original_units:  K
#     standard_name:   sea_surface_temperature
#     units:           degC, <xarray.DataArray 'tos' (lat: 232, lon: 360)>
# dask.array<getitem, shape=(232, 360), dtype=float32, chunksize=(232, 360), chunktype=numpy.ndarray>
# Coordinates:
#   * lat        (lat) float64 -81.5 -80.5 -79.5 -78.5 ... 86.5 87.5 88.5 89.5
#     latitude   (lat, lon) float32 dask.array<chunksize=(232, 360), meta=np.ndarray>
#   * lon        (lon) float64 0.5 1.5 2.5 3.5 4.5 ... 356.5 357.5 358.5 359.5
#     longitude  (lat, lon) float32 dask.array<chunksize=(232, 360), meta=np.ndarray>
#     time       object 2014-12-16 12:00:00
#     name       <U62 'CMIP.BCC.BCC-CSM2-MR.historical.r1i1p1f1.Omon.tos.gn.v20...
# Attributes:
#     cell_measures:  area: areacello
#     cell_methods:   area: mean where sea time: mean (interval: 30 minutes)
#     comment:        Temperature of upper boundary of the liquid ocean, includ...
#     long_name:      Sea Surface Temperature
#     original_name:  tos
#     standard_name:  sea_surface_temperature
#     units:          degC, <xarray.DataArray 'tos' (lat: 232, lon: 360)>
# dask.array<getitem, shape=(232, 360), dtype=float32, chunksize=(232, 360), chunktype=numpy.ndarray>
# Coordinates:
#   * lat        (lat) float64 -81.5 -80.5 -79.5 -78.5 ... 86.5 87.5 88.5 89.5
#     latitude   (lat, lon) float32 dask.array<chunksize=(232, 360), meta=np.ndarray>
#   * lon        (lon) float64 0.5 1.5 2.5 3.5 4.5 ... 356.5 357.5 358.5 359.5
#     longitude  (lat, lon) float32 dask.array<chunksize=(232, 360), meta=np.ndarray>
#     time       object 2014-12-16 12:00:00
#     name       <U59 'CMIP.BCC.BCC-ESM1.historical.r1i1p1f1.Omon.tos.gn.v20181...
# Attributes:
#     cell_measures:  area: areacello
#     cell_methods:   area: mean where sea time: mean (interval: 30 minutes)
#     comment:        Temperature of upper boundary of the liquid ocean, includ...
#     long_name:      Sea Surface Temperature
#     original_name:  tos
#     standard_name:  sea_surface_temperature
#     units:          degC, <xarray.DataArray 'tos' (y: 256, x: 360)>
# dask.array<getitem, shape=(256, 360), dtype=float32, chunksize=(256, 360), chunktype=numpy.ndarray>
# Coordinates:
#     latitude   (y, x) float32 dask.array<chunksize=(256, 360), meta=np.ndarray>
#     longitude  (y, x) float32 dask.array<chunksize=(256, 360), meta=np.ndarray>
#     time       datetime64[ns] 2014-12-16T12:00:00
#   * x          (x) float64 0.5 1.5 2.5 3.5 4.5 ... 355.5 356.5 357.5 358.5 359.5
#   * y          (y) float64 -88.0 -85.75 -85.25 -84.75 ... 148.6 150.5 152.4
#     name       <U59 'CMIP.MIROC.MIROC6.historical.r1i1p1f1.Omon.tos.gn.v20181...
# Attributes:
#     cell_measures:  area: areacello
#     cell_methods:   area: mean where sea time: mean
#     comment:        Temperature of upper boundary of the liquid ocean, includ...
#     long_name:      Sea Surface Temperature
#     original_name:  TO
#     standard_name:  sea_surface_temperature
#     units:          degC, <xarray.DataArray 'tos' (ncells: 830305)>
# dask.array<getitem, shape=(830305,), dtype=float32, chunksize=(830305,), chunktype=numpy.ndarray>
# Coordinates:
#     lat      (ncells) float64 dask.array<chunksize=(830305,), meta=np.ndarray>
#     lon      (ncells) float64 dask.array<chunksize=(830305,), meta=np.ndarray>
#     time     datetime64[ns] 2014-12-16T12:00:00
#     name     <U64 'CMIP.AWI.AWI-CM-1-1-MR.historical.r1i1p1f1.Omon.tos.gn.v20...
# Dimensions without coordinates: ncells
# Attributes:
#     CDI_grid_type:  unstructured
#     cell_measures:  area: areacello
#     cell_methods:   area: mean where sea time: mean
#     description:    Temperature of upper boundary of the liquid ocean, includ...
#     standard_name:  sea_surface_temperature
#     units:          degC, <xarray.DataArray 'tos' (lat: 180, lon: 360)>
# dask.array<getitem, shape=(180, 360), dtype=float32, chunksize=(180, 360), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float64 -89.5 -88.5 -87.5 -86.5 -85.5 ... 86.5 87.5 88.5 89.5
#   * lon      (lon) float64 0.5 1.5 2.5 3.5 4.5 ... 355.5 356.5 357.5 358.5 359.5
#     time     object 2014-12-15 12:00:00
#     name     <U57 'CMIP.NCAR.CESM2.historical.r1i1p1f1.Omon.tos.gr.v20190308'
# Attributes: (12/19)
#     cell_measures:  area: areacello
#     cell_methods:   area: mean where sea time: mean
#     comment:        Model data on the 1x1 grid includes values in all cells f...
#     description:    This may differ from "surface temperature" in regions of ...
#     frequency:      mon
#     id:             tos
#     ...             ...
#     time_label:     time-mean
#     time_title:     Temporal mean
#     title:          Sea Surface Temperature
#     type:           real
#     units:          degC
#     variable_id:    tos, <xarray.DataArray 'tos' (j: 384, i: 320)>
# dask.array<getitem, shape=(384, 320), dtype=float32, chunksize=(384, 320), chunktype=numpy.ndarray>
# Coordinates:
#   * i          (i) int32 0 1 2 3 4 5 6 7 8 ... 312 313 314 315 316 317 318 319
#   * j          (j) int32 0 1 2 3 4 5 6 7 8 ... 376 377 378 379 380 381 382 383
#     latitude   (j, i) float64 dask.array<chunksize=(384, 320), meta=np.ndarray>
#     longitude  (j, i) float64 dask.array<chunksize=(384, 320), meta=np.ndarray>
#     time       object 2014-12-16 12:00:00
#     name       <U62 'CMIP.SNU.SAM0-UNICON.historical.r1i1p1f1.Omon.tos.gn.v20...
# Attributes:
#     cell_measures:  area: areacello
#     cell_methods:   area: mean where sea time: mean (interval: 1 month)
#     comment:        Temperature of upper boundary of the liquid ocean, includ...
#     history:        rewrote by cmor via python script 2019-04-03T14:38:42Z al...
#     long_name:      Sea Surface Temperature
#     standard_name:  sea_surface_temperature
#     units:          degC, <xarray.DataArray 'tos' (lat: 90, lon: 144)>
# dask.array<getitem, shape=(90, 144), dtype=float32, chunksize=(90, 144), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float64 -89.0 -87.0 -85.0 -83.0 -81.0 ... 83.0 85.0 87.0 89.0
#   * lon      (lon) float64 1.25 3.75 6.25 8.75 11.25 ... 351.2 353.8 356.2 358.8
#     time     object 2014-12-16 12:00:00
#     name     <U68 'CMIP.NASA-GISS.GISS-E2-1-H.historical.r1i1p1f1.Omon.tos.gn...
# Attributes:
#     cell_measures:   area: areacello
#     cell_methods:    area: mean where sea time: mean
#     comment:         Temperature of upper boundary of the liquid ocean, inclu...
#     long_name:       Sea Surface Temperature
#     original_units:  K
#     standard_name:   sea_surface_temperature
#     units:           degC, <xarray.DataArray 'tos' (j: 291, i: 360)>
# dask.array<getitem, shape=(291, 360), dtype=float32, chunksize=(291, 360), chunktype=numpy.ndarray>
# Coordinates:
#   * i          (i) int32 0 1 2 3 4 5 6 7 8 ... 352 353 354 355 356 357 358 359
#   * j          (j) int32 0 1 2 3 4 5 6 7 8 ... 283 284 285 286 287 288 289 290
#     latitude   (j, i) float64 dask.array<chunksize=(291, 360), meta=np.ndarray>
#     longitude  (j, i) float64 dask.array<chunksize=(291, 360), meta=np.ndarray>
#     time       object 2014-12-16 12:00:00
#     name       <U60 'CMIP.CCCma.CanESM5.historical.r1i1p1f1.Omon.tos.gn.v2019...
# Attributes:
#     cell_measures:  area: areacello
#     cell_methods:   area: mean where sea time: mean
#     comment:        Temperature of upper boundary of the liquid ocean, includ...
#     long_name:      Sea Surface Temperature
#     original_name:  sosstsst
#     standard_name:  sea_surface_temperature
#     units:          degC, <xarray.DataArray 'tos' (lat: 180, lon: 360)>
# dask.array<getitem, shape=(180, 360), dtype=float32, chunksize=(180, 360), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float64 -89.5 -88.5 -87.5 -86.5 -85.5 ... 86.5 87.5 88.5 89.5
#   * lon      (lon) float64 0.5 1.5 2.5 3.5 4.5 ... 355.5 356.5 357.5 358.5 359.5
#     time     object 2014-12-16 12:00:00
#     name     <U61 'CMIP.INM.INM-CM4-8.historical.r1i1p1f1.Omon.tos.gr1.v20190...
# Attributes:
#     cell_measures:  area: areacello
#     cell_methods:   area: mean where sea time: mean (interval: 1 month)
#     comment:        Temperature of upper boundary of the liquid ocean, includ...
#     long_name:      Sea Surface Temperature
#     original_name:  tos
#     standard_name:  sea_surface_temperature
#     units:          degC, <xarray.DataArray 'tos' (lat: 180, lon: 360)>
# dask.array<getitem, shape=(180, 360), dtype=float32, chunksize=(180, 360), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float64 -89.5 -88.5 -87.5 -86.5 -85.5 ... 86.5 87.5 88.5 89.5
#   * lon      (lon) float64 0.5 1.5 2.5 3.5 4.5 ... 355.5 356.5 357.5 358.5 359.5
#     time     object 2014-12-16 12:00:00
#     name     <U61 'CMIP.INM.INM-CM5-0.historical.r1i1p1f1.Omon.tos.gr1.v20190...
# Attributes:
#     cell_measures:  area: areacello
#     cell_methods:   area: mean where sea time: mean (interval: 1 month)
#     comment:        Temperature of upper boundary of the liquid ocean, includ...
#     long_name:      Sea Surface Temperature
#     original_name:  tos
#     standard_name:  sea_surface_temperature
#     units:          degC, <xarray.DataArray 'tos' (j: 220, i: 256)>
# dask.array<getitem, shape=(220, 256), dtype=float32, chunksize=(220, 256), chunktype=numpy.ndarray>
# Coordinates:
#   * i          (i) int32 0 1 2 3 4 5 6 7 8 ... 248 249 250 251 252 253 254 255
#   * j          (j) int32 0 1 2 3 4 5 6 7 8 ... 212 213 214 215 216 217 218 219
#     latitude   (j, i) float64 dask.array<chunksize=(220, 256), meta=np.ndarray>
#     longitude  (j, i) float64 dask.array<chunksize=(220, 256), meta=np.ndarray>
#     time       datetime64[ns] 2014-12-16T12:00:00
#     name       <U80 'CMIP.HAMMOZ-Consortium.MPI-ESM-1-2-HAM.historical.r1i1p1...
# Attributes:
#     cell_measures:  area: areacello
#     cell_methods:   area: mean where sea time: mean
#     comment:        Temperature of upper boundary of the liquid ocean, includ...
#     history:        2019-11-24T16:01:05Z altered by CMOR: replaced missing va...
#     long_name:      Sea Surface Temperature
#     original_name:  tos
#     standard_name:  sea_surface_temperature
#     units:          degC, <xarray.DataArray 'tos' (j: 292, i: 362)>
# dask.array<getitem, shape=(292, 362), dtype=float32, chunksize=(292, 362), chunktype=numpy.ndarray>
# Coordinates:
#   * i          (i) int32 1 2 3 4 5 6 7 8 9 ... 355 356 357 358 359 360 361 362
#   * j          (j) int32 1 2 3 4 5 6 7 8 9 ... 285 286 287 288 289 290 291 292
#     latitude   (j, i) float32 dask.array<chunksize=(292, 362), meta=np.ndarray>
#     longitude  (j, i) float32 dask.array<chunksize=(292, 362), meta=np.ndarray>
#     time       object 2014-12-16 12:00:00
#     name       <U58 'CMIP.NUIST.NESM3.historical.r1i1p1f1.Omon.tos.gn.v20190703'
# Attributes:
#     cell_measures:  area: areacello
#     cell_methods:   area: mean where sea time: mean (interval: 1 month)
#     comment:        Temperature of upper boundary of the liquid ocean, includ...
#     long_name:      Sea Surface Temperature
#     standard_name:  sea_surface_temperature
#     units:          degC, <xarray.DataArray 'tos' (j: 200, i: 360)>
# dask.array<getitem, shape=(200, 360), dtype=float32, chunksize=(200, 360), chunktype=numpy.ndarray>
# Coordinates:
#   * i          (i) int32 1 2 3 4 5 6 7 8 9 ... 353 354 355 356 357 358 359 360
#   * j          (j) int32 1 2 3 4 5 6 7 8 9 ... 193 194 195 196 197 198 199 200
#     latitude   (j, i) float32 dask.array<chunksize=(200, 360), meta=np.ndarray>
#     longitude  (j, i) float32 dask.array<chunksize=(200, 360), meta=np.ndarray>
#     time       object 2014-12-16 12:00:00
#     name       <U63 'CMIP.CAMS.CAMS-CSM1-0.historical.r1i1p1f1.Omon.tos.gn.v2...
# Attributes:
#     cell_measures:  area: areacello
#     cell_methods:   area: mean where sea time: mean
#     comment:        Temperature of upper boundary of the liquid ocean, includ...
#     history:        2019-06-11T06:44:45Z altered by CMOR: replaced missing va...
#     long_name:      Sea Surface Temperature
#     original_name:  temp
#     standard_name:  sea_surface_temperature
#     units:          degC, <xarray.DataArray 'tos' (j: 220, i: 256)>
# dask.array<getitem, shape=(220, 256), dtype=float32, chunksize=(220, 256), chunktype=numpy.ndarray>
# Coordinates:
#   * i          (i) int32 0 1 2 3 4 5 6 7 8 ... 248 249 250 251 252 253 254 255
#   * j          (j) int32 0 1 2 3 4 5 6 7 8 ... 212 213 214 215 216 217 218 219
#     latitude   (j, i) float64 dask.array<chunksize=(220, 256), meta=np.ndarray>
#     longitude  (j, i) float64 dask.array<chunksize=(220, 256), meta=np.ndarray>
#     time       datetime64[ns] 2014-12-16T12:00:00
#     name       <U66 'CMIP.MPI-M.MPI-ESM1-2-LR.historical.r1i1p1f1.Omon.tos.gn...
# Attributes:
#     cell_measures:  area: areacello
#     cell_methods:   area: mean where sea time: mean
#     comment:        Temperature of upper boundary of the liquid ocean, includ...
#     history:        2019-09-11T14:21:40Z altered by CMOR: replaced missing va...
#     long_name:      Sea Surface Temperature
#     original_name:  tos
#     standard_name:  sea_surface_temperature
#     units:          degC, <xarray.DataArray 'tos' (j: 404, i: 802)>
# dask.array<getitem, shape=(404, 802), dtype=float32, chunksize=(404, 802), chunktype=numpy.ndarray>
# Coordinates:
#   * i          (i) int32 0 1 2 3 4 5 6 7 8 ... 794 795 796 797 798 799 800 801
#   * j          (j) int32 0 1 2 3 4 5 6 7 8 ... 396 397 398 399 400 401 402 403
#     latitude   (j, i) float64 dask.array<chunksize=(404, 802), meta=np.ndarray>
#     longitude  (j, i) float64 dask.array<chunksize=(404, 802), meta=np.ndarray>
#     time       datetime64[ns] 2014-12-16T12:00:00
#     name       <U66 'CMIP.MPI-M.MPI-ESM1-2-HR.historical.r1i1p1f1.Omon.tos.gn...
# Attributes:
#     cell_measures:  area: areacello
#     cell_methods:   area: mean where sea time: mean
#     comment:        Temperature of upper boundary of the liquid ocean, includ...
#     long_name:      Sea Surface Temperature
#     original_name:  tos
#     standard_name:  sea_surface_temperature
#     units:          degC, <xarray.DataArray 'tos' (y: 576, x: 720)>
# dask.array<getitem, shape=(576, 720), dtype=float32, chunksize=(576, 720), chunktype=numpy.ndarray>
# Coordinates:
#     lat      (y, x) float32 dask.array<chunksize=(576, 720), meta=np.ndarray>
#     lon      (y, x) float32 dask.array<chunksize=(576, 720), meta=np.ndarray>
#     time     object 2014-12-16 12:00:00
#   * x        (x) float64 -299.8 -299.2 -298.8 -298.2 ... 58.25 58.75 59.25 59.75
#   * y        (y) float64 -77.91 -77.72 -77.54 -77.36 ... 89.26 89.47 89.68 89.89
#     name     <U66 'CMIP.NOAA-GFDL.GFDL-ESM4.historical.r1i1p1f1.Omon.tos.gn.v...
# Attributes:
#     cell_measures:  area: areacello
#     cell_methods:   area: mean where sea time: mean
#     long_name:      Sea Surface Temperature
#     original_name:  tos
#     standard_name:  sea_surface_temperature
#     units:          degC, <xarray.DataArray 'tos' (latitude: 80, longitude: 192)>
# dask.array<getitem, shape=(80, 192), dtype=float32, chunksize=(80, 192), chunktype=numpy.ndarray>
# Coordinates:
#   * latitude   (latitude) float64 -88.63 -86.13 -83.88 ... 83.88 86.13 88.63
#   * longitude  (longitude) float64 -0.9375 0.9375 2.812 ... 353.4 355.3 357.2
#     time       object 2014-12-17 00:00:00
#     name       <U60 'CMIP.UA.MCM-UA-1-0.historical.r1i1p1f1.Omon.tos.gn.v2019...
# Attributes:
#     cell_measures:  area: areacello
#     cell_methods:   area: mean where sea time: mean
#     long_name:      Sea Surface Temperature
#     standard_name:  sea_surface_temperature
#     table_id:       Omon
#     units:          degC]

# %%
tos_ds = xr.concat(dset_list, dim='name')
tos_ds
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 tos_ds = xr.concat(dset_list, dim='name')
#       2 tos_ds
#
# File ~/miniconda3/envs/paleoproj/lib/python3.10/site-packages/xarray/core/concat.py:231, in concat(objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     226     raise ValueError(
#     227         f"compat={compat!r} invalid: must be 'broadcast_equals', 'equals', 'identical', 'no_conflicts' or 'override'"
#     228     )
#     230 if isinstance(first_obj, DataArray):
# --> 231     return _dataarray_concat(
#     232         objs,
#     233         dim=dim,
#     234         data_vars=data_vars,
#     235         coords=coords,
#     236         compat=compat,
#     237         positions=positions,
#     238         fill_value=fill_value,
#     239         join=join,
#     240         combine_attrs=combine_attrs,
#     241     )
#     242 elif isinstance(first_obj, Dataset):
#     243     return _dataset_concat(
#     244         objs,
#     245         dim=dim,
#    (...)
#     252         combine_attrs=combine_attrs,
#     253     )
#
# File ~/miniconda3/envs/paleoproj/lib/python3.10/site-packages/xarray/core/concat.py:657, in _dataarray_concat(arrays, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     654             arr = cast(T_DataArray, arr.rename(name))
#     655     datasets.append(arr._to_temp_dataset())
# --> 657 ds = _dataset_concat(
#     658     datasets,
#     659     dim,
#     660     data_vars,
#     661     coords,
#     662     compat,
#     663     positions,
#     664     fill_value=fill_value,
#     665     join=join,
#     666     combine_attrs=combine_attrs,
#     667 )
#     669 merged_attrs = merge_attrs([da.attrs for da in arrays], combine_attrs)
#     671 result = arrays[0]._from_temp_dataset(ds, name)
#
# File ~/miniconda3/envs/paleoproj/lib/python3.10/site-packages/xarray/core/concat.py:466, in _dataset_concat(datasets, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     463 # Make sure we're working on a copy (we'll be loading variables)
#     464 datasets = [ds.copy() for ds in datasets]
#     465 datasets = list(
# --> 466     align(*datasets, join=join, copy=False, exclude=[dim], fill_value=fill_value)
#     467 )
#     469 dim_coords, dims_sizes, coord_names, data_names = _parse_datasets(datasets)
#     470 dim_names = set(dim_coords)
#
# File ~/miniconda3/envs/paleoproj/lib/python3.10/site-packages/xarray/core/alignment.py:771, in align(join, copy, indexes, exclude, fill_value, *objects)
#     575 """
#     576 Given any number of Dataset and/or DataArray objects, returns new
#     577 objects with aligned indexes and dimension sizes.
#    (...)
#     761
#     762 """
#     763 aligner = Aligner(
#     764     objects,
#     765     join=join,
#    (...)
#     769     fill_value=fill_value,
#     770 )
# --> 771 aligner.align()
#     772 return aligner.results
#
# File ~/miniconda3/envs/paleoproj/lib/python3.10/site-packages/xarray/core/alignment.py:559, in Aligner.align(self)
#     557 self.assert_no_index_conflict()
#     558 self.align_indexes()
# --> 559 self.assert_unindexed_dim_sizes_equal()
#     561 if self.join == "override":
#     562     self.override_indexes()
#
# File ~/miniconda3/envs/paleoproj/lib/python3.10/site-packages/xarray/core/alignment.py:459, in Aligner.assert_unindexed_dim_sizes_equal(self)
#     457     add_err_msg = ""
#     458 if len(sizes) > 1:
# --> 459     raise ValueError(
#     460         f"cannot reindex or align along dimension {dim!r} "
#     461         f"because of conflicting dimension sizes: {sizes!r}" + add_err_msg
#     462     )
#
# ValueError: cannot reindex or align along dimension 'y' because of conflicting dimension sizes: {832, 332} (note: an index is found along that dimension with size=832)
