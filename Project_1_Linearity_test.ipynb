# %% [markdown]
# # LIBRARY

# %%
from netCDF4 import Dataset as NetCDFFile
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
import netCDF4 as nc
from netCDF4 import Dataset
from matplotlib import gridspec
import glob
import cartopy.crs as ccrs
from matplotlib.pyplot import cm
import numpy as np
from mpl_toolkits.axes_grid1 import ImageGrid
import pylab

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
from mpl_toolkits.axes_grid1 import ImageGrid
import pylab

# %% [markdown]
# # Load Data

# %%
data_15_both=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_15/CESM_output_data/atm/hist/*")
data_15_last18_both=data_15_both[24:240] # Get years 3-20
data_15_data_both = xr.open_mfdataset(data_15_last18_both,combine="by_coords",use_cftime=True)
data_15 = data_15_data_both.mean('time') # Average over the last 18 years

# %%
data_15_path_s=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_15_s/CESM_output_data/atm/hist/*")
data_15_last18_s=data_15_path_s[24:240] # Get years 3-20
data_15_data_s = xr.open_mfdataset(data_15_last18_s,combine="by_coords",use_cftime=True)
data_15_s = data_15_data_s.mean('time') # Average over the last 18 years

# %%
data_control_path = glob.glob("/data/keeling/a/pappup2/a/CESM/cam5_new/CESM_output_data/atm/hist/*") #End of year control
data_control_last18=data_control_path[24:240] # Get years 3-20
data_control_data = xr.open_mfdataset(data_control_last18,combine="by_coords",use_cftime=True)
data_control = data_control_data.mean('time') # Average over the last 18 years

data_pole_path = glob.glob("/data/keeling/a/pappup2/a/CESM/cam_90_n/CESM_output_data/atm/hist/*") #End of year expriment-2 extraopical patch
data_pole_last18=data_pole_path[24:240] # Get years 3-20
data_pole_data = xr.open_mfdataset(data_pole_last18,combine="by_coords",use_cftime=True)
data_pole_n = data_pole_data.mean('time') # Average over the last 18 years


data_00_path = glob.glob("/data/keeling/a/pappup2/a/CESM/cam_00/CESM_output_data/atm/hist/*")
data_00_last18=data_00_path[24:240] # Get years 3-20
data_00_data = xr.open_mfdataset(data_00_last18,combine="by_coords",use_cftime=True)
data_00 = data_00_data.mean('time') # Average over the last 18 years


data_05_path = glob.glob("/data/keeling/a/pappup2/a/CESM/cam_05_n/CESM_output_data/atm/hist/*")
data_05_last18=data_05_path[24:240] # Get years 3-20
data_05_data = xr.open_mfdataset(data_05_last18,combine="by_coords",use_cftime=True)
data_05_n = data_05_data.mean('time') # Average over the last 18 years

data_10_path=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_10_n/CESM_output_data/atm/hist/*")
data_10_last18=data_10_path[24:240] # Get years 3-20
data_10_data = xr.open_mfdataset(data_10_last18,combine="by_coords",use_cftime=True)
data_10_n = data_10_data.mean('time') # Average over the last 18 years

data_15_path=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_15_n/CESM_output_data/atm/hist/*")
data_15_last18=data_15_path[24:240] # Get years 3-20
data_15_data = xr.open_mfdataset(data_15_last18,combine="by_coords",use_cftime=True)
data_15_n = data_15_data.mean('time') # Average over the last 18 years

data_20_path=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_20_n/CESM_output_data/atm/hist/*")
data_20_last18=data_20_path[24:240] # Get years 3-20
data_20_data = xr.open_mfdataset(data_20_last18,combine="by_coords",use_cftime=True)
data_20_n = data_20_data.mean('time') # Average over the last 18 years

data_25_path=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_25_n/CESM_output_data/atm/hist/*")
data_25_last18=data_25_path[24:240] # Get years 3-20
data_25_data = xr.open_mfdataset(data_25_last18,combine="by_coords",use_cftime=True)
data_25_n = data_25_data.mean('time') # Average over the last 18 years

data_30_path=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_30_n/CESM_output_data/atm/hist/*")
data_30_last18=data_30_path[24:240] # Get years 3-20
data_30_data = xr.open_mfdataset(data_30_last18,combine="by_coords",use_cftime=True)
data_30_n = data_30_data.mean('time') # Average over the last 18 years

data_35_path=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_35_n/CESM_output_data/atm/hist/*")
data_35_last18=data_35_path[24:240] # Get years 3-20
data_35_data = xr.open_mfdataset(data_35_last18,combine="by_coords",use_cftime=True)
data_35_n = data_35_data.mean('time') # Average over the last 18 years

data_40_path=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_40_n/CESM_output_data/atm/hist/*")
data_40_last18=data_40_path[24:240] # Get years 3-20
data_40_data = xr.open_mfdataset(data_40_last18,combine="by_coords",use_cftime=True)
data_40_n = data_40_data.mean('time') # Average over the last 18 years


data_extratropic_path=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_45_n/CESM_output_data/atm/hist/*")
data_extratropic_last18=data_extratropic_path[24:240] # Get years 3-20
data_extratropic_data = xr.open_mfdataset(data_extratropic_last18,combine="by_coords",use_cftime=True)
data_45_n = data_extratropic_data.mean('time') # Average over the last 18 years

data_50_path=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_50_n/CESM_output_data/atm/hist/*")
data_50_last18=data_50_path[24:240] # Get years 3-20
data_50_data = xr.open_mfdataset(data_50_last18,combine="by_coords",use_cftime=True)
data_50_n = data_50_data.mean('time') # Average over the last 18 years

data_55_path=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_55_n/CESM_output_data/atm/hist/*")
data_55_last18=data_55_path[24:240] # Get years 3-20
data_55_data = xr.open_mfdataset(data_55_last18,combine="by_coords",use_cftime=True)
data_55_n = data_55_data.mean('time') # Average over the last 18 years


data_60_path=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_60_n/CESM_output_data/atm/hist/*")
data_60_last18=data_60_path[24:240] # Get years 3-20
data_60_data = xr.open_mfdataset(data_60_last18,combine="by_coords",use_cftime=True)
data_60_n = data_60_data.mean('time') # Average over the last 18 years

data_65_path=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_65_n/CESM_output_data/atm/hist/*")
data_65_last18=data_65_path[24:240] # Get years 3-20
data_65_data = xr.open_mfdataset(data_65_last18,combine="by_coords",use_cftime=True)
data_65_n = data_65_data.mean('time') # Average over the last 18 years

data_70_path=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_70_n/CESM_output_data/atm/hist/*")
data_70_last18=data_70_path[24:240] # Get years 3-20
data_70_data = xr.open_mfdataset(data_70_last18,combine="by_coords",use_cftime=True)
data_70_n = data_70_data.mean('time') # Average over the last 18 years


data_75_path=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_75_n/CESM_output_data/atm/hist/*")
data_75_last18=data_75_path[24:240] # Get years 3-20
data_75_data = xr.open_mfdataset(data_75_last18,combine="by_coords",use_cftime=True)
data_75_n = data_75_data.mean('time') # Average over the last 18 years

data_80_path=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_80_n/CESM_output_data/atm/hist/*")
data_80_last18=data_80_path[24:240] # Get years 3-20
data_80_data = xr.open_mfdataset(data_80_last18,combine="by_coords",use_cftime=True)
data_80_n = data_80_data.mean('time') # Average over the last 18 years

data_85_path=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_85_n/CESM_output_data/atm/hist/*")
data_85_last18=data_85_path[24:240] # Get years 3-20
data_85_data = xr.open_mfdataset(data_85_last18,combine="by_coords",use_cftime=True)
data_85_n = data_85_data.mean('time') # Average over the last 18 years

#2k increase everywhere experiment
data_2k_path=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_2k/CESM_output_data/atm/hist/*")
data_2k_last18=data_2k_path[24:240] # Get years 3-20
data_2k_data = xr.open_mfdataset(data_2k_last18,combine="by_coords",use_cftime=True)
data_2k = data_2k_data.mean('time') # Average over the last 18 years

#surface_t2 = surface_t_2.mean('lon')
TOA_flux_exp_minus_control_00 = (data_00.FSNT.mean('lon')-data_00.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_05_n = (data_05_n.FSNT.mean('lon')-data_05_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_10_n = (data_10_n.FSNT.mean('lon')-data_10_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_15_n = (data_15_n.FSNT.mean('lon')-data_15_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_20_n = (data_20_n.FSNT.mean('lon')-data_20_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_25_n = (data_25_n.FSNT.mean('lon')-data_25_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_30_n = (data_30_n.FSNT.mean('lon')-data_30_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_35_n = (data_35_n.FSNT.mean('lon')-data_35_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_40_n = (data_40_n.FSNT.mean('lon')-data_40_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_45_n = (data_45_n.FSNT.mean('lon')-data_45_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_50_n = (data_50_n.FSNT.mean('lon')-data_50_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_55_n = (data_55_n.FSNT.mean('lon')-data_55_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_60_n = (data_60_n.FSNT.mean('lon')-data_60_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_65_n = (data_65_n.FSNT.mean('lon')-data_65_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_70_n = (data_70_n.FSNT.mean('lon')-data_70_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_75_n = (data_75_n.FSNT.mean('lon')-data_75_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_80_n = (data_80_n.FSNT.mean('lon')-data_80_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_85_n = (data_85_n.FSNT.mean('lon')-data_85_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_pole_n = (data_pole_n.FSNT.mean('lon')-data_pole_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

# %%
data_4k_n_path=glob.glob("/data/keeling/a/pappup2/a/CESM/cam_4k_n/CESM_output_data/atm/hist/*")
data_4k_n_last18=data_4k_n_path[24:240] # Get years 3-20
data_4k_n_data = xr.open_mfdataset(data_4k_n_last18,combine="by_coords",use_cftime=True)
data_4k_n = data_4k_n_data.mean('time') # Average over the last 18 years

# %% [markdown]
# # Non-linearity Test

# %%
pole=data_pole_n.TS.mean('lon')-data_control.TS.mean('lon')
zero=data_00.TS.mean('lon')-data_control.TS.mean('lon')
five=data_05_n.TS.mean('lon')-data_control.TS.mean('lon')
ten=data_10_n.TS.mean('lon')-data_control.TS.mean('lon')
fifteen=data_15_n.TS.mean('lon')-data_control.TS.mean('lon')
twenty=data_20_n.TS.mean('lon')-data_control.TS.mean('lon')
twentyfive=data_25_n.TS.mean('lon')-data_control.TS.mean('lon')
thirty=data_30_n.TS.mean('lon')-data_control.TS.mean('lon')
thirtyfive=data_35_n.TS.mean('lon')-data_control.TS.mean('lon')
fourty=data_40_n.TS.mean('lon')-data_control.TS.mean('lon')
fourtyfive=data_45_n.TS.mean('lon')-data_control.TS.mean('lon')
fifty=data_50_n.TS.mean('lon')-data_control.TS.mean('lon')
fiftyfive=data_55_n.TS.mean('lon')-data_control.TS.mean('lon')
sixty=data_60_n.TS.mean('lon')-data_control.TS.mean('lon')
sixtyfive=data_65_n.TS.mean('lon')-data_control.TS.mean('lon')
seventy=data_70_n.TS.mean('lon')-data_control.TS.mean('lon')
seventyfive=data_75_n.TS.mean('lon')-data_control.TS.mean('lon')
eighty=data_80_n.TS.mean('lon')-data_control.TS.mean('lon')
eightyfive=data_85_n.TS.mean('lon')-data_control.TS.mean('lon')

# %%
two_k = data_2k.TS.mean('lon')-data_control.TS.mean('lon')
squre_two_k=two_k**2

# %%
squre_total=pole**2+zero**2+five**2+ten**2+fifteen**2+twenty**2+twentyfive**2+thirty**2+thirtyfive**2+fourty**2+fourtyfive**2+fifty**2+fiftyfive**2+sixty**2+sixtyfive**2+seventy**2+seventyfive**2+eighty**2+eightyfive**2
total=pole+zero+five+ten+fifteen+twenty+twentyfive+thirty+thirtyfive+fourty+fourtyfive+fifty+fiftyfive+sixty+sixtyfive+seventy+seventyfive+eighty+eightyfive

# %%
diff=2*squre_two_k-squre_total

# %%
total.plot()

# %%
surface_t4 = data_4k_n.TS.mean('lon')-data_control.TS.mean('lon')
surface_t4.plot()

# %%
squre_total.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 squre_total.plot()
#
# NameError: name 'squre_total' is not defined

# %%
diff.plot()

# %% [markdown]
# Flip test

# %% [raw]
# #data_15_s=data_15_n.reindex(lat=data_15_n.lat[::-1])
# #data_15_sdata_15_n.isel(lat=slice(-1,None,None))
#
# surface_t3 = data_15_s.TS.mean('lon')-data_control.TS.mean('lon')
# y=surface_t3
# #surface_t3=surface_t2.reindex(lat=list(reversed(surface_t2)))
# print(y)

# %% [raw]
# data_15_s=data_15_n.reindex(lat=data_15_n.lat[::-1]).TS
# data_15_s=data_15_n.reindex(lat=data_15_n.lat[::-1])

# %%
# It did not work

# %%
#surface_t2 = surface_t_2.mean('lon')
surface_t1 = data_15.TS.mean('lon')-data_control.TS.mean('lon')
surface_t1.plot(color="red",label=" 15")

surface_t2 = data_15_n.TS.mean('lon')-data_control.TS.mean('lon')
surface_t2.plot(color="black",label=" 15_n",linestyle='dashed')

#plt.plot(x,y,color="green")
surface_t3 = data_15_s.TS.mean('lon')-data_control.TS.mean('lon')
surface_t3.plot(color="green",label=" 15_s",linestyle='dashed')
#surface_t2.plot(label="Result of prescribed SST--equatorial band")
plt.legend(loc='lower right')

# %%
add=(data_15_s+data_15_n)/2

# %%
add.TS.mean('lon').plot(label='add/2',color='black')
data_control.TS.mean('lon').plot(label='control')
data_15.TS.mean('lon').plot(label='15')
plt.legend(loc='lower right')

# %% [markdown]
# # TOA FLUX

# %%
TOA_flux_exp_minus_control_15_s = (data_15_s.FSNT.mean('lon')-data_15_s.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_15 =(data_15.FSNT.mean('lon')-data_15.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))


TOA_flux_exp_minus_control_15_ns=TOA_flux_exp_minus_control_15_n+TOA_flux_exp_minus_control_15_s

pp_15_ns=np.array(TOA_flux_exp_minus_control_15_ns)
#zp= pp.transpose()
exp_15_ns=np.linspace(0,1,96)
plat_15_ns=np.array(TOA_flux_exp_minus_control_15_ns.lat)
expp_15_ns, ppp_15_ns=np.meshgrid(exp_15_ns, pp_15_ns)

pp_15=np.array(TOA_flux_exp_minus_control_15)
#zp= pp.transpose()
exp_15=np.linspace(0,1,96)
plat_15=np.array(TOA_flux_exp_minus_control_15.lat)
expp_15, ppp_15=np.meshgrid(exp_15, pp_15)

# %%
nrow = 1
ncol = 3
fig = plt.figure(figsize=(15, 15))
grid = ImageGrid(fig, 
                 111, # as in plt.subplot(111)
                 nrows_ncols=(nrow,ncol),
                 axes_pad=0,
                 share_all=True,)

#for i in range(1):
#    for j in range(2):
im = np.random.rand(28,28)
gs = gridspec.GridSpec(3, 3)
gs.update(wspace=0)
vmax=20
vmin=-20
plt.subplot(gs[0,0])
plt.pcolormesh(expp_15,plat_15,ppp_15,cmap='RdBu_r',vmax=vmax, vmin=vmin)
plt.yticks(np.arange(-90, 91, 30))
plt.ylabel("Latitude")
plt.xticks([])
plt.xlabel("15")

plt.subplot(gs[0,1])
plt.pcolormesh(expp_15_ns,plat_15_ns,ppp_15_ns,cmap='RdBu_r',vmax=vmax, vmin=vmin)
plt.xticks([])
plt.xlabel("15_ns")
ax = pylab.gca()
ax.yaxis.set_visible(False)



# Get the current axis
ax = pylab.gca()
# Set Y-axis visibility to False
ax.yaxis.set_visible(False)

#        plt.set_yticklabels([])

#plt.tight_layout() # do not use this!!
#plt.subplot(gs[0,8])
plt.colorbar(shrink=1)
plt.show()

# %% [markdown]
# # short wave TOA

# %%
sTOA_flux_exp_minus_control_15_n = (data_15_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_flux_exp_minus_control_15_s = (data_15_s.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))

sTOA_flux_exp_minus_control_15 = (data_15.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))


sTOA_flux_exp_minus_control_15_ns=sTOA_flux_exp_minus_control_15_n+sTOA_flux_exp_minus_control_15_s

# %%
pp_15=np.array(sTOA_flux_exp_minus_control_15)
#zp= pp.transpose()
exp_15=np.linspace(0,1,96)
plat_15=np.array(sTOA_flux_exp_minus_control_15.lat)
expp_15, ppp_15=np.meshgrid(exp_15, pp_15)

pp_15_ns=np.array(sTOA_flux_exp_minus_control_15_ns)
#zp= pp.transpose()
exp_15_ns=np.linspace(0,1,96)
plat_15_ns=np.array(sTOA_flux_exp_minus_control_15_ns.lat)
expp_15_ns, ppp_15_ns=np.meshgrid(exp_15_ns, pp_15_ns)

# %%
im = np.random.rand(28,28)
gs = gridspec.GridSpec(3, 3)
gs.update(wspace=0)
vmax=30
vmin=-30
plt.subplot(gs[0,0])
plt.pcolormesh(expp_15,plat_15,ppp_15,cmap='RdBu_r',vmax=vmax, vmin=vmin)
plt.yticks(np.arange(-90, 91, 30))
plt.ylabel("Latitude")
plt.xticks([])
plt.xlabel("15")

plt.subplot(gs[0,1])
plt.pcolormesh(expp_15_ns,plat_15_ns,ppp_15_ns,cmap='RdBu_r',vmax=vmax, vmin=vmin)
plt.xticks([])
plt.xlabel("15_ns")
ax = pylab.gca()
ax.yaxis.set_visible(False)



# Get the current axis
ax = pylab.gca()
# Set Y-axis visibility to False
ax.yaxis.set_visible(False)

#        plt.set_yticklabels([])

#plt.tight_layout() # do not use this!!
#plt.subplot(gs[0,8])
plt.colorbar(shrink=1)
plt.show()

# %% [markdown]
# # Long Wave TOA

# %%
lTOA_flux_exp_minus_control_15_n = (data_15_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_flux_exp_minus_control_15_s = (data_15_s.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))

lTOA_flux_exp_minus_control_15 = (data_15.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))


lTOA_flux_exp_minus_control_15_ns=lTOA_flux_exp_minus_control_15_n+lTOA_flux_exp_minus_control_15_s

# %%
pp_15=np.array(lTOA_flux_exp_minus_control_15)
#zp= pp.transpose()
exp_15=np.linspace(0,1,96)
plat_15=np.array(lTOA_flux_exp_minus_control_15.lat)
expp_15, ppp_15=np.meshgrid(exp_15, pp_15)

pp_15_ns=np.array(sTOA_flux_exp_minus_control_15_ns)
#zp= pp.transpose()
exp_15_ns=np.linspace(0,1,96)
plat_15_ns=np.array(lTOA_flux_exp_minus_control_15_ns.lat)
expp_15_ns, ppp_15_ns=np.meshgrid(exp_15_ns, pp_15_ns)

# %%
im = np.random.rand(28,28)
gs = gridspec.GridSpec(3, 3)
gs.update(wspace=0)
vmax=30
vmin=-30
plt.subplot(gs[0,0])
plt.pcolormesh(expp_15,plat_15,ppp_15,cmap='RdBu_r',vmax=vmax, vmin=vmin)
plt.yticks(np.arange(-90, 91, 30))
plt.ylabel("Latitude")
plt.xticks([])
plt.xlabel("15")

plt.subplot(gs[0,1])
plt.pcolormesh(expp_15_ns,plat_15_ns,ppp_15_ns,cmap='RdBu_r',vmax=vmax, vmin=vmin)
plt.xticks([])
plt.xlabel("15_ns")
ax = pylab.gca()
ax.yaxis.set_visible(False)



# Get the current axis
ax = pylab.gca()
# Set Y-axis visibility to False
ax.yaxis.set_visible(False)

#        plt.set_yticklabels([])

#plt.tight_layout() # do not use this!!
#plt.subplot(gs[0,8])
plt.colorbar(shrink=1)
plt.show()

# %% [markdown]
# # Zonal TOA, Qs, QA

# %%
TOA_15_n = (data_15_n.FSNT.mean('lon')-data_15_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_15_s = (data_15_s.FSNT.mean('lon')-data_15_s.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

TOA_15_ns=TOA_15_n+TOA_15_s
TOA_15 = (data_15.FSNT.mean('lon')-data_15.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

# %%
TOA_15_ns.plot( label='15_ns patch')
TOA_15.plot( label='15 patch')

plt.legend(loc='upper left')
plt.title('TOA flux')
# Out:
# Text(0.5, 1.0, 'TOA flux')

# %%
Qs_15_n=(-data_15_n.FLNS.mean('lon')+data_15_n.FSNS.mean('lon')-data_15_n.SHFLX.mean('lon')-data_15_n.LHFLX.mean('lon'))-(-data_control.FLNS.mean('lon')+data_control.FSNS.mean('lon')-data_control.SHFLX.mean('lon')-data_control.LHFLX.mean('lon'))
Qs_15_s=(-data_15_s.FLNS.mean('lon')+data_15_s.FSNS.mean('lon')-data_15_s.SHFLX.mean('lon')-data_15_s.LHFLX.mean('lon'))-(-data_control.FLNS.mean('lon')+data_control.FSNS.mean('lon')-data_control.SHFLX.mean('lon')-data_control.LHFLX.mean('lon'))

Qs_15_ns=Qs_15_n+Qs_15_s
Qs_15=(-data_15.FLNS.mean('lon')+data_15.FSNS.mean('lon')-data_15.SHFLX.mean('lon')-data_15.LHFLX.mean('lon'))-(-data_control.FLNS.mean('lon')+data_control.FSNS.mean('lon')-data_control.SHFLX.mean('lon')-data_control.LHFLX.mean('lon'))

# %%
Qs_15_ns.plot( label='15_ns patch')
Qs_15.plot( label='15 patch')

plt.legend(loc='upper left')
plt.title('Qs')
# Out:
# Text(0.5, 1.0, 'Qs')

# %%
Qa_15_n=Qs_15_n-TOA_15_n
Qa_15_s=Qs_15_s-TOA_15_s

Qa_15_ns=Qa_15_n+Qa_15_s
Qa_15=Qs_15-TOA_15

# %%
Qa_15_ns.plot( label='15_ns patch')
Qa_15.plot( label='15 patch')

plt.legend(loc='upper left')
plt.title('Qa')
# Out:
# Text(0.5, 1.0, 'Qa')

# %%
Qa_15_s=Qs_15_s-TOA_15_s
Qa_15_s.plot(color='green', label='Qa_sh')

Qa_15_n=Qs_15_n-TOA_15_n
Qa_15_n.plot(color='red', label='Qa_nh')


plt.legend(loc='upper right')
plt.title("15 deg Patch")
# Out:
# Text(0.5, 1.0, '15 deg Patch')

# %%
Qs_15_s.plot(color='green', label='Qs_sh')

Qs_15_n.plot(color='red', label='Qs_nh')


plt.legend(loc='upper right')
plt.title("15 deg Patch")
# Out:
# Text(0.5, 1.0, '15 deg Patch')

# %%
TOA_15_s.plot(color='green', label='TOA_sh')

TOA_15_n.plot(color='red', label='TOA_nh')


plt.legend(loc='upper right')
plt.title("15 deg Patch")
# Out:
# Text(0.5, 1.0, '15 deg Patch')

# %% [markdown]
# # Vertical Temp

# %%
T_15_n=data_15_n.T.mean('lon')-data_control.T.mean('lon')
T_15_s=data_15_s.T.mean('lon')-data_control.T.mean('lon')

T_15_ns=T_15_n+T_15_s
T_15=data_15.T.mean('lon')-data_control.T.mean('lon')

# %%
im = np.random.rand(28,28)
gs = gridspec.GridSpec(2, 2)
gs.update(wspace=0.1)

plt.subplot(gs[0,0])
T_15_ns.plot(yincrease=False, cmap='RdBu_r',add_colorbar=False)
#plt.yscale("log")
plt.title('15_ns')
ax = pylab.gca()
plt.xticks([-90, -80, -60,-40,-20,0,20,40,60,80,90])
plt.yticks([1000, 800, 600,400,200])
plt.xticks(rotation=90)

plt.subplot(gs[0,1])
T_15.plot(yincrease=False, cmap='RdBu_r')
#plt.yscale("log")
plt.title('15')
ax = pylab.gca()
ax.yaxis.set_visible(False)
plt.xticks([-90, -80, -60,-40,-20,0,20,40,60,80,90])
plt.xticks(rotation=90)

# Get the current axis
ax = pylab.gca()
# Set Y-axis visibility to False
ax.yaxis.set_visible(False)

#        plt.set_yticklabels([])

#plt.tight_layout() # do not use this!!
#plt.subplot(gs[0,6])
#plt.colorbar()
plt.show()

# %% [markdown]
# # All Sky, Clear Sky & CRE

# %%
css_15_n=data_15_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_15_s=data_15_s.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')

css_15_ns=css_15_n+css_15_s
css_15=data_15.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')

csl_15_n=data_15_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_15_s=data_15_s.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')

csl_15_ns=csl_15_n+csl_15_s
csl_15=data_15.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')

ass_15_n=data_15_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_15_s=data_15_s.FSNT.mean('lon')-data_control.FSNT.mean('lon')

ass_15_ns=ass_15_n+ass_15_s
ass_15=data_15.FSNT.mean('lon')-data_control.FSNT.mean('lon')

asl_15_n=data_15_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_15_s=data_15_s.FLNT.mean('lon')-data_control.FLNT.mean('lon')

asl_15_ns=asl_15_n+asl_15_s
asl_15=data_15.FLNT.mean('lon')-data_control.FLNT.mean('lon')

CRES_15_n = (data_15_n.FSNT.mean('lon')-data_15_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_15_s = (data_15_s.FSNT.mean('lon')-data_15_s.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))

CRES_15_ns=CRES_15_n+CRES_15_s
CRES_15 = (data_15.FSNT.mean('lon')-data_15.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))

CREL_15_n = (data_15_n.FLNT.mean('lon')-data_15_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_15_s = (data_15_s.FLNT.mean('lon')-data_15_s.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))

CREL_15_ns=CREL_15_n+CREL_15_s
CREL_15 = (data_15.FLNT.mean('lon')-data_15.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))

# %%
tcs_15_n=css_15_n-csl_15_n
tcs_15_s=css_15_s-csl_15_s

tcs_15_ns=tcs_15_n+tcs_15_s
tcs_15=css_15-csl_15

tas_15_n=ass_15_n-asl_15_n
tas_15_s=ass_15_s-asl_15_s

tas_15_ns=tas_15_n+tas_15_s
tas_15=ass_15-asl_15

tCRE_15_n=CRES_15_n-CREL_15_n
tCRE_15_s=CRES_15_s-CREL_15_s

tCRE_15_ns=tCRE_15_n+tCRE_15_s
tCRE_15=CRES_15-CREL_15

# %%
CRES_15_ns.plot(label='CRES_15_ns')
CRES_15.plot(label='CRES_15')


plt.legend(loc='lower left')
plt.title("CRES")
# Out:
# Text(0.5, 1.0, 'CRES')

# %%
CREL_15_ns.plot(label='CREL_15_ns')
CREL_15.plot(label='CREL_15')


plt.legend(loc='lower left')
plt.title("CREL")
# Out:
# Text(0.5, 1.0, 'CREL')

# %%
tCRE_15_ns.plot(label='15_ns')
tCRE_15.plot(label='15')


plt.legend(loc='lower left')
plt.title("Total CRE")
# Out:
# Text(0.5, 1.0, 'Total CRE')

# %%
tas_15_ns.plot(label='15_ns')
tas_15.plot(label='15')


plt.legend(loc='lower left')
plt.title("Total All Sky")
# Out:
# Text(0.5, 1.0, 'Total All Sky')

# %%
tcs_15_ns.plot(label='15_ns')
tcs_15.plot(label='15')


plt.legend(loc='lower left')
plt.title("Total Clear Sky")
# Out:
# Text(0.5, 1.0, 'Total Clear Sky')

# %% [markdown]
# # Comperison with +4k NH exp and sum of all NH exp

# %%
TOA_flux_exp_minus_control_00 = (data_00.FSNT.mean('lon')-data_00.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_05_n = (data_05_n.FSNT.mean('lon')-data_05_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_10_n = (data_10_n.FSNT.mean('lon')-data_10_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_15_n = (data_15_n.FSNT.mean('lon')-data_15_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_20_n = (data_20_n.FSNT.mean('lon')-data_20_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_25_n = (data_25_n.FSNT.mean('lon')-data_25_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_30_n = (data_30_n.FSNT.mean('lon')-data_30_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_35_n = (data_35_n.FSNT.mean('lon')-data_35_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_40_n = (data_40_n.FSNT.mean('lon')-data_40_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_45_n = (data_45_n.FSNT.mean('lon')-data_45_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_50_n = (data_50_n.FSNT.mean('lon')-data_50_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_55_n = (data_55_n.FSNT.mean('lon')-data_55_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_60_n = (data_60_n.FSNT.mean('lon')-data_60_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_65_n = (data_65_n.FSNT.mean('lon')-data_65_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_70_n = (data_70_n.FSNT.mean('lon')-data_70_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_75_n = (data_75_n.FSNT.mean('lon')-data_75_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_80_n = (data_80_n.FSNT.mean('lon')-data_80_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_85_n = (data_85_n.FSNT.mean('lon')-data_85_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_flux_exp_minus_control_pole_n = (data_pole_n.FSNT.mean('lon')-data_pole_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

# %%
Sum_TOA_NH_exp=TOA_flux_exp_minus_control_00+TOA_flux_exp_minus_control_05_n+TOA_flux_exp_minus_control_10_n+TOA_flux_exp_minus_control_15_n+TOA_flux_exp_minus_control_20_n+TOA_flux_exp_minus_control_25_n+TOA_flux_exp_minus_control_30_n+TOA_flux_exp_minus_control_35_n+TOA_flux_exp_minus_control_40_n+TOA_flux_exp_minus_control_45_n+TOA_flux_exp_minus_control_50_n+TOA_flux_exp_minus_control_55_n+TOA_flux_exp_minus_control_60_n+TOA_flux_exp_minus_control_65_n+TOA_flux_exp_minus_control_70_n+TOA_flux_exp_minus_control_75_n+TOA_flux_exp_minus_control_80_n+TOA_flux_exp_minus_control_85_n+TOA_flux_exp_minus_control_pole_n
#sum_of_all_patches=data_00+data_05_n+data_10_n+data_15_n+data_20_n+data_25_n+data_30_n+data_35_n+data_40_n+data_45_n+data_50_n+data_55_n+data_60_n+data_65_n+data_70_n+data_75_n+data_80_n+data_85_n+data_pole_n
#Sum_TOA_NH_exp=(sum_of_all_patches.FSNT.mean('lon')-sum_of_all_patches.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

# %%
TOA_flux_exp_minus_control_4k_n = (data_4k_n.FSNT.mean('lon')-data_4k_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

# %%
pp_total=np.array(Sum_TOA_NH_exp)
exp_total=np.linspace(0,1,96)
plat_total=np.array(Sum_TOA_NH_exp.lat)
expp_total, ppp_total=np.meshgrid(exp_total, pp_total)

pp_4k_n=np.array(TOA_flux_exp_minus_control_4k_n)
exp_4k_n=np.linspace(0,1,96)
plat_4k_n=np.array(TOA_flux_exp_minus_control_4k_n.lat)
expp_4k_n, ppp_4k_n=np.meshgrid(exp_4k_n, pp_4k_n)

# %%
nrow = 1
ncol = 3
fig = plt.figure(figsize=(5, 5))
grid = ImageGrid(fig, 
                 111, # as in plt.subplot(111)
                 nrows_ncols=(nrow,ncol),
                 axes_pad=0,
                 share_all=True,)

#for i in range(1):
#    for j in range(2):
im = np.random.rand(28,28)
gs = gridspec.GridSpec(2, 2)
gs.update(wspace=0)
vmax=50
vmin=-50
plt.subplot(gs[0,0])
plt.pcolormesh(expp_total,plat_total,ppp_total,cmap='seismic',vmax=vmax,vmin=vmin)
plt.yticks(np.arange(-90, 91, 30))
plt.ylabel("Latitude")
plt.xticks([])
plt.xlabel("Sum of all NH EXP")

plt.subplot(gs[0,1])
plt.pcolormesh(expp_4k_n,plat_4k_n,ppp_4k_n,cmap='seismic',vmax=vmax,vmin=vmin)
plt.xticks([])
plt.xlabel("+4K NH EXP")
ax = pylab.gca()
ax.yaxis.set_visible(False)

plt.colorbar(shrink=1)
plt.show()

# %%
#short wave of TOA flux
sTOA_flux_exp_minus_control_00 = (data_00.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_flux_exp_minus_control_05_n = (data_05_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_flux_exp_minus_control_10_n = (data_10_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_flux_exp_minus_control_15_n = (data_15_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_flux_exp_minus_control_20_n = (data_20_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_flux_exp_minus_control_25_n = (data_25_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_flux_exp_minus_control_30_n = (data_30_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_flux_exp_minus_control_35_n = (data_35_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_flux_exp_minus_control_40_n = (data_40_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_flux_exp_minus_control_45_n = (data_45_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_flux_exp_minus_control_50_n = (data_50_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_flux_exp_minus_control_55_n = (data_55_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_flux_exp_minus_control_60_n = (data_60_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_flux_exp_minus_control_65_n = (data_65_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_flux_exp_minus_control_70_n = (data_70_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_flux_exp_minus_control_75_n = (data_75_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_flux_exp_minus_control_80_n = (data_80_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_flux_exp_minus_control_85_n = (data_85_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_flux_exp_minus_control_pole_n = (data_pole_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))


#long wave of TOA flux
lTOA_flux_exp_minus_control_00 = (data_00.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_flux_exp_minus_control_05_n = (data_05_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_flux_exp_minus_control_10_n = (data_10_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_flux_exp_minus_control_15_n = (data_15_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_flux_exp_minus_control_20_n = (data_20_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_flux_exp_minus_control_25_n = (data_25_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_flux_exp_minus_control_30_n = (data_30_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_flux_exp_minus_control_35_n = (data_35_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_flux_exp_minus_control_40_n = (data_40_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_flux_exp_minus_control_45_n = (data_45_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_flux_exp_minus_control_50_n = (data_50_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_flux_exp_minus_control_55_n = (data_55_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_flux_exp_minus_control_60_n = (data_60_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_flux_exp_minus_control_65_n = (data_65_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_flux_exp_minus_control_70_n = (data_70_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_flux_exp_minus_control_75_n = (data_75_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_flux_exp_minus_control_80_n = (data_80_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_flux_exp_minus_control_85_n = (data_85_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_flux_exp_minus_control_pole_n = (data_pole_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))

# %%
#shortwave TOA Flux
sTOA_flux_exp_minus_control_4k_n = (data_4k_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sw_Sum_TOA_NH_exp=sTOA_flux_exp_minus_control_00+sTOA_flux_exp_minus_control_05_n+sTOA_flux_exp_minus_control_10_n+sTOA_flux_exp_minus_control_15_n+sTOA_flux_exp_minus_control_20_n+sTOA_flux_exp_minus_control_25_n+sTOA_flux_exp_minus_control_30_n+sTOA_flux_exp_minus_control_35_n+sTOA_flux_exp_minus_control_40_n+sTOA_flux_exp_minus_control_45_n+sTOA_flux_exp_minus_control_50_n+sTOA_flux_exp_minus_control_55_n+sTOA_flux_exp_minus_control_60_n+sTOA_flux_exp_minus_control_65_n+sTOA_flux_exp_minus_control_70_n+sTOA_flux_exp_minus_control_75_n+sTOA_flux_exp_minus_control_80_n+sTOA_flux_exp_minus_control_85_n+sTOA_flux_exp_minus_control_pole_n

#long wave of TOA flux
lTOA_flux_exp_minus_control_4k_n = (data_4k_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lw_Sum_TOA_NH_exp=lTOA_flux_exp_minus_control_00+lTOA_flux_exp_minus_control_05_n+lTOA_flux_exp_minus_control_10_n+lTOA_flux_exp_minus_control_15_n+lTOA_flux_exp_minus_control_20_n+lTOA_flux_exp_minus_control_25_n+lTOA_flux_exp_minus_control_30_n+lTOA_flux_exp_minus_control_35_n+lTOA_flux_exp_minus_control_40_n+lTOA_flux_exp_minus_control_45_n+lTOA_flux_exp_minus_control_50_n+lTOA_flux_exp_minus_control_55_n+lTOA_flux_exp_minus_control_60_n+lTOA_flux_exp_minus_control_65_n+lTOA_flux_exp_minus_control_70_n+lTOA_flux_exp_minus_control_75_n+lTOA_flux_exp_minus_control_80_n+lTOA_flux_exp_minus_control_85_n+lTOA_flux_exp_minus_control_pole_n

# %%
lpp_total=np.array(lw_Sum_TOA_NH_exp)
#zp= pp.transpose()
lexp_total=np.linspace(0,1,96)
lplat_total=np.array(lw_Sum_TOA_NH_exp.lat)
lexpp_total, lppp_total=np.meshgrid(lexp_total, lpp_total)

lpp_4k_n=np.array(lTOA_flux_exp_minus_control_4k_n)
#zp= pp.transpose()
lexp_4k_n=np.linspace(0,1,96)
lplat_4k_n=np.array(lTOA_flux_exp_minus_control_4k_n.lat)
lexpp_4k_n, lppp_4k_n=np.meshgrid(lexp_4k_n, lpp_4k_n)

# %%
nrow = 1
ncol = 3
fig = plt.figure(figsize=(5, 5))
grid = ImageGrid(fig, 
                 111, # as in plt.subplot(111)
                 nrows_ncols=(nrow,ncol),
                 axes_pad=0,
                 share_all=True,)

#for i in range(1):
#    for j in range(2):
im = np.random.rand(28,28)
gs = gridspec.GridSpec(2, 2)
gs.update(wspace=0)
vmax=70
vmin=-70
plt.subplot(gs[0,0])
plt.pcolormesh(lexpp_total,lplat_total,lppp_total,cmap='seismic',vmax=vmax,vmin=vmin)
plt.yticks(np.arange(-90, 91, 30))
plt.ylabel("Latitude")
plt.xticks([])
plt.xlabel("Sum of all NH EXP")

plt.subplot(gs[0,1])
plt.pcolormesh(lexpp_4k_n,lplat_4k_n,lppp_4k_n,cmap='seismic',vmax=vmax,vmin=vmin)
plt.xticks([])
plt.xlabel("+4k NH EXP")
ax = pylab.gca()
ax.yaxis.set_visible(False)

plt.colorbar(shrink=1)
plt.show()

# %%
spp_total=np.array(sw_Sum_TOA_NH_exp)
#zp= pp.transpose()
sexp_total=np.linspace(0,1,96)
splat_total=np.array(sw_Sum_TOA_NH_exp.lat)
sexpp_total, sppp_total=np.meshgrid(sexp_total, spp_total)

spp_4k_n=np.array(sTOA_flux_exp_minus_control_4k_n)
#zp= pp.transpose()
sexp_4k_n=np.linspace(0,1,96)
splat_4k_n=np.array(sTOA_flux_exp_minus_control_4k_n.lat)
sexpp_4k_n, sppp_4k_n=np.meshgrid(sexp_4k_n, spp_4k_n)

# %%
nrow = 1
ncol = 3
fig = plt.figure(figsize=(5, 5))
grid = ImageGrid(fig, 
                 111, # as in plt.subplot(111)
                 nrows_ncols=(nrow,ncol),
                 axes_pad=0,
                 share_all=True,)

#for i in range(1):
#    for j in range(2):
im = np.random.rand(28,28)
gs = gridspec.GridSpec(2, 2)
gs.update(wspace=0)
vmax=70
vmin=-70
plt.subplot(gs[0,0])
plt.pcolormesh(sexpp_total,splat_total,sppp_total,cmap='seismic',vmax=vmax,vmin=vmin)
plt.yticks(np.arange(-90, 91, 30))
plt.ylabel("Latitude")
plt.xticks([])
plt.xlabel("Sum of all NH EXP")

plt.subplot(gs[0,1])
plt.pcolormesh(sexpp_4k_n,splat_4k_n,sppp_4k_n,cmap='seismic',vmax=vmax,vmin=vmin)
plt.xticks([])
plt.xlabel("+4k NH EXP")
ax = pylab.gca()
ax.yaxis.set_visible(False)

plt.colorbar(shrink=1)
plt.show()

# %%
#Surface flux
Qs_00=(-data_00.FLNS.mean('lon')+data_00.FSNS.mean('lon')-data_00.SHFLX.mean('lon')-data_00.LHFLX.mean('lon'))-(-data_control.FLNS.mean('lon')+data_control.FSNS.mean('lon')-data_control.SHFLX.mean('lon')-data_control.LHFLX.mean('lon'))
Qs_05_n=(-data_05_n.FLNS.mean('lon')+data_05_n.FSNS.mean('lon')-data_05_n.SHFLX.mean('lon')-data_05_n.LHFLX.mean('lon'))-(-data_control.FLNS.mean('lon')+data_control.FSNS.mean('lon')-data_control.SHFLX.mean('lon')-data_control.LHFLX.mean('lon'))
Qs_10_n=(-data_10_n.FLNS.mean('lon')+data_10_n.FSNS.mean('lon')-data_10_n.SHFLX.mean('lon')-data_10_n.LHFLX.mean('lon'))-(-data_control.FLNS.mean('lon')+data_control.FSNS.mean('lon')-data_control.SHFLX.mean('lon')-data_control.LHFLX.mean('lon'))
Qs_15_n=(-data_15_n.FLNS.mean('lon')+data_15_n.FSNS.mean('lon')-data_15_n.SHFLX.mean('lon')-data_15_n.LHFLX.mean('lon'))-(-data_control.FLNS.mean('lon')+data_control.FSNS.mean('lon')-data_control.SHFLX.mean('lon')-data_control.LHFLX.mean('lon'))
Qs_20_n=(-data_20_n.FLNS.mean('lon')+data_20_n.FSNS.mean('lon')-data_20_n.SHFLX.mean('lon')-data_20_n.LHFLX.mean('lon'))-(-data_control.FLNS.mean('lon')+data_control.FSNS.mean('lon')-data_control.SHFLX.mean('lon')-data_control.LHFLX.mean('lon'))
Qs_25_n=(-data_25_n.FLNS.mean('lon')+data_25_n.FSNS.mean('lon')-data_25_n.SHFLX.mean('lon')-data_25_n.LHFLX.mean('lon'))-(-data_control.FLNS.mean('lon')+data_control.FSNS.mean('lon')-data_control.SHFLX.mean('lon')-data_control.LHFLX.mean('lon'))
Qs_30_n=(-data_30_n.FLNS.mean('lon')+data_30_n.FSNS.mean('lon')-data_30_n.SHFLX.mean('lon')-data_30_n.LHFLX.mean('lon'))-(-data_control.FLNS.mean('lon')+data_control.FSNS.mean('lon')-data_control.SHFLX.mean('lon')-data_control.LHFLX.mean('lon'))
Qs_35_n=(-data_35_n.FLNS.mean('lon')+data_35_n.FSNS.mean('lon')-data_35_n.SHFLX.mean('lon')-data_35_n.LHFLX.mean('lon'))-(-data_control.FLNS.mean('lon')+data_control.FSNS.mean('lon')-data_control.SHFLX.mean('lon')-data_control.LHFLX.mean('lon'))
Qs_40_n=(-data_40_n.FLNS.mean('lon')+data_40_n.FSNS.mean('lon')-data_40_n.SHFLX.mean('lon')-data_40_n.LHFLX.mean('lon'))-(-data_control.FLNS.mean('lon')+data_control.FSNS.mean('lon')-data_control.SHFLX.mean('lon')-data_control.LHFLX.mean('lon'))
Qs_45_n=(-data_45_n.FLNS.mean('lon')+data_45_n.FSNS.mean('lon')-data_45_n.SHFLX.mean('lon')-data_45_n.LHFLX.mean('lon'))-(-data_control.FLNS.mean('lon')+data_control.FSNS.mean('lon')-data_control.SHFLX.mean('lon')-data_control.LHFLX.mean('lon'))
Qs_50_n=(-data_50_n.FLNS.mean('lon')+data_50_n.FSNS.mean('lon')-data_50_n.SHFLX.mean('lon')-data_50_n.LHFLX.mean('lon'))-(-data_control.FLNS.mean('lon')+data_control.FSNS.mean('lon')-data_control.SHFLX.mean('lon')-data_control.LHFLX.mean('lon'))
Qs_55_n=(-data_55_n.FLNS.mean('lon')+data_55_n.FSNS.mean('lon')-data_55_n.SHFLX.mean('lon')-data_55_n.LHFLX.mean('lon'))-(-data_control.FLNS.mean('lon')+data_control.FSNS.mean('lon')-data_control.SHFLX.mean('lon')-data_control.LHFLX.mean('lon'))
Qs_60_n=(-data_60_n.FLNS.mean('lon')+data_60_n.FSNS.mean('lon')-data_60_n.SHFLX.mean('lon')-data_60_n.LHFLX.mean('lon'))-(-data_control.FLNS.mean('lon')+data_control.FSNS.mean('lon')-data_control.SHFLX.mean('lon')-data_control.LHFLX.mean('lon'))
Qs_65_n=(-data_65_n.FLNS.mean('lon')+data_65_n.FSNS.mean('lon')-data_65_n.SHFLX.mean('lon')-data_65_n.LHFLX.mean('lon'))-(-data_control.FLNS.mean('lon')+data_control.FSNS.mean('lon')-data_control.SHFLX.mean('lon')-data_control.LHFLX.mean('lon'))
Qs_70_n=(-data_70_n.FLNS.mean('lon')+data_70_n.FSNS.mean('lon')-data_70_n.SHFLX.mean('lon')-data_70_n.LHFLX.mean('lon'))-(-data_control.FLNS.mean('lon')+data_control.FSNS.mean('lon')-data_control.SHFLX.mean('lon')-data_control.LHFLX.mean('lon'))
Qs_75_n=(-data_75_n.FLNS.mean('lon')+data_75_n.FSNS.mean('lon')-data_75_n.SHFLX.mean('lon')-data_75_n.LHFLX.mean('lon'))-(-data_control.FLNS.mean('lon')+data_control.FSNS.mean('lon')-data_control.SHFLX.mean('lon')-data_control.LHFLX.mean('lon'))
Qs_80_n=(-data_80_n.FLNS.mean('lon')+data_80_n.FSNS.mean('lon')-data_80_n.SHFLX.mean('lon')-data_80_n.LHFLX.mean('lon'))-(-data_control.FLNS.mean('lon')+data_control.FSNS.mean('lon')-data_control.SHFLX.mean('lon')-data_control.LHFLX.mean('lon'))
Qs_85_n=(-data_85_n.FLNS.mean('lon')+data_85_n.FSNS.mean('lon')-data_85_n.SHFLX.mean('lon')-data_85_n.LHFLX.mean('lon'))-(-data_control.FLNS.mean('lon')+data_control.FSNS.mean('lon')-data_control.SHFLX.mean('lon')-data_control.LHFLX.mean('lon'))
Qs_pole_n=(-data_pole_n.FLNS.mean('lon')+data_pole_n.FSNS.mean('lon')-data_pole_n.SHFLX.mean('lon')-data_pole_n.LHFLX.mean('lon'))-(-data_control.FLNS.mean('lon')+data_control.FSNS.mean('lon')-data_control.SHFLX.mean('lon')-data_control.LHFLX.mean('lon'))


#TOA
TOA_00 = (data_00.FSNT.mean('lon')-data_00.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_05_n = (data_05_n.FSNT.mean('lon')-data_05_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_10_n = (data_10_n.FSNT.mean('lon')-data_10_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_15_n = (data_15_n.FSNT.mean('lon')-data_15_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_20_n = (data_20_n.FSNT.mean('lon')-data_20_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_25_n = (data_25_n.FSNT.mean('lon')-data_25_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_30_n = (data_30_n.FSNT.mean('lon')-data_30_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_35_n = (data_35_n.FSNT.mean('lon')-data_35_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_40_n = (data_40_n.FSNT.mean('lon')-data_40_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_45_n = (data_45_n.FSNT.mean('lon')-data_45_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_50_n = (data_50_n.FSNT.mean('lon')-data_50_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_55_n = (data_55_n.FSNT.mean('lon')-data_55_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_60_n = (data_60_n.FSNT.mean('lon')-data_60_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_65_n = (data_65_n.FSNT.mean('lon')-data_65_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_70_n = (data_70_n.FSNT.mean('lon')-data_70_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_75_n = (data_75_n.FSNT.mean('lon')-data_75_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_80_n = (data_80_n.FSNT.mean('lon')-data_80_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_85_n = (data_85_n.FSNT.mean('lon')-data_85_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
TOA_pole_n = (data_pole_n.FSNT.mean('lon')-data_pole_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))

# %%
TOA_4k_n=(data_4k_n.FSNT.mean('lon')-data_4k_n.FLNT.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FLNT.mean('lon'))
Sum_TOA=TOA_00+TOA_05_n+TOA_10_n+TOA_15_n+TOA_20_n+TOA_25_n+TOA_30_n+TOA_35_n+TOA_40_n+TOA_45_n+TOA_50_n+TOA_55_n+TOA_60_n+TOA_65_n+TOA_70_n+TOA_75_n+TOA_80_n+TOA_85_n+TOA_pole_n

# %%
Sum_TOA.plot(label='Sum of all NH Exp')
TOA_4k_n.plot(label='+4k NH EXP')
plt.legend(loc='upper right')
plt.title('TOA flux')
# Out:
# Text(0.5, 1.0, 'TOA flux')

# %%
#SW
sTOA_pole_n = (data_pole_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_00 = (data_00.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_05_n = (data_05_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_10_n = (data_10_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_15_n = (data_15_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_20_n = (data_20_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_25_n = (data_25_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_30_n = (data_30_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_35_n = (data_35_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_40_n = (data_40_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_45_n = (data_45_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_50_n = (data_50_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_55_n = (data_55_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_60_n = (data_60_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_65_n = (data_65_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_70_n = (data_70_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_75_n = (data_75_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_80_n = (data_80_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_85_n = (data_85_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))

#LW
lTOA_pole_n = (data_pole_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_00 = (data_00.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_05_n = (data_05_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_10_n = (data_10_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_15_n = (data_15_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_20_n = (data_20_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_25_n = (data_25_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_30_n = (data_30_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_35_n = (data_35_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_40_n = (data_40_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_45_n = (data_45_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_50_n = (data_50_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_55_n = (data_55_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_60_n = (data_60_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_65_n = (data_65_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_70_n = (data_70_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_75_n = (data_75_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_80_n = (data_80_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_85_n = (data_85_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))

# %%
#shortwave TOA Flux
sTOA_flux_exp_minus_control_4k_n = (data_4k_n.FSNT.mean('lon'))-(data_control.FSNT.mean('lon'))
sTOA_total_flux_all_exp=(sTOA_flux_exp_minus_control_00+sTOA_flux_exp_minus_control_pole_n+sTOA_flux_exp_minus_control_05_n+sTOA_flux_exp_minus_control_10_n+sTOA_flux_exp_minus_control_15_n+sTOA_flux_exp_minus_control_20_n+sTOA_flux_exp_minus_control_25_n+sTOA_flux_exp_minus_control_30_n+sTOA_flux_exp_minus_control_35_n+sTOA_flux_exp_minus_control_40_n+sTOA_flux_exp_minus_control_45_n+sTOA_flux_exp_minus_control_50_n+sTOA_flux_exp_minus_control_55_n+sTOA_flux_exp_minus_control_60_n+sTOA_flux_exp_minus_control_65_n+sTOA_flux_exp_minus_control_70_n+sTOA_flux_exp_minus_control_75_n+sTOA_flux_exp_minus_control_80_n+sTOA_flux_exp_minus_control_85_n)
#long wave of TOA flux
lTOA_flux_exp_minus_control_4k_n = (data_4k_n.FLNT.mean('lon'))-(data_control.FLNT.mean('lon'))
lTOA_total_flux_all_exp=(lTOA_flux_exp_minus_control_00+lTOA_flux_exp_minus_control_pole_n+lTOA_flux_exp_minus_control_05_n+lTOA_flux_exp_minus_control_10_n+lTOA_flux_exp_minus_control_15_n+lTOA_flux_exp_minus_control_20_n+lTOA_flux_exp_minus_control_25_n+lTOA_flux_exp_minus_control_30_n+lTOA_flux_exp_minus_control_35_n+lTOA_flux_exp_minus_control_40_n+lTOA_flux_exp_minus_control_45_n+lTOA_flux_exp_minus_control_50_n+lTOA_flux_exp_minus_control_55_n+lTOA_flux_exp_minus_control_60_n+lTOA_flux_exp_minus_control_65_n+lTOA_flux_exp_minus_control_70_n+lTOA_flux_exp_minus_control_75_n+lTOA_flux_exp_minus_control_80_n+lTOA_flux_exp_minus_control_85_n)

# %%
sTOA_flux_exp_minus_control_4k_n.plot(label='4K NH Exp')
sTOA_total_flux_all_exp.plot( label='Sum of all NH Exp')
plt.legend(loc='upper left')
plt.title('SW TOA flux')
# Out:
# Text(0.5, 1.0, 'SW TOA flux')

# %%
lTOA_flux_exp_minus_control_4k_n.plot(label='4K NH Exp')
lTOA_total_flux_all_exp.plot( label='Sum of all NH Exp')
plt.legend(loc='upper left')
plt.title('LW TOA flux')
# Out:
# Text(0.5, 1.0, 'LW TOA flux')

# %%
Sum_Qs=Qs_00+Qs_pole_n+Qs_05_n+Qs_10_n+Qs_15_n+Qs_20_n+Qs_25_n+Qs_30_n+Qs_35_n+Qs_40_n+Qs_45_n+Qs_50_n+Qs_55_n+Qs_60_n+Qs_65_n+Qs_70_n+Qs_75_n+Qs_80_n+Qs_85_n
Qs_4k_n=(-data_4k_n.FLNS.mean('lon')+data_4k_n.FSNS.mean('lon')-data_4k_n.SHFLX.mean('lon')-data_4k_n.LHFLX.mean('lon'))-(-data_control.FLNS.mean('lon')+data_control.FSNS.mean('lon')-data_control.SHFLX.mean('lon')-data_control.LHFLX.mean('lon'))

# %%
Sum_Qs.plot(label='Sum of all NH Exp')
Qs_4k_n.plot(label='+4k NH EXP')
plt.legend(loc='upper right')
plt.title('Surface heat flux')
# Out:
# Text(0.5, 1.0, 'Surface heat flux')

# %%
Sum_Qa=Sum_Qs-Sum_TOA
Qa_4k_n=Qs_4k_n-TOA_4k_n

# %%
Sum_Qa.plot(label='Sum of all NH Exp')
Qa_4k_n.plot(label='+4k NH EXP')
plt.legend(loc='upper right')
plt.title('Qa=(Qs-TOA) flux')
# Out:
# Text(0.5, 1.0, 'Qa=(Qs-TOA) flux')

# %%
T_pole_n=data_pole_n.T.mean('lon')-data_control.T.mean('lon')
T_00=data_00.T.mean('lon')-data_control.T.mean('lon')
T_05_n=data_05_n.T.mean('lon')-data_control.T.mean('lon')
T_10_n=data_10_n.T.mean('lon')-data_control.T.mean('lon')
T_15_n=data_15_n.T.mean('lon')-data_control.T.mean('lon')
T_20_n=data_20_n.T.mean('lon')-data_control.T.mean('lon')
T_25_n=data_25_n.T.mean('lon')-data_control.T.mean('lon')
T_30_n=data_30_n.T.mean('lon')-data_control.T.mean('lon')
T_35_n=data_35_n.T.mean('lon')-data_control.T.mean('lon')
T_40_n=data_40_n.T.mean('lon')-data_control.T.mean('lon')
T_45_n=data_45_n.T.mean('lon')-data_control.T.mean('lon')
T_50_n=data_50_n.T.mean('lon')-data_control.T.mean('lon')
T_55_n=data_55_n.T.mean('lon')-data_control.T.mean('lon')
T_60_n=data_60_n.T.mean('lon')-data_control.T.mean('lon')
T_65_n=data_65_n.T.mean('lon')-data_control.T.mean('lon')
T_70_n=data_70_n.T.mean('lon')-data_control.T.mean('lon')
T_75_n=data_75_n.T.mean('lon')-data_control.T.mean('lon')
T_80_n=data_80_n.T.mean('lon')-data_control.T.mean('lon')
T_85_n=data_85_n.T.mean('lon')-data_control.T.mean('lon')

T_4k_n=data_4k_n.T.mean('lon')-data_control.T.mean('lon')
T_total=(T_pole_n+T_00+T_05_n+T_10_n+T_15_n+T_20_n+T_25_n+T_30_n+T_35_n+T_40_n+T_45_n+T_50_n+T_55_n+T_60_n+T_65_n+T_70_n+T_75_n+T_80_n+T_85_n)

# %%
nrow = 1
ncol = 7
fig = plt.figure(figsize=(25, 20))
grid = ImageGrid(fig, 
                 111, # as in plt.subplot(111)
                 nrows_ncols=(nrow,ncol),
                 axes_pad=0,
                 share_all=True,)

#for i in range(1):
#    for j in range(2):
im = np.random.rand(28,28)
gs = gridspec.GridSpec(14, 14)
gs.update(wspace=0.3)
vmax=10
vmin=-10
plt.subplot(gs[0,0])
T_4k_n.plot(vmax=vmax, vmin=vmin,yincrease=False, cmap='RdBu_r',add_colorbar=False)
#plt.yscale("log")
plt.title('4k NH')
ax = pylab.gca()
#plt.hlines(y=1000, xmin=-10, xmax=10, colors='black', linestyles='-', lw=5, label='Single Short Line')
plt.xticks([-90, -60,-30,0,30,60,90])
plt.yticks([1000, 800, 600,400,200])
plt.xticks(rotation=45)

plt.subplot(gs[0,1])
T_total.plot(vmax=vmax, vmin=vmin,yincrease=False, cmap='RdBu_r')
#plt.yscale("log")
plt.title('Sum of all NH Exp')
ax = pylab.gca()
ax.yaxis.set_visible(False)
#plt.hlines(y=1000, xmin=-5, xmax=15, colors='black', linestyles='-', lw=5, label='Single Short Line')
plt.xticks([-90, -60,-30,0,30,60,90])
plt.xticks(rotation=45)


# Get the current axis
ax = pylab.gca()
# Set Y-axis visibility to False
ax.yaxis.set_visible(False)

#        plt.set_yticklabels([])

#plt.tight_layout() # do not use this!!
#plt.subplot(gs[0,6])
#plt.colorbar()
plt.show()

# %%
#clear sky short wave
css_pole_n=data_pole_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_00=data_00.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_05_n=data_05_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_10_n=data_10_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_15_n=data_15_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_20_n=data_20_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_25_n=data_25_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_30_n=data_30_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_35_n=data_35_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_40_n=data_40_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_45_n=data_45_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_50_n=data_50_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_55_n=data_55_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_60_n=data_60_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_65_n=data_65_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_70_n=data_70_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_75_n=data_75_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_80_n=data_80_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')
css_85_n=data_85_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')


#clear sky long wave
csl_pole_n=data_pole_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_00=data_00.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_05_n=data_05_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_10_n=data_10_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_15_n=data_15_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_20_n=data_20_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_25_n=data_25_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_30_n=data_30_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_35_n=data_35_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_40_n=data_40_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_45_n=data_45_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_50_n=data_50_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_55_n=data_55_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_60_n=data_60_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_65_n=data_65_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_70_n=data_70_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_75_n=data_75_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_80_n=data_80_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')
csl_85_n=data_85_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')


#all sky short wave
ass_pole_n=data_pole_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_00=data_00.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_05_n=data_05_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_10_n=data_10_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_15_n=data_15_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_20_n=data_20_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_25_n=data_25_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_30_n=data_30_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_35_n=data_35_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_40_n=data_40_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_45_n=data_45_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_50_n=data_50_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_55_n=data_55_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_60_n=data_60_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_65_n=data_65_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_70_n=data_70_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_75_n=data_75_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_80_n=data_80_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')
ass_85_n=data_85_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')



#all sky long wave
asl_pole_n=data_pole_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_00=data_00.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_05_n=data_05_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_10_n=data_10_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_15_n=data_15_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_20_n=data_20_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_25_n=data_25_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_30_n=data_30_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_35_n=data_35_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_40_n=data_40_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_45_n=data_45_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_50_n=data_50_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_55_n=data_55_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_60_n=data_60_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_65_n=data_65_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_70_n=data_70_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_75_n=data_75_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_80_n=data_80_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')
asl_85_n=data_85_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')



#CRE short wave-zonal
CRES_pole_n = (data_pole_n.FSNT.mean('lon')-data_pole_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_00 = (data_00.FSNT.mean('lon')-data_00.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_05_n = (data_05_n.FSNT.mean('lon')-data_05_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_10_n = (data_10_n.FSNT.mean('lon')-data_10_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_15_n = (data_15_n.FSNT.mean('lon')-data_15_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_20_n = (data_20_n.FSNT.mean('lon')-data_20_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_25_n = (data_25_n.FSNT.mean('lon')-data_25_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_30_n = (data_30_n.FSNT.mean('lon')-data_30_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_35_n = (data_35_n.FSNT.mean('lon')-data_35_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_40_n = (data_40_n.FSNT.mean('lon')-data_40_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_45_n = (data_45_n.FSNT.mean('lon')-data_45_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_50_n = (data_50_n.FSNT.mean('lon')-data_50_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_55_n = (data_55_n.FSNT.mean('lon')-data_55_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_60_n = (data_60_n.FSNT.mean('lon')-data_60_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_65_n = (data_65_n.FSNT.mean('lon')-data_65_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_70_n = (data_70_n.FSNT.mean('lon')-data_70_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_75_n = (data_75_n.FSNT.mean('lon')-data_75_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_80_n = (data_80_n.FSNT.mean('lon')-data_80_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))
CRES_85_n = (data_85_n.FSNT.mean('lon')-data_85_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))


#CRE long wave-zonal
CREL_pole_n = (data_pole_n.FLNT.mean('lon')-data_pole_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_00 = (data_00.FLNT.mean('lon')-data_00.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_05_n = (data_05_n.FLNT.mean('lon')-data_05_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_10_n = (data_10_n.FLNT.mean('lon')-data_10_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_15_n = (data_15_n.FLNT.mean('lon')-data_15_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_20_n = (data_20_n.FLNT.mean('lon')-data_20_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_25_n = (data_25_n.FLNT.mean('lon')-data_25_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_30_n = (data_30_n.FLNT.mean('lon')-data_30_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_35_n = (data_35_n.FLNT.mean('lon')-data_35_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_40_n = (data_40_n.FLNT.mean('lon')-data_40_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_45_n = (data_45_n.FLNT.mean('lon')-data_45_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_50_n = (data_50_n.FLNT.mean('lon')-data_50_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_55_n = (data_55_n.FLNT.mean('lon')-data_55_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_60_n = (data_60_n.FLNT.mean('lon')-data_60_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_65_n = (data_65_n.FLNT.mean('lon')-data_65_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_70_n = (data_70_n.FLNT.mean('lon')-data_70_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_75_n = (data_75_n.FLNT.mean('lon')-data_75_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_80_n = (data_80_n.FLNT.mean('lon')-data_80_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))
CREL_85_n = (data_85_n.FLNT.mean('lon')-data_85_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))

# %%
CRES_total=(CRES_pole_n+CRES_00+CRES_05_n+CRES_10_n+CRES_15_n+CRES_20_n+CRES_25_n+CRES_30_n+CRES_35_n+CRES_40_n+CRES_45_n+CRES_50_n+CRES_55_n+CRES_60_n+CRES_65_n+CRES_70_n+CRES_75_n+CRES_80_n+CRES_85_n)
CRES_4k_n=(data_4k_n.FSNT.mean('lon')-data_4k_n.FSNTC.mean('lon'))-(data_control.FSNT.mean('lon')-data_control.FSNTC.mean('lon'))

CREL_total=(CREL_pole_n+CREL_00+CREL_05_n+CREL_10_n+CREL_15_n+CREL_20_n+CREL_25_n+CREL_30_n+CREL_35_n+CREL_40_n+CREL_45_n+CREL_50_n+CREL_55_n+CREL_60_n+CREL_65_n+CREL_70_n+CREL_75_n+CREL_80_n+CREL_85_n)
CREL_4k_n=(data_4k_n.FLNT.mean('lon')-data_4k_n.FLNTC.mean('lon'))-(data_control.FLNT.mean('lon')-data_control.FLNTC.mean('lon'))

ass_total=(ass_pole_n+ass_00+ass_05_n+ass_10_n+ass_15_n+ass_20_n+ass_25_n+ass_30_n+ass_35_n+ass_40_n+ass_45_n+ass_50_n+ass_55_n+ass_60_n+ass_65_n+ass_70_n+ass_75_n+ass_80_n+ass_85_n)
ass_4k_n=data_4k_n.FSNT.mean('lon')-data_control.FSNT.mean('lon')

asl_total=(asl_pole_n+asl_00+asl_05_n+asl_10_n+asl_15_n+asl_20_n+asl_25_n+asl_30_n+asl_35_n+asl_40_n+asl_45_n+asl_50_n+asl_55_n+asl_60_n+asl_65_n+asl_70_n+asl_75_n+asl_80_n+asl_85_n)
asl_4k_n=data_4k_n.FLNT.mean('lon')-data_control.FLNT.mean('lon')

css_total=(css_pole_n+css_00+css_05_n+css_10_n+css_15_n+css_20_n+css_25_n+css_30_n+css_35_n+css_40_n+css_45_n+css_50_n+css_55_n+css_60_n+css_65_n+css_70_n+css_75_n+css_80_n+css_85_n)
css_4k_n=data_4k_n.FSNTC.mean('lon')-data_control.FSNTC.mean('lon')

csl_total=(csl_pole_n+csl_00+csl_05_n+csl_10_n+csl_15_n+csl_20_n+csl_25_n+csl_30_n+csl_35_n+csl_40_n+csl_45_n+csl_50_n+csl_55_n+csl_60_n+csl_65_n+csl_70_n+csl_75_n+csl_80_n+csl_85_n)
csl_4k_n=data_4k_n.FLNTC.mean('lon')-data_control.FLNTC.mean('lon')

# %%
CRES_total.plot(label='CRES_total')
CRES_4k_n.plot(label='CRES_4k_n')
plt.legend(loc='lower left')
plt.title("CRES")
# Out:
# Text(0.5, 1.0, 'CRES')

# %%
CREL_total.plot(label='CREL_total')
CREL_4k_n.plot(label='CRES_4k_n')
plt.legend(loc='lower left')
plt.title("CREL")
# Out:
# Text(0.5, 1.0, 'CREL')

# %%
ass_total.plot(label='asl_total')
ass_4k_n.plot(label='asl_4k_n')
plt.legend(loc='lower left')
plt.title("ASS")
# Out:
# Text(0.5, 1.0, 'ASS')

# %%
asl_total.plot(label='asl_total')
asl_4k_n.plot(label='asl_4k_n')
plt.legend(loc='lower left')
plt.title("ASL")
# Out:
# Text(0.5, 1.0, 'ASL')

# %%
css_total.plot(label='css_total')
css_4k_n.plot(label='asl_4k_n')
plt.legend(loc='lower left')
plt.title("CSS")
# Out:
# Text(0.5, 1.0, 'CSS')

# %%
csl_total.plot(label='csl_total')
csl_4k_n.plot(label='csl_4k_n')
plt.legend(loc='lower left')
plt.title("CSL")
# Out:
# Text(0.5, 1.0, 'CSL')

# %%
# total clear sky
tcs_pole_n=css_pole_n-csl_pole_n
tcs_00=css_00-csl_00
tcs_05_n=css_05_n-csl_05_n
tcs_10_n=css_10_n-csl_10_n
tcs_15_n=css_15_n-csl_15_n
tcs_20_n=css_20_n-csl_20_n
tcs_25_n=css_25_n-csl_25_n
tcs_30_n=css_30_n-csl_30_n
tcs_35_n=css_35_n-csl_35_n
tcs_40_n=css_40_n-csl_40_n
tcs_45_n=css_45_n-csl_45_n
tcs_50_n=css_50_n-csl_50_n
tcs_55_n=css_55_n-csl_55_n
tcs_60_n=css_60_n-csl_60_n
tcs_65_n=css_65_n-csl_65_n
tcs_70_n=css_70_n-csl_70_n
tcs_75_n=css_75_n-csl_75_n
tcs_80_n=css_80_n-csl_80_n
tcs_85_n=css_85_n-csl_85_n

# total all sky
tas_pole_n=ass_pole_n-asl_pole_n
tas_00=ass_00-asl_00
tas_05_n=ass_05_n-asl_05_n
tas_10_n=ass_10_n-asl_10_n
tas_15_n=ass_15_n-asl_15_n
tas_20_n=ass_20_n-asl_20_n
tas_25_n=ass_25_n-asl_25_n
tas_30_n=ass_30_n-asl_30_n
tas_35_n=ass_35_n-asl_35_n
tas_40_n=ass_40_n-asl_40_n
tas_45_n=ass_45_n-asl_45_n
tas_50_n=ass_50_n-asl_50_n
tas_55_n=ass_55_n-asl_55_n
tas_60_n=ass_60_n-asl_60_n
tas_65_n=ass_65_n-asl_65_n
tas_70_n=ass_70_n-asl_70_n
tas_75_n=ass_75_n-asl_75_n
tas_80_n=ass_80_n-asl_80_n
tas_85_n=ass_85_n-asl_85_n

#total CRE
tCRE_pole_n=CRES_pole_n-CREL_pole_n
tCRE_00=CRES_00-CREL_00
tCRE_05_n=CRES_05_n-CREL_05_n
tCRE_10_n=CRES_10_n-CREL_10_n
tCRE_15_n=CRES_15_n-CREL_15_n
tCRE_20_n=CRES_20_n-CREL_20_n
tCRE_25_n=CRES_25_n-CREL_25_n
tCRE_30_n=CRES_30_n-CREL_30_n
tCRE_35_n=CRES_35_n-CREL_35_n
tCRE_40_n=CRES_40_n-CREL_40_n
tCRE_45_n=CRES_45_n-CREL_45_n
tCRE_50_n=CRES_50_n-CREL_50_n
tCRE_55_n=CRES_55_n-CREL_55_n
tCRE_60_n=CRES_60_n-CREL_60_n
tCRE_65_n=CRES_65_n-CREL_65_n
tCRE_70_n=CRES_70_n-CREL_70_n

tCRE_75_n=CRES_75_n-CREL_75_n
tCRE_80_n=CRES_80_n-CREL_80_n
tCRE_85_n=CRES_85_n-CREL_85_n

# %%
tcs_total=(tcs_pole_n+tcs_00+tcs_05_n+tcs_10_n+tcs_15_n+tcs_20_n+tcs_25_n+tcs_30_n+tcs_35_n+tcs_40_n+tcs_45_n+tcs_50_n+tcs_55_n+tcs_60_n+tcs_65_n+tcs_70_n+tcs_75_n+tcs_80_n+tcs_85_n)
tcs_4k_n=css_4k_n-csl_4k_n

tas_total=(tas_pole_n+tas_00+tas_05_n+tas_10_n+tas_15_n+tas_20_n+tas_25_n+tas_30_n+tas_35_n+tas_40_n+tas_45_n+tas_50_n+tas_55_n+tas_60_n+tas_65_n+tas_70_n+tas_75_n+tas_80_n+tas_85_n)
tas_4k_n=ass_4k_n-asl_4k_n

tCRE_total=(tCRE_pole_n+tCRE_00+tCRE_05_n+tCRE_10_n+tCRE_15_n+tCRE_20_n+tCRE_25_n+tCRE_30_n+tCRE_35_n+tCRE_40_n+tCRE_45_n+tCRE_50_n+tCRE_55_n+tCRE_60_n+tCRE_65_n+tCRE_70_n+tCRE_75_n+tCRE_80_n+tCRE_85_n)
tCRE_4k_n=CRES_4k_n-CREL_4k_n

# %%
tcs_total.plot(label='Total Clear Sky(Total)')
tcs_4k_n.plot(label='Total Clear Sky 4k NH')
plt.legend(loc='lower left')
plt.title("Clear Sky")
# Out:
# Text(0.5, 1.0, 'Clear Sky')

# %%
tas_total.plot(label='Total all Sky(Total)')
tas_4k_n.plot(label='Total all Sky 4k NH')
plt.legend(loc='lower left')
plt.title("All Sky")
# Out:
# Text(0.5, 1.0, 'All Sky')

# %%
tCRE_total.plot(label='Total CRE (Total)')
tCRE_4k_n.plot(label='Total CRE 4k NH')
plt.legend(loc='lower left')
plt.title("Total CRE")
# Out:
# Text(0.5, 1.0, 'Total CRE')
